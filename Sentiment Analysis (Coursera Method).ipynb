# %%
import pandas as pd
import numpy as np
import nltk

# %%
df=pd.read_csv("headlines.csv")

# %%
headlinecat=[cat for cat in df["headline_category"].value_counts().index if 'business' in cat]

# %%
headlinecat
# Out:
# ['business.india-business',
#  'business.international-business',
#  'business.personal-finance',
#  'business',
#  'india-business-news-wire',
#  'business.faqs.income-tax-faqs',
#  'business.mf-simplified.mf-news',
#  'business.mf-simplified.jargon-busters.debt',
#  'business.faqs.aadhar-faqs',
#  'business.mf-simplified.jargon-busters.equity',
#  'business.faqs.gst-faqs',
#  'business.mf-simplified.faq']

# %%
df1=df.loc[df["headline_category"].str.find("business")!=-1].reset_index(drop=True)

# %%
df1.head()
# Out:
#    publish_date        headline_category  \
# 0      20010104  business.india-business
# 1      20010522  business.india-business
# 2      20010522  business.india-business
# 3      20010522  business.india-business
# 4      20010522  business.india-business
#
#                                        headline_text
# 0       Car dealers caught in Bihar sales tax ruling
# 1  Re-negotiation best: Deshmukh; lenders' SOS to...
# 2       Samsung says hello to cellular unit in India
# 3            Govt lifts port-linked curbs on imports
# 4                  RIL plans to mop up to Rs 1;000cr

# %%
import matplotlib.pyplot as plt
import random
import re
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

# %%
df1.shape
# Out:
# (155587, 3)

# %%
df1["headline_text"]=df1["headline_text"].str.lower()

# %%
df2=df1.loc[df1["headline_text"].str.find("sensex" or "bse")!=-1].reset_index(drop=True)

# %%
df2.shape
# Out:
# (5706, 3)

# %%
df2.head()
# Out:
#    publish_date        headline_category  \
# 0      20010529  business.india-business
# 1      20010715  business.india-business
# 2      20010727  business.india-business
# 3      20010804  business.india-business
# 4      20010807  business.india-business
#
#                                     headline_text
# 0  sensex stays in the bull zone; gains 60 points
# 1      money wise brsensex faces a roller coaster
# 2                for sensex; worst is yet to come
# 3         sensex recovers by 2.27% over last week
# 4                      sensex slides by 11 points

# %% [markdown]
# ### Tokenizing  (making a list of words)

# %%
tokenizer=TweetTokenizer(preserve_case=False, reduce_len=True)

# %%
tokenized=[]
for headline in df1["headline_text"]:
    tokenized.append(tokenizer.tokenize(headline))

# %%
tokenized
# Out:
# [['car', 'dealers', 'caught', 'in', 'bihar', 'sales', 'tax', 'ruling'],
#  ['re-negotiation',
#   'best',
#   ':',
#   'deshmukh',
#   ';',
#   'lenders',
#   "'",
#   'sos',
#   'to',
#   'centre'],
#  ['samsung', 'says', 'hello', 'to', 'cellular', 'unit', 'in', 'india'],
#  ['govt', 'lifts', 'port-linked', 'curbs', 'on', 'imports'],
#  ['ril', 'plans', 'to', 'mop', 'up', 'to', 'rs', '1', ';', '000cr'],
#  ['eicher', 'crashes', 'into', 'the', 'red', ';', 'to', 'cut', '200', 'jobs'],
#  ['indo', 'rama', 'posts', 'rs18cr', 'net'],
#  ['jet', ';', 'sahara', 'to', 'wait', '&', 'watch'],
#  ['auto', 'body', 'drives', 'in', 'new', 'classification', 'norms'],
#  ['are', 'us', '64', "'", 's', 'sunny', 'days', 'over', '?'],
#  ['dpc', 'may', 'contest', 'merc', 'jurisdiction'],
#  ['brave', 'new', 'biotech'],
#  ['the', 'beginning', 'of', 'salary', 'fall', '?'],
#  ['dgca', 'proposal', 'on', 'airfares', 'upsets', 'airlines'],
#  ['zee', 'and', 'the', 'art', 'of', 'programming', 'a', 'turnaround'],
#  ['learn', 'to', 'check', 'a', 'right', 'isi', 'mark'],
#  ['mseb', 'plans', 'an', 'acid', 'test', 'for', 'dpc', 'phase', 'ii'],
#  ['ashok', 'leyland', 'to', 'cut', 'jobs', ';', 'divisions'],
#  ["'",
#   'fixing',
#   'of',
#   'former',
#   'dse',
#   'ed',
#   "sodhi's",
#   'pay',
#   'package',
#   'lacks',
#   'transparency',
#   "'"],
#  ['dd', 'metro', 'is', 'up', 'for', 'grabs'],
#  ['dpc',
#   'signals',
#   'climb',
#   'down',
#   ';',
#   'sees',
#   'scope',
#   'to',
#   'cut',
#   'power',
#   'tariffs'],
#  ['satyam', 'says', 'it', 'may', 'face', 'manpower', 'problems'],
#  ['m',
#   '&',
#   'm',
#   'net',
#   'dips',
#   '54',
#   '%',
#   ';',
#   'to',
#   'keep',
#   'payout',
#   'at',
#   '55',
#   '%'],
#  ['better',
#   'late',
#   'than',
#   'never',
#   ';',
#   'nid',
#   'takes',
#   'on',
#   'a',
#   'new',
#   'design'],
#  ['sensex',
#   'stays',
#   'in',
#   'the',
#   'bull',
#   'zone',
#   ';',
#   'gains',
#   '60',
#   'points'],
#  ['sail', 'cuts', 'losses', 'by', 'half'],
#  ['driving', 'at', 'a', 'low', 'gear'],
#  ['beware', ';', 'the', 'snoopware', 'is', 'watching', 'you', '!'],
#  ['ia',
#   'divestment',
#   'may',
#   'be',
#   'a',
#   'roadblock',
#   'for',
#   'new',
#   'players',
#   'in',
#   'domestic',
#   'skies'],
#  ['car', 'sales', 'drop', '15', '%', 'in', 'april'],
#  ['ia',
#   'divestment',
#   'may',
#   'be',
#   'a',
#   'roadblock',
#   'for',
#   'new',
#   'players',
#   'in',
#   'domestic',
#   'skies'],
#  ['slowdown',
#   'hits',
#   'idbi',
#   ';',
#   'net',
#   'down',
#   '27.3',
#   '%',
#   'to',
#   'rs',
#   '691',
#   'cr'],
#  ['car', 'sales', 'drop', '15', '%', 'in', 'april'],
#  ['korn',
#   '/',
#   'ferry',
#   'to',
#   'search',
#   'for',
#   'dewang',
#   "mehta's",
#   'successors'],
#  ['korn',
#   '/',
#   'ferry',
#   'to',
#   'search',
#   'for',
#   'dewang',
#   "mehta's",
#   'successors'],
#  ['media',
#   ';',
#   'publications',
#   'promise',
#   'big',
#   'ad',
#   'spend',
#   'in',
#   'future'],
#  ['centre', 'unveils', 'bailout', 'package', 'for', 'madhavpura', 'bank'],
#  ['goodyear', 'rolls', 'out', 'tubeless', 'radial', 'tyres', 'in', 'india'],
#  ['nationwide', 'bank', 'strike', 'on', 'july', '4'],
#  ['mtnl', 'to', 'execute', 'cdma-wll', 'service', 'soon'],
#  ['trai', 'moots', 'allotment', 'of', 'codes', 'to', 'std', 'operators'],
#  ['bharti-singtel', 'jv', 'gets', 'loi', 'for', 'std', 'services'],
#  ['hc',
#   'restrains',
#   'govt',
#   'from',
#   'recovering',
#   "whisky's",
#   'price',
#   'difference'],
#  ['ia', 'to', 'review', 'flexi-fare', 'for', 'july-august'],
#  ['m',
#   '&',
#   'm',
#   'to',
#   'don',
#   'sportier',
#   'image',
#   ';',
#   'import',
#   'lotus',
#   'elise'],
#  ['bnp', 'paribas', 'may', 'acquire', 'an', 'indian', 'bank'],
#  ['crude', 'oil', 'production', 'skids', 'this', 'fiscal'],
#  ['govt',
#   'nod',
#   'for',
#   '13',
#   'pvt',
#   'parties',
#   'to',
#   'start',
#   'air',
#   'services'],
#  ['bsp',
#   'mp',
#   'charges',
#   'sebi',
#   'with',
#   "'",
#   'unwillingness',
#   "'",
#   'to',
#   'probe',
#   'rpl'],
#  ['fipb', 'clears', '32', 'fdi', 'proposals', 'worth', 'rs', '477', 'cr'],
#  ['lg', 'launches', 'healthcare', 'products'],
#  ['jaswant', 'holds', 'talks', 'on', 'bilateral', 'trade', ';', 'wto'],
#  ['no', 'proposal', 'to', 'enhance', 'petro', 'prices', ':', 'naik'],
#  ['sabeer', "bhatia's", "'", 'arzoo', "'", 'remains', 'unfulfilled'],
#  ['ranbaxy', 'sues', 'wilmark', 'for', 'using', 'similar', 'brand', 'name'],
#  ['dumped', 'dd', 'goes', 'for', 'rebid', 'of', 'slots'],
#  ['8', 'global', 'fis', 'join', "rpl's", '$', '500', 'm', 'loan', 'syndicate'],
#  ['jaswant', 'holds', 'talks', 'on', 'bilateral', 'trade', ';', 'wto'],
#  ['yamaha', 'appeals', 'against', 'fake', 'bikes', 'from', 'china'],
#  ['satyam', 'wary', 'of', 'growth', 'despite', 'robust', '2000-01'],
#  ['a-i', 'to', 'present', 'profitable', 'budget', 'for', '2001-02'],
#  ['software', 'parks', 'question', "satyam's", 'export', 'revenues'],
#  ['indian', 'american', 'in', 'disney', 'interactive', 'top', 'post'],
#  ['us', 'lends', 'ears', 'to', 'india', 'on', 'steel'],
#  ['rupee', 'ends', 'mildly', 'higher', 'against', 'dollar'],
#  ['en-masse', 'transfers', 'at', "balco's", 'delhi', 'office'],
#  ['six-point', 'strategy', 'to', 'speed', 'up', 'fdi', 'flows'],
#  ['i-t',
#   'hauls',
#   'up',
#   'firms',
#   ';',
#   'banks',
#   ';',
#   'fis',
#   'for',
#   'investing',
#   'in',
#   'tax-free',
#   'bonds'],
#  ['dpc', ';', 'mseb', 'to', 'fight', 'legal', 'battle'],
#  ['tcs', 'sets', 'up', 'asia-pacific', 'hq', 'in', 'singapore'],
#  ['imports', 'of', '300', 'sensitive', 'items', 'down', '11', '%'],
#  ['rpl', 'gets', 'cabinet', 'nod', 'to', 'dilute', 'reliance', 'shares'],
#  ['daewoo', 'reworks', 'marketing', 'strategy'],
#  ['enron', 'debacle', 'would', 'dampen', 'flow', 'of', 'fdi', 'into', 'india'],
#  ['nissan',
#   ';',
#   'mitsubishi',
#   'cut',
#   'global',
#   'vehicle',
#   'output',
#   'in',
#   'may'],
#  ['strategic',
#   'partner',
#   'may',
#   'get',
#   '5',
#   'directors',
#   'on',
#   'a-i',
#   'board'],
#  ['duty', 'drawback', 'rates', 'partially', 'rolled', 'back'],
#  ['no', 'distress', 'export', 'of', 'diesel', ':', 'ram', 'naik'],
#  ['world', 'bank', 'announces', '$', '913.8', 'million', 'aid', 'to', 'india'],
#  ['summertime', ';', 'and', 'iim', 'on', 'easy', 'street'],
#  ['tatas',
#   ';',
#   'sia',
#   ';',
#   'videocon',
#   ';',
#   'cases',
#   'referred',
#   'to',
#   'cabinet'],
#  ['hll', 'unveils', 'action-plan', 'for', 'food', 'revolution'],
#  ['subsidies', 'on', 'lpg', ';', 'kerosene', 'to', 'stay', ':', 'naik'],
#  ['prasar', 'bharati', 'seeks', 'agency', 'to', 'monitor', 'dd', 'reach'],
#  ['siemens', "'", 'buy-back', 'offer', 'to', 'begin', 'from', 'june', '25'],
#  ['china-russia', 'trade', 'hits', 'record', 'level'],
#  ['meet',
#   'to',
#   'finalise',
#   'madhavpura',
#   'revival',
#   'plan',
#   'from',
#   'june',
#   '25'],
#  ["satellite's", 'corrupt', 'cops', 'still', 'on', 'the', 'run'],
#  ['us', 'loses', 'key', 'wto', 'case', 'to', 'eu'],
#  ['forex',
#   'reserves',
#   'swell',
#   'by',
#   '$',
#   '153',
#   'm',
#   'to',
#   '$',
#   '43',
#   ';',
#   '160',
#   'm'],
#  ['gaz', 'de', 'france', 'to', 'hedge', "petronet's", 'risk'],
#  ['hdfc',
#   'to',
#   'buy',
#   '8',
#   '%',
#   'stake',
#   'in',
#   'positra',
#   'sez',
#   'for',
#   'rs',
#   '150',
#   'cr'],
#  ['media', 'lab', 'takes', 'it', 'to', 'the', 'have-nots'],
#  ['lord', 'paul', 'against', 'vested', 'interests', 'in', 'open', 'trade'],
#  ['without',
#   'reforms',
#   'can',
#   'we',
#   'have',
#   'a',
#   'sustained',
#   'bull',
#   'run',
#   '?'],
#  ['desperately', 'seeking', 'disinvestment'],
#  ['global', 'oil', 'majors', 'queue', 'up', 'for', 'ibp', 'pie'],
#  ['balmer', 'lawrie', 'to', 'be', 'demerged'],
#  ['dolphin', 'gets', 'aggressive', ';', 'slashes', 'call', 'rate'],
#  ['a', 'cellular', 'giant', 'is', 'born'],
#  ["it's", 'official', ';', 'batata', ';', 'bpl', 'announce', 'merger'],
#  ['a-i', 'share', 'deal', 'to', 'boost', 'sell-off', 'price'],
#  ['hindujas', 'are', 'not', 'pulling', 'out', ':', 'shourie'],
#  ['panel', 'calls', 'for', 'freeing', 'agricultural', 'marketing'],
#  ['toontown', 'reaches', 'out', 'to', 'india'],
#  ['govt',
#   'package',
#   'to',
#   'face',
#   'difficulty',
#   'in',
#   'redeeming',
#   'us',
#   '-',
#   '64',
#   'fully'],
#  ['grasim', 'industries', ';', 'workers', 'reach', 'closure', 'agreement'],
#  ['dse',
#   'provides',
#   'liquidity',
#   'in',
#   'us',
#   '-',
#   '64',
#   'for',
#   'small',
#   'investors'],
#  ['price', 'rigging', 'needs', 'to', 'be', 'checked'],
#  ['pak',
#   'studying',
#   'response',
#   'to',
#   'indian',
#   'offer',
#   'to',
#   'reduce',
#   'tariffs'],
#  ['g', '-', '8', 'finance', 'ministers', 'hold', 'summit', 'in', 'rome'],
#  ['china', 'not', 'dumping', 'goods', 'into', 'india', ':', 'cii'],
#  ['fall',
#   'in',
#   'volumes',
#   'may',
#   'force',
#   'dse',
#   'to',
#   'merge',
#   'with',
#   'bse'],
#  ['telecom',
#   'm',
#   '&',
#   'a',
#   ':',
#   'small',
#   'firms',
#   'see',
#   'space',
#   'to',
#   'survive'],
#  ['making', 'the', 'mission', 'possible'],
#  ['make', 'uti', 'an', 'asset', 'management', 'firm'],
#  ['us', '-', '64', ':', 'paid', 'more', 'earned', 'less'],
#  ['godbole', 'panel', 'recommends', 'privatisation', 'of', 'mseb'],
#  ['us',
#   '-',
#   '64',
#   'crisis',
#   'not',
#   "'",
#   'disastrous',
#   "'",
#   ':',
#   'amfi',
#   'chief'],
#  ['strenghten', 'indo-pak', 'trade', 'ties', ':', 'cii'],
#  ['infosys',
#   'sees',
#   'rs',
#   '800',
#   'cr',
#   'profit',
#   'this',
#   'fiscal',
#   ';',
#   'q1',
#   'net',
#   'soars',
#   '56',
#   '%'],
#  ['distacom', 'to', 'sell', 'its', '49', '%', 'stake', 'in', 'spice'],
#  ['bpl', 'to', 'buy', 'out', 'france', 'telecom', 'in', 'batata'],
#  ['us', 'slowdown', 'takes', 'its', 'toll', 'on', 'infosys'],
#  ['indian',
#   'oil',
#   ';',
#   'reliance',
#   'among',
#   'forbes',
#   "'",
#   'international',
#   '500'],
#  ['npp', 'will', 'not', 'exempt', 'r', '&', 'd-savvy', 'from', 'dpco'],
#  ['bharti',
#   'cellular',
#   'reduces',
#   'airtime',
#   'tariff',
#   'for',
#   "'",
#   'magic',
#   "'"],
#  ['ongc', 'nod', 'for', 'increasing', 'production', 'in', 'major', 'fields'],
#  ['rupee', 'ends', 'barely', 'changed', 'against', 'dollar'],
#  ['essar', 'slashes', 'airtime', 'tariff', 'on', 'cash', 'card'],
#  ['dupont', 'on', 'expansion', 'drive', 'in', 'india'],
#  ['essel', 'sells', '50', 'lakh', 'zee', 'shares', 'to', 'us', 'investor'],
#  ['more', 'bad', 'news', 'on', 'growth', 'front'],
#  ['controls', 'on', 'sugar', 'industry', 'to', 'go', 'soon', ':', 'shanta'],
#  ['shourie', 'denies', 'favouring', 'tatas', 'in', 'air', 'india', 'bid'],
#  ['uti', 'package', 'likely', 'today', '?'],
#  ['dupont', 'on', 'expansion', 'drive', 'in', 'india'],
#  ['pak', "doesn't", 'click', 'with', 'indian', 'it', 'training', 'cos'],
#  ['maharaja', 'will', 'fly', 'chennai-hk', 'direct'],
#  ['investor', 'protection', 'fund', 'likely', 'by', 'next', 'week'],
#  ['hc', 'issues', 'contempt', 'notice', 'to', 'netware', 'infosys'],
#  ['biocon', ';', 'transcorp', 'in', 'technology', 'battle'],
#  ['govt', 'may', 'amend', 'act', 'to', 'allow', 'rbi', 'to', 'lower', 'slr'],
#  ['investors',
#   'urge',
#   'centre',
#   'to',
#   'intervene',
#   'in',
#   'us',
#   '-',
#   '64',
#   'scheme'],
#  ['wilful', 'defaulters', 'should', 'be', 'sent', 'to', 'jail', ':', 'sinha'],
#  ['jpc', ';', 'govt', 'set', 'to', 'train', 'guns', 'on', 'hfcl', ';', 'zee'],
#  ['berger',
#   ';',
#   'ici',
#   'form',
#   'jv',
#   'to',
#   'make',
#   'auto',
#   ';',
#   'ind',
#   'coatings'],
#  ['eli',
#   'lilly',
#   'to',
#   'make',
#   'india',
#   'global',
#   'bulk',
#   'drug',
#   'outsourcing',
#   'hub'],
#  ['rupee', 'stages', 'mild', 'rally', 'against', '$'],
#  ['guidelines', 'for', 'advisors', ';', 'bidders', 'for', 'disinvestment'],
#  ['sinha', 'confident', 'of', 'achieving', 'indirect', 'tax', 'target'],
#  ['uti',
#   'redemptions',
#   'at',
#   'rs',
#   '2',
#   ';',
#   '265',
#   'crore',
#   'in',
#   'june',
#   ':',
#   'amfi'],
#  ['skumars', "'", 'flip-flop', 'e-com', 'venture'],
#  ['improve', 'quality', 'to', 'boost', 'exports', ':', 'thai', 'minister'],
#  ['hc',
#   'orders',
#   'bajaj',
#   'auto',
#   'to',
#   'make',
#   '701',
#   'workers',
#   'permanent'],
#  ['b', '.', 'k', '.', 'modi', 'to', 'meet', 'fis', 'again', 'today'],
#  ['promoters',
#   "'",
#   'stake',
#   'in',
#   'zee',
#   'telefilms',
#   'down',
#   'to',
#   '59',
#   '%'],
#  ['murdoch', 'upbeat', 'on', 'indian', 'market'],
#  ['bengal', 'sets', 'up', 'panel', 'to', 'decide', 'on', 'fate', 'of', 'psus'],
#  ['sinha', 'meets', 'banks', ';', 'fis', 'to', 'tackle', 'slowdown'],
#  ['improve', 'quality', 'to', 'boost', 'exports', ':', 'thai', 'minister'],
#  ['sugar', 'industry', 'stands', 'to', 'gain', 'in', 'wto', 'regime'],
#  ['uti', 'to', 'get', 'bank', 'loan', 'for', 'equity', 'holding'],
#  ['divestment', 'norms', "won't", 'affect', 'morgan', 'stanely'],
#  ['hunt', 'for', 'nasscom', 'president', 'in', 'last', 'leg'],
#  ['fis', 'to', 'stay', 'away', 'from', 'modi', 'rubber', 'open', 'offer'],
#  ['brokers', 'meet', 'on', 'july', '17', 'to', 'chart', 'action', 'plan'],
#  ['indo-myanmar', 'border', 'trade', 'declining'],
#  ['militancy', 'reduces', 'poverty', 'in', 'kashmir'],
#  ['money', 'wise', 'brsensex', 'faces', 'a', 'roller', 'coaster'],
#  ['forex',
#   'reserves',
#   'swell',
#   'by',
#   '$',
#   '141',
#   'mn',
#   'to',
#   '$',
#   '43',
#   ';',
#   '596',
#   'mn'],
#  ['mphasis', 'shareholders', 'okay', 'equity', 'sale', 'to', 'chrysalis'],
#  ['financial', 'sector', 'reforms', 'jeopardise', 'economy'],
#  ['uti',
#   'board',
#   'fails',
#   'to',
#   'firm',
#   'up',
#   'exit',
#   'route',
#   'for',
#   'us',
#   '-',
#   '64'],
#  ['commemorative', 'coin', 'for', "beijing's", 'olympic', 'bid', 'success'],
#  ['transfer', 'pricing', 'rules', 'to', 'aid', 'higher', 'tax', 'collections'],
#  ['rs', '28', 'cr', 'citigroup', 'funding', 'for', 'daksh'],
#  ['fiis', 'net', 'buyers', 'in', 'equities', 'at', 'rs', '261.2', 'crore'],
#  ['uti',
#   'offers',
#   'limited',
#   'exit',
#   ';',
#   'to',
#   'announce',
#   'nav',
#   'from',
#   'jan'],
#  ['spice', 'in', 'talks', 'with', 'cellphone', 'majors', 'for', 'merger'],
#  ['nri', 'industrialists', 'optimistic', 'about', 'indo-pak', 'summit'],
#  ['indian', 'languages', 'to', 'bridge', 'digital', 'gulf'],
#  ['small', 'uti', 'investors', 'heave', 'a', 'sigh', 'of', 'relief'],
#  ['entreprenuer', ':', 'the', 'vanguard', 'of', 'growth'],
#  ['gdp', 'projected', 'to', 'grow', 'by', '6.3', '%', ':', 'cmie'],
#  ['rbi', 'governor', 'says', 'economy', 'is', 'in', 'good', 'shape'],
#  ['inflation', 'rises', 'to', '5.16', '%'],
#  ['active', 'govt', 'role', 'needed', 'to', 'tackle', 'fakes'],
#  ['textile', 'policy', 'envisages', 'export', 'target', 'of', '$', '50', 'b'],
#  ['fis', 'seek', 'rs', '45', 'crore', 'guarantee', 'from', 'modis'],
#  ["dpc's", 'lng', 'carrier', 'to', 'be', 'deployed', 'in', 'spot', 'market'],
#  ['nri', 'industrialists', 'optimistic', 'about', 'indo-pak', 'summit'],
#  ['maruti', 'to', 'invest', 'rs', '550', 'crore'],
#  ['fiis',
#   "'",
#   'stake',
#   'in',
#   'mrl',
#   'may',
#   'be',
#   'purnendu',
#   "chatterjee's",
#   'holding'],
#  ['lower',
#   'manufacturing',
#   'calls',
#   'for',
#   'vat',
#   ';',
#   'internal',
#   'competition'],
#  ['govt',
#   'for',
#   'amending',
#   'i-t',
#   'laws',
#   'to',
#   'tax',
#   'e-commerce',
#   'firms'],
#  ['somebody', 'errs', ';', 'others', 'pay', 'the', 'price'],
#  ['niit', 'not', 'to', 'cut', 'back', 'on', 'spending'],
#  ['banks', 'need', 'funds', 'to', 'become', 'technologically', 'competent'],
#  ['mp-based',
#   'companies',
#   'record',
#   '13',
#   '%',
#   'growth',
#   ':',
#   'cmie',
#   'report'],
#  ['it', 'companies', ':', 'will', 'q3', 'be', 'the', 'turning', 'point', '?'],
#  ['tisco', 'seeks', 'acquisition', 'opportunities', 'in', 'select', 'fields'],
#  ['dod', 'may', 'consider', 'liberalising', 'terms', 'for', 'ia', 'selloff'],
#  ['market', 'cool', 'to', 'agra', 'talks'],
#  ['ntpc', 'not', 'to', 'buy', 'enron', 'equity', ':', 'centre'],
#  ['j', '.', 'j', '.', 'irani', 'stresses', 'on', 'achieving', 'targets'],
#  ['govt',
#   'to',
#   'get',
#   'rs',
#   '1',
#   ';',
#   '486',
#   'cr',
#   'from',
#   '4th',
#   'cellular',
#   'slot'],
#  ['telco', 'among', 'top', '10', 'losers'],
#  ['rupee', 'gains', 'against', '$'],
#  ['us', '-', '64', ':', "it's", 'a', 'losing', 'game', 'for', 'investors'],
#  ['block', 'deals', 'in', 'limelight', 'in', 'listless', 'market'],
#  ['sc', 'allows', 'balco', 'plea', 'on', 'discrimination'],
#  ['strategic',
#   'sale',
#   'of',
#   'holdings',
#   'least',
#   'priority',
#   ':',
#   'uti',
#   'chief'],
#  ['relief', 'for', 'investors', 'with', '3', ';', '000', '+', 'units', 'soon'],
#  ['coca', 'cola', 'closes', '2', 'plants', 'in', 'mumbai', ';', 'pune'],
#  ['satellite-based', 'system', 'for', 'airports', 'soon'],
#  ['psu',
#   'bank',
#   'chiefs',
#   'meet',
#   'uti',
#   'chief',
#   'for',
#   'us',
#   '-',
#   '64',
#   'assistance'],
#  ['tyco', 'to', 'make', "b'lore", 'plant', 'global', 'sourcing', 'base'],
#  ['hll', 'eyes', 'organic', 'tea', 'segment'],
#  ['give', 'grants', 'to', 'poor', 'countries', ';', 'us', 'tells', 'wb'],
#  ['no', 'increase', 'in', 'bonus', 'of', 'policy-holders', ':', 'lic'],
#  ['hc', 'stops', 'govt', 'from', 'finalising', 'cellular', 'bids'],
#  ['saga', 'of', 'it-aided', 'design'],
#  ['states', 'may', 'fix', 'margin', 'for', 'pds', 'shops', ':', 'govt'],
#  ['insurance', 'claims', 'to', 'be', 'settled', 'in', '7', 'days'],
#  ['car', 'wars', ':', 'global', 'models', 'at', 'indian', 'prices'],
#  ['moet-hennessy', 'to', 'market', 'cognac', ';', 'champagne', 'in', 'india'],
#  ['mf', 'industry', 'grew', 'by', '46.49', '%', 'in', '1999-2000'],
#  ['auto', 'car', ';', 'two-wheeler', 'sales', 'up', 'in', 'june'],
#  ['bids', 'for', '4th', 'cellular', 'slot', 'received'],
#  ['hyundai', 'sonata', 'makes', 'its', 'debut'],
#  ['ketan', 'denies', 'foreign', 'bank', 'account', 'ownerships'],
#  ['siemens', 'q3', 'net', 'profit', 'down', '48.97', '%'],
#  ['pay', 'up', 'first', ';', 'fis', 'tell', 'modis'],
#  ['tisco', 'top', 'steel', 'maker', ';', 'q1', 'net', 'crashes', '79', '%'],
#  ['india', 'inc', 'pessimistic', 'on', 'industrial', 'recovery'],
#  ['ub', 'group', 'to', 'launch', 'flavoured', 'water'],
#  ['govt', 'targets', '$', '50', 'bn', 'textile', 'exports', 'by', '2010'],
#  ['mid-air', 'duel', 'over', "a-i's", 'future'],
#  ['after',
#   'a-i',
#   ';',
#   'maruti',
#   ';',
#   'hoc',
#   'to',
#   'be',
#   'divested',
#   ':',
#   'joshi'],
#  ['bse', 'sub-panel', 'to', 'oversee', 'corporatisation', 'process'],
#  ['business', 'bhailateralism'],
#  ['rupee', 'stages', 'smart', 'rally', 'against', 'dollar'],
#  ["bush's", 'wb', 'plan', 'will', 'hit', 'india'],
#  ['badla', 'operators', 'route', 'rs', '2', ';', '000', 'cr', 'to', 'mfs'],
#  ['vassal', 'blames', 'sebi', 'for', 'us', '-', '64', 'crisis'],
#  ['maruti', 'prices', 'to', 'go', 'up', 'soon'],
#  ['biotech', 'regulator', 'may', 'face', 'hurdle'],
#  ['bajaj', "'", 'eliminator', "'", 'hits', 'the', 'road'],
#  ['govt', 'may', 'raise', 'cess', 'on', 'petrol', ';', 'diesel'],
#  ['rbi', 'favours', 'greater', 'freedom', 'to', 'co-op', 'banks'],
#  ['rbi', 'foresees', 'higher', 'agri', 'growth', 'this', 'fiscal'],
#  ['govt',
#   'to',
#   'move',
#   'sc',
#   'over',
#   '4th',
#   'cellular',
#   'slot',
#   ':',
#   'paswan'],
#  ['top', 'uti', 'officials', 'charged', 'with', 'fraud'],
#  ['itc', 'net', 'up', '21', '%', 'at', 'rs', '301', 'crore', 'in', 'q1'],
#  ['forex',
#   'reserves',
#   'decline',
#   'by',
#   '$',
#   '37',
#   'mn',
#   'to',
#   '$',
#   '43',
#   ';',
#   '559',
#   'mn'],
#  ['tax', 'collections', 'plunge', '13', '%', 'in', 'q1'],
#  ['ipcl', 'net', 'down', '64', '%', 'to', 'rs', '12.67', 'cr', 'in', 'q1'],
#  ['rural', 'telesubscribers', 'get', 'a', 'cheap', 'deal'],
#  ['say', 'cheese', ';', 'desi', 'pizzas', 'for', 'rs', '20'],
#  ['sailing', 'through', 'gloom', 'time'],
#  ['money', 'wisebrlessons', 'from', 'us', '64', 'debacle'],
#  ['merrill', 'lynch', 'pays', 'for', 'playing', 'bull', 'during', 'boom'],
#  ['reliance', ';', 'dot', 'ink', 'basic', 'circles', 'pact'],
#  ['vsnl', 'venture', 'to', 'provide', 'services', 'in', 'nepal'],
#  ['cbi', 'arrests', 'subramanyam'],
#  ['fis',
#   'yet',
#   'to',
#   'finalise',
#   'participation',
#   'in',
#   "modi's",
#   'open',
#   'offer'],
#  ['bharti', 'moves', 'hc', ';', 'dot', 'to', 'follow'],
#  ['rising', 'fuel', 'costs', 'dent', "a-i's", 'bottomline'],
#  ['yashwant', 'should', 'quit', ';', 'demands', 'cpi', '(', 'm', ')'],
#  ['should', 'india', 'disinvest', 'kashmir', '?'],
#  ['us', 'slump', 'may', 'last', 'longer', 'than', 'expected'],
#  ['pc', 'sales', ':', 'no', 'revolution', 'in', 'sight'],
#  ['from', 'one', 'ikon', 'to', 'many', 'models'],
#  ['mbt', 'shelves', 'ipo', ';', 'plans', 'pvt', 'placement'],
#  ['digvijay', 'reviews', 'finance', "department's", 'functioning'],
#  ['boost', 'demand', 'to', 'revive', 'economy'],
#  ['will',
#   'they',
#   'smoke',
#   'the',
#   'pipe',
#   '(',
#   'line',
#   ')',
#   'of',
#   'peace',
#   '?'],
#  ['sebi',
#   'will',
#   'raise',
#   'issue',
#   'of',
#   'brokers',
#   'funding',
#   'with',
#   'rbi',
#   ';',
#   'says',
#   'mehta'],
#  ['bollywood', 'warms', 'up', 'to', 'india', 'inc', '.'],
#  ['exide', 'in', 'jv', 'with', 'austrian', 'firm'],
#  ['crude', 'production', 'dips', '7.5', '%', 'to', '2.48', 'mt', 'in', 'june'],
#  ['govt', 'awaits', 'hc', 'ruling'],
#  ['telco',
#   ';',
#   'm',
#   '&',
#   'm',
#   'drive',
#   'comm',
#   'vehicles',
#   'sales',
#   'down',
#   'in',
#   'q2'],
#  ['rupee', 'opens', 'slightly', 'weak', 'against', '$'],
#  ['power',
#   'grid',
#   'corporation',
#   'to',
#   'invest',
#   'rs',
#   '1',
#   ';',
#   '100',
#   'crores',
#   'in',
#   'telecom'],
#  ['brokers', 'go', 'on', 'one-day', 'strike'],
#  ['dragon', ';', 'tiger', 'of', 'china', 'eye', 'india'],
#  ['bharti-singtel', 'pulls', 'out', 'of', 'vsnl', 'bidding'],
#  ['if', 'software', 'becomes', 'free'],
#  ['rural',
#   'credit',
#   'likely',
#   'to',
#   'go',
#   'up',
#   'to',
#   'rs',
#   '86',
#   ';',
#   '000',
#   'crore',
#   ':',
#   'report'],
#  ['centre', 'to', 'chart', 'fresh', 'norms', 'for', 'ia', 'sell-off'],
#  ['uti', 'suspends', 'officials', 'under', 'cbi', 'investigation'],
#  ['multiple', 'zones', 'to', 'buy', 'back', 'mail.com', 'stake'],
#  ['stock', 'brokers', 'embark', 'on', 'nationwide', 'strike'],
#  ['india',
#   'scores',
#   'on',
#   'size',
#   ';',
#   'loses',
#   'on',
#   'red',
#   'tape',
#   'for',
#   'fdi'],
#  ['indian',
#   'households',
#   'ditch',
#   'stock',
#   'market',
#   'for',
#   'small',
#   'savings'],
#  ['ril',
#   'to',
#   'invest',
#   'rs',
#   '1',
#   ';',
#   '500',
#   'cr',
#   'in',
#   'oil',
#   'exploration'],
#  ['sebi', 'suspends', 'ace', 'stock', 'broker', 'nikhil', 'shah'],
#  ['action', 'initiated', 'against', 'bpl', ';', 'videocon'],
#  ['3',
#   '-',
#   'member',
#   'panel',
#   'to',
#   'probe',
#   "uti's",
#   'investment',
#   'decision'],
#  ['govt', 'may', 'mull', 'more', 'compensation', 'to', 'vsnl'],
#  ['govt',
#   'to',
#   'file',
#   'caveat',
#   'in',
#   'sc',
#   'tomorrow',
#   'on',
#   '4th',
#   'cellular',
#   'slot',
#   'issue'],
#  ["vsnl's", 'participation', 'in', 'cellular', 'bid', 'dismissed'],
#  ['disinvestment', 'commission', 'reconstituted'],
#  ['a-i', 'flights', 'to', 'hong', 'kong', ';', 'singapore', 'from', 'mumbai'],
#  ['modis', 'to', 'hive', 'off', 'tyre', 'business'],
#  ['videocon',
#   'withdraws',
#   'ia',
#   'bid',
#   ';',
#   'to',
#   'decide',
#   'shortly',
#   'on',
#   'vsnl'],
#  ['for', 'top', 'brass', "it's", 'simply', 'not', 'peanuts'],
#  ['bse', 'suspends', 'trading', 'in', 'dsq', 'software', 'from', 'july', '30'],
#  ['indian', 'tea', 'exports', 'hit', 'by', 'iran', 'ban'],
#  ['telco', 'losses', 'up'],
#  ['kawasaki', 'to', 'source', 'parts', 'from', 'bajaj'],
#  ['tarapore',
#   'mum',
#   'on',
#   'uti',
#   ';',
#   'seeks',
#   'stronger',
#   'regulatory',
#   'capability'],
#  ['vat',
#   'panels',
#   'to',
#   'probe',
#   'revenue',
#   'loss',
#   'due',
#   'to',
#   'vat',
#   'and',
#   'vat',
#   'on',
#   'services'],
#  ['sbi', ';', 'icici', 'bank', 'to', 'outsmart', 'others', 'in', '3', 'years'],
#  ['s', 'ramadorai', 'appointed', 'tata', 'tech', 'chief'],
#  ['specialty', ';', 'ranbaxy', 'to', 'call', 'it', 'a', 'day'],
#  ['hiten', "dalal's", 'arrest', 'deferred'],
#  ['hindujas', ';', 'sterlite', ';', 'csfb', 'issued', 'show-cause', 'notices'],
#  ['verdict', 'on', 'ketan', "parekh's", 'bail', 'plea', 'tomorrow'],
#  ['hll', 'net', 'rises', ';', 'to', 'pay', '250', '%'],
#  ['sbi', 'q1', 'net', 'rises', '26', '%', 'to', 'rs', '580', 'cr'],
#  ['samsung',
#   'india',
#   'h1',
#   'sales',
#   'up',
#   '38',
#   '%',
#   'at',
#   'rs',
#   '1',
#   ';',
#   '247cr'],
#  ['ibm', 'invests', '$', '10m', 'in', 'chrysalis'],
#  ['irda', 'warns', 'lic', ';', 'gic', 'on', 'uti', 'equity', 'exposure'],
#  ['states', 'to', 'pay', 'rs', '18', ';', '000cr', 'to', 'ntpc'],
#  ['tatas', 'sack', 'five', 'top', 'executives'],
#  ['uti',
#   'in',
#   'talks',
#   'with',
#   'private',
#   'banks',
#   'for',
#   'us',
#   '-',
#   '64',
#   'package'],
#  ['global', 'tele', 'arm', 'plans', 'techcompetency', 'centres'],
#  ['ril', 'to', 'acquire', 'oil', '&', 'gas', 'blocks', 'from', 'tullow'],
#  ['imf', ';', 'wb', 'under', 'pressure', 'to', 'simplify', 'loan', 'terms'],
#  ['purple', 'yogi', 'plans', 'makeover'],
#  ['equities', 'suffer', 'setback', 'on', 'selling', 'pressure'],
#  ['4th', 'round', 'cellular', 'bids', 'stays', 'on', 'hold'],
#  ['dunlop', 'sees', 'exodus', 'of', 'executives', 'in', 'last', '7', 'months'],
#  ['us', '-', '64', 'should', 'be', 'separated', 'from', 'other', 'schemes'],
#  ['court', 'rejects', 'ketan', "parekh's", 'bail', 'plea'],
#  ['shares', 'finish', 'lower', 'on', 'sustained', 'selling'],
#  ['icici', 'lombard', 'may', 'get', 'irda', 'nod', 'tomorrow'],
#  ['govt', 'seeks', "sebi's", 'opinion', 'on', 'hzl', 'delisting'],
#  ['govt', 'should', 'reduce', 'stake', 'in', 'idbi', ':', 'panel'],
#  ['gspc', 'stops', 'gas', 'supply', 'to', 'essar', 'steel', 'plant'],
#  ['cii', 'discusses', 'it', 'jvs', 'with', 'british', 'counterpart'],
#  ['cbi', 'interrogates', 'arvind', 'johari', 'of', 'cyberspace'],
#  ['former', 'bse', 'president', 'damani', 'is', 'dead'],
#  ['4', 'states', 'ready', 'to', 'buy', 'dpc', 'power'],
#  ['vsnl', ';', 'ibp', 'shareholders', "'", 'nod', 'likely', 'by', 'sept'],
#  ['rupee', 'weakens', 'slightly', 'against', 'the', 'dollar'],
#  ['apollo', 'tyres', 'net', 'profit', 'drops', 'by', '30', 'per', 'cent'],
#  ['carrier', 'net', 'plunges', '75', '%', 'to', 'rs', '2.55', 'cr'],
#  ['canada', '3000', 'to', 'begin', 'mumbai-toronto', 'flight'],
#  ['beer', 'battle', 'hots', 'up'],
#  ['sebi', 'begins', 'proceedings', 'against', 'broker', 'rahul', 'bajaj'],
#  ['business', 'between', 'india', ';', 'uk', 'exceeds', 'target'],
#  ['ec', 'launches', 'antitrust', 'proceedings', 'against', 'de', 'beers'],
#  ['nandas', 'enter', 'entertainment'],
#  ['devanhalli', 'airport', 'project', 'hits', 'roadblock'],
#  ['polaris', 'picks', 'up', '25', '%', 'stake', 'in', 'eternet', 'inc'],
#  ['uti', 'may', 'hike', 'redemption', 'limit', 'for', 'small', 'investors'],
#  ['govt', 'gives', 'nod', 'to', 'investor', 'protection', 'fund'],
#  ['lots', 'in', "'", 'store', "'", 'for', 'hitachi', 'in', 'india'],
#  ['royal', 'philips', 'to', 'buy', 'out', 'cg', 'glass'],
#  ['$', '589', 'm', 'wb', 'loan', 'to', 'upgrade', 'grand', 'trunk', 'road'],
#  ['indian', 'techies', 'do', 'it', 'again'],
#  ['vsnl', 'q1', 'net', 'down', '4.54', '%'],
#  ['icici', 'net', 'up', '13', '%'],
#  ['rpl', 'exports', '1.4', 'mt', 'of', 'petro', 'products', 'in', 'q1'],
#  ['month-end', 'pressure', 'weakens', 'rupee'],
#  ['bhel', 'bags', 'rs', '18', 'cr', 'supply', 'order', 'from', 'apgenco'],
#  ["it's",
#   'dull',
#   ';',
#   'but',
#   'head-hunters',
#   'find',
#   'work',
#   'in',
#   'finance',
#   ';',
#   'insurance'],
#  ['uti', 'to', 'be', 'split', '?'],
#  ['for', 'sensex', ';', 'worst', 'is', 'yet', 'to', 'come'],
#  ['retain', 'depb', 'export', 'incentive', 'scheme', ':', 'exporters'],
#  ['underinvoicing', 'hits', 'mmtc', 'edible', 'oil', 'imports'],
#  ['chinese', 'bikes', 'no', 'threat', 'to', 'india', ':', 'yamaha'],
#  ['duraline', 'to', 'hike', 'capacity', 'at', 'goa', 'plant'],
#  ['taxing', 'times', 'are', 'here', 'again'],
#  ['subramanyam', ';', '3', 'others', 'remanded', 'to', 'police', 'custody'],
#  ['philips', 'carbon', 'stops', 'operation'],
#  ['us', 'power', 'major', 'aes', 'to', 'quit', 'cesco'],
#  ['a-i', 'valuation', 'may', 'fall', 'way', 'below', 'expectations'],
#  ['psus', 'spearhead', 'growth', 'in', 'q1'],
#  ['four', 'states', 'not', 'to', 'buy', 'power', 'at', 'current', 'rates'],
#  ['ongc', 'board', 'clears', 'recast', 'plan'],
#  ['lnm', 'group', 'acquires', "romania's", 'sidex'],
#  ['godrej', 'q1', 'net', 'profit', 'at', 'rs', '11.18', 'cr'],
#  ["maharashtra's", 'offer', 'unrealistic', ':', 'dpc'],
#  ['chandra',
#   'open',
#   'to',
#   'diluting',
#   'stake',
#   'in',
#   'zee',
#   'below',
#   '50',
#   '%'],
#  ['bajaj', 'auto', 'q1', 'net', 'inches', 'up', 'to', 'rs', '121cr'],
#  ['ipa', 'moots', 'open', 'production', 'of', 'critical', 'patented', 'drugs'],
#  ['banks', ';', 'fis', 'owe', 'rs', '900', 'cr', 'in', 'taxes'],
#  ['hc',
#   'to',
#   'hear',
#   'pil',
#   'on',
#   'us',
#   '-',
#   '64',
#   'scheme',
#   'on',
#   'aug',
#   '1'],
#  ['more',
#   'investment',
#   'decision',
#   'making',
#   'powers',
#   'for',
#   'bsnl',
#   'mooted'],
#  ['cse', 'set', 'to', 'forge', 'pact', 'with', 'bse', 'for', 'derivatives'],
#  ['bob', 'offers', 'rs', '300', 'cr', 'to', 'uti'],
#  ['adobe', 'india', 'may', 'provide', 'software', 'to', 'state', 'govts'],
#  ['cse',
#   'worried',
#   'after',
#   'cancellation',
#   'of',
#   '14',
#   'mn',
#   'dsq',
#   'shares'],
#  ['oil', 'traders', "'", 'nationwide', 'stir', 'from', 'august', '20'],
#  ['haldia', 'petrochem', 'may', 'find', 'saviour'],
#  ['infosys', 'continues', 'to', 'top', 'growth', 'fund'],
#  ['tea', 'exports', 'may', 'fall', 'this', 'year'],
#  ['uti',
#   'grapples',
#   'with',
#   'potential',
#   'rs',
#   '1',
#   ';',
#   '700',
#   'cr',
#   'pay-out'],
#  ['land', 'compensation', 'only', 'on', 'market', 'value', ':', 'sc'],
#  ['top', 'business', 'magazine', 'to', 'cut', 'down', 'staff'],
#  ['subsidy', 'on', 'petro', 'products', 'rises'],
#  ['china', 'to', 'enter', 'wto', ';', 'more', 'challenges', 'for', 'india'],
#  ['aig',
#   'to',
#   'pick',
#   'up',
#   '12',
#   '%',
#   'stake',
#   'in',
#   'nagarjuna',
#   'refinery'],
#  ['cmc', ';', 'htl', 'sell-off', 'likely', 'by', 'august'],
#  ['bpl', ';', 'leowe', 'pact', 'sees', 'the', 'big', 'picture'],
#  ['drt', 'to', 'hear', 'boi', 'suits', 'against', "ketan's", 'cos'],
#  ['next', 'godbole', 'panel', 'meeting', 'may', 'be', 'cancelled'],
#  ['convergence', 'bill', 'to', 'be', 'tabled', 'this', 'session'],
#  ['revamp', ';', 'corporatisation', 'of', 'uti', 'demanded'],
#  ['bnp',
#   'paribas',
#   'to',
#   'buy',
#   'a',
#   'taiwanese',
#   'investment',
#   'trust',
#   ':',
#   'report'],
#  ['lohani', 'takes', 'over', 'as', 'new', 'itdc', 'chairman'],
#  ['cars',
#   ';',
#   'bikes',
#   'exports',
#   'up',
#   ';',
#   'scooters',
#   ';',
#   'muvs',
#   'down',
#   'in',
#   'q1'],
#  ['carrier', 'forms', 'panel', 'for', 'recast'],
#  ['rupee', 'weakens', 'slightly', 'against', '$'],
#  ['bajaj', 'capital', '3rd', 'most', 'admired', 'financial', 'firm'],
#  ['cbi', 'begins', 'probe', 'into', 'cyberspace', 'share', 'transaction'],
#  ['singhanias', 'up', 'stake', 'in', 'raymond', 'to', 'over', '30', '%'],
#  ['wockhardt', 'q2', 'net', 'up', '70.68', '%'],
#  ['fresh', 'bids', 'for', 'appointing', 'a-i', 'valuers', 'likely'],
#  ['body', 'language', 'speaks', 'louder', 'than', 'speech'],
#  ['govt', 'working', 'out', 'package', 'for', 'coal', 'india'],
#  ['raymond', 'forays', 'into', "women's", 'wear'],
#  ['modern', 'under-valued', 'by', 'anz', 'grindlays', ':', 'cag'],
#  ['raymond',
#   'earns',
#   'rs',
#   '1',
#   ';',
#   '150',
#   'cr',
#   'on',
#   'steel',
#   ';',
#   'cement',
#   'hive',
#   'off'],
#  ['reshuffle',
#   'to',
#   'give',
#   'professional',
#   'touch',
#   'to',
#   'itdc',
#   ':',
#   'kumar'],
#  ['rupee', 'ends', 'marginally', 'better'],
#  ['injunctions', 'fail', 'to', 'prevent', 'film', 'piracy'],
#  ['balco', 'kicks', 'off', 'vrs', ';', 'unions', 'appeal', 'for', 'rejection'],
#  ['no',
#   'move',
#   'to',
#   'raise',
#   'import',
#   'duty',
#   'on',
#   'cigarettes',
#   ':',
#   'sinha'],
#  ['imports',
#   'by',
#   'mmtc',
#   'under',
#   'cloud',
#   ';',
#   'cbi',
#   'probe',
#   'recommended'],
#  ["pm's", 'offer', 'to', 'quit', 'makes', 'short', 'impact', 'on', 'scrips'],
#  ['o', '.', 'p', '.', 'srivastava', 'takes', 'over', 'as', 'cbdt', 'chairman'],
#  ['zee', 'net', 'down', '13', '%', 'at', 'rs', '36.3', 'cr'],
#  ['govt', 'planning', 'regulator', 'for', 'coal', 'sector'],
#  ['table', 'phone', 'transcripts', 'of', 'uti', 'deals', ':', 'sena'],
#  ['titan', 'ind', 'records', 'rs', '14.6', 'cr', 'net', 'loss'],
#  ['hc', 'issues', 'fresh', 'contempt', 'notice', 'to', 'netware', 'infosys'],
#  ['agrani', 'selects', 'alcatel', 'satellite', 'system'],
#  ['maharashtra', 'okays', 'divestment', 'bill'],
#  ['uti', ':', 'more', 'than', 'what', 'meets', 'the', 'eye'],
#  ['bat', 'q2', 'profit', 'rises', '7.9', '%', 'on', 'europe', ';', 'asia'],
#  ['k', '.', 'j', '.', 'udeshi', 'is', 'rbi', 'executive', 'director'],
#  ['reliance', 'not', 'keen', 'on', "enron's", 'stake', 'in', 'dpc'],
#  ['ioc', 'to', 'set', 'up', 'lpg', 'dispensing', 'stations', ':', 'gangwar'],
#  ['uti', 'did', 'not', 'heed', 'to', "jpc's", 'warning', ':', 'sinha'],
#  ['us', 'exim', 'set', 'to', 'move', 'sc', 'on', 'dabhol', 'row'],
#  ['govt', 'faces', 'criticism', 'over', 'bail-outs'],
#  ['govt', 'okays', 'rs', '1', ';', '000', 'cr', 'bail-out', 'for', 'ifci'],
#  ['can', 'fin', 'posts', '28', '%', 'rise', 'in', 'profit'],
#  ['lic', 'picks', 'up', '9', '%', 'stake', 'in', 'obc', 'from', 'market'],
#  ['electronics', 'exports', 'jump', '72.5', '%', '2000-01'],
#  ['indo-pak', 'sugar', 'trade', 'dispute', 'erupts', 'again'],
#  ['committee', 'asks', 'govt', 'to', 'withdraw', 'tot'],
#  ['rupee', 'rock', 'steady', 'against', '$'],
#  ["sbi's", 'fraud', 'cases', 'amount', 'to', 'rs', '269.15', 'cr'],
#  ['uti', 'readies', 'war', 'chest', 'for', 'us', '-', '64', 'redemptions'],
#  ['exports',
#   'dip',
#   '5',
#   '%',
#   ';',
#   'trade',
#   'deficit',
#   'widens',
#   'by',
#   '34',
#   '%'],
#  ['tvs', 'suzuki', 'net', 'skids', '46', 'per', 'cent'],
#  ['icra', 'to', 'unveil', 'corp', 'governance', 'ratings', 'for', 'india'],
#  ["'", 'uti', 'participated', 'in', "rpl's", 'gdr', 'offer', "'"],
#  ['birla', 'century', 'net', 'down', '18.98', '%', 'in', 'q1'],
#  ['maruti', 'sales', 'up', '12', '%', 'in', 'july'],
#  ['single', 'rate', 'vat', 'may', 'boost', 'economy'],
#  ['icici', 'lombard', 'get', 'nod', 'from', 'irda'],
#  ['bob', 'to', 'tie', 'up', 'with', 'amc', 'for', 'life', 'insurance'],
#  ['cbi', 'asks', 'sebi', 'to', 'take', 'action', 'against', 'ed'],
#  ['industrial', 'slowdown', 'will', 'lead', 'to', 'recession'],
#  ['bharti', 'offers', 'rs', '258', 'cr', 'down', 'payment'],
#  ['wipro', 'sharpens', 'its', 'focus', 'on', 'embedded', 'software'],
#  ['dip', 'in', 'exports', 'due', 'to', 'international', 'slowdown'],
#  ['zen', ';', 'wagonr', 'drive', 'up', 'mul', 'sales'],
#  ['firm', 'garners', 'rs', '20', 'cr', 'in', 'german', 'fair'],
#  ['rupee', 'strengthens', 'further', 'against', '$'],
#  ['uti', 'reserves', 'turn', 'negative'],
#  ['arunachal', 'to', 'decentralise', 'tea', 'cultivation'],
#  ['videocon', 'may', 'sell', 'stake', 'in', 'ravva', 'venture'],
#  ['nine', 'more', 'psus', 'empanelled', 'for', 'divestment'],
#  ['german', 'bank', 'to', 'credit', 'power', ';', 'telecom', 'projects'],
#  ['general', 'motors', 'to', 'up', 'investment', 'in', 'india'],
#  ['indo-china', 'trade', 'to', 'get', 'a', 'boost'],
#  ['b', '.', 'muthuraman', 'is', 'new', 'tisco', 'md'],
#  ['lukewarm', 'response', 'to', 'uti', 'repurchase'],
#  ['vrs', 'for', 'central', 'govt', 'employees', 'soon', ':', 'shourie'],
#  ['indian', 'beer', 'wins', 'international', 'acclaim'],
#  ['cse', 'may', 'suspend', 'trading', 'of', 'dsq', 'software'],
#  ['bajaj', "auto's", 'vrs', 'gets', 'lukewarm', 'response'],
#  ['us', 'bankers', 'follow', 'shariah', 'to', 'strike', 'gold'],
#  ['cii', 'delegates', 'meet', 'us', 'officials', 'on', 'steel'],
#  ['karnik', 'looks', 'to', 'rebuild', 'nasscom'],
#  ['uti', 'crisis', ':', 'as', 'usual', ';', 'public', 'pays', 'the', 'price'],
#  ['anti-dumping', 'duties', 'on', 'theophylline', ';', 'caffeine', 'import'],
#  ['aes', 'pullout', "won't", 'affect', 'privatisation', ':', 'prabhu'],
#  ['now', ';', 'a', 'bentley', 'car', 'for', 'rs', '1', 'cr'],
#  ['uti', 'chief', 'promises', 'a', 'cleanup', 'job'],
#  ['cancelling',
#   'dpc',
#   'phase-i',
#   '&',
#   'revival',
#   'of',
#   'phase-ii',
#   'a',
#   'mistake'],
#  ['mrtpc', 'gives', 'clean', 'chit', 'to', 'daewoo'],
#  ['financial',
#   'sector',
#   'facing',
#   'crisis',
#   'of',
#   'confidence',
#   ':',
#   'vittal'],
#  ['bank',
#   'of',
#   'india',
#   'to',
#   'open',
#   'branches',
#   'in',
#   'china',
#   ';',
#   'vietnam'],
#  ['uti',
#   'receives',
#   'applications',
#   'for',
#   'repurchases',
#   'of',
#   '2.22',
#   'crore',
#   'units'],
#  ['india',
#   'has',
#   'potential',
#   'to',
#   'garner',
#   '$',
#   '100',
#   'bn',
#   'fdi',
#   'in',
#   '5',
#   'yrs'],
#  ['equities', 'rise', 'further', 'smartly', 'at', 'nse'],
#  ['singling', 'rbi', 'nominees', 'not', 'appropriate'],
#  ['kyoto', 'enjoys', 'backing', 'of', 'g', '-', '77', 'nations'],
#  ['petronet', 'seals', 'lng', 'chain', ';', 'inks', 'gas', 'sale', 'mous'],
#  ['closure', 'of', 'psus', 'only', 'last', 'resort', ':', 'govt'],
#  ['china', 'lifts', 'restrictions', 'on', 'pvt', 'enterprises'],
#  ['sony', 'gets', '$', '808', 'mn', 'credit', 'line'],
#  ['govt', '.', 'allays', 'fear', 'of', 'inflation'],
#  ['aes', 'pulls', 'out', 'from', 'orissa', ';', 'crisis', 'galore'],
#  ['ifci', 'to', 'enquire', 'modern', 'syntex', 'accounts'],
#  ['sahara', 'to', 'tie', 'up', 'with', 'foreign', 'airline'],
#  ['bhel', 'bags', 'rs', '10', 'cr', 'order', 'from', 'ongc'],
#  ['my', 'resignation', 'will', 'not', 'help', ':', 'sinha'],
#  ['uti', 'may', 'dig', 'into', 'reserve', 'fund'],
#  ['mps', 'just', 'love', 'bombay', 'high'],
#  ['sensex', 'recovers', 'by', '2.27', '%', 'over', 'last', 'week'],
#  ['sinha', 'rules', 'out', 'resignation', 'over', 'uti', 'muddle'],
#  ['data', 'storage', 'to', 'dominate', 'it', 'spending'],
#  ['uti', 'firm', 'on', 'strategic', 'sale', 'in', 'dud', 'firms'],
#  ['air', 'nz', 'deal', 'forcing', 'sia', 'to', 'rethink', 'over', 'a-i'],
#  ['ulip', 'keeping', 'uti', 'flag', 'high'],
#  ['uti', 'may', 'suspend', 'us', '-', '64', 'sales', 'indefinitely'],
#  ['former', 'wiproites', 'make', 'it', 'big', 'in', 'the', 'techie', 'world'],
#  ['cyberspace', 'was', 'a', 'wrong', 'investment', 'decision', ':', 'sinha'],
#  ['potential', 'to', 'tap', '$', '100', 'bn', 'fdi', 'in', '5', 'yrs'],
#  ['itc', 'open', 'to', 'm', '&', 'a', 'in', 'related', 'areas'],
#  ['hdfc', 'standard', 'life', 'to', 'break', 'even', 'after', '5', 'years'],
#  ['itc', 'chairman', 'against', 'bat', 'increasing', 'stake', 'in', 'vst'],
#  ['wll', 'mobile', 'phones', 'in', 'punjab', 'by', 'march', '2002'],
#  ['how', 'to', 'save', 'dabhol'],
#  ['sbi', 'forex', 'profit', 'on', 'the', 'downswing'],
#  ['ioc', 'hikes', 'servo', 'prices'],
#  ['voltas', 'exonerated', 'from', 'unfair', 'trade', 'charges'],
#  ['hpcl', 'to', 'complete', 'bhatinda', 'refinery', 'by', 'dec', '2005'],
#  ['fiiss',
#   '&',
#   'mfs',
#   'operated',
#   'in',
#   'contrast',
#   'during',
#   'july',
#   ':',
#   'sebi'],
#  ['will', 'kiran', 'karnik', 'succeed', '?'],
#  ['bharti', 'initiates', 'talks', 'for', 'rs', '3000', 'cr', 'debt'],
#  ['b2b',
#   'transaction',
#   'volumes',
#   'to',
#   'touch',
#   'rs',
#   '51',
#   ';',
#   '000',
#   'cr'],
#  ['cse', 'board', 'to', 'discuss', 'dsq', 'suspension', 'on', 'tuesday'],
#  ['face', 'offbrthe', 'silver', 'lining', 'in', 'hcl'],
#  ['we', 'were', 'forced', 'to', 'rescind', 'the', 'ppa', ':', 'mseb'],
#  ['niit', 'to', 'add', '2', 'more', 'sbus', 'in', 'retail', ';', 'transport'],
#  ['regulatory', 'framework', 'must', 'for', 'media', 'industry'],
#  ['tough',
#   'time',
#   'for',
#   'consumer',
#   'durables',
#   'firms',
#   ';',
#   'warns',
#   'icra'],
#  ['cyberspace', 'scam', 'gets', 'financiers', 'trapped'],
#  ['bpl',
#   'appoints',
#   'i-sec',
#   'to',
#   'sell',
#   'off',
#   'maharashtra',
#   'cellular',
#   'licence'],
#  ['pharma', 'growth', 'plans', 'enchant', 'industry', 'analysts'],
#  ['a-i', 'earns', 'rs', '245', 'cr', 'via', 'seat', 'sharing'],
#  ['telco',
#   ';',
#   'bajaj',
#   ';',
#   'm',
#   '&',
#   'm',
#   'forsee',
#   'higher',
#   'growth',
#   'in',
#   'net',
#   'profit'],
#  ['vsnl', 'notified', 'vrs', 'for', 'employees'],
#  ['parliament', 'approves', 'repeal', 'of', 'banking', 'companies', 'act'],
#  ['anti-dumping',
#   'case',
#   'against',
#   'porcelain',
#   'tile',
#   'import',
#   'from',
#   'china'],
#  ['ford', 'reduces', 'cost', 'of', 'ownership'],
#  ['crompton', 'greaves', 'recasts', 'to', 'come', 'out', 'of', 'red'],
#  ['tatas', 'file', 'fir', 'against', 'dilip', 'pendse', ';', '5', 'others'],
#  ['india',
#   'to',
#   'press',
#   'for',
#   "'",
#   'limited',
#   "'",
#   'agenda',
#   'for',
#   'wto',
#   'talks'],
#  ['tata', ';', 'hughes', 'exploring', 'telecoms', 'tie-up'],
#  ['indian',
#   'firms',
#   'invited',
#   'to',
#   'set',
#   'up',
#   'units',
#   'in',
#   "china's",
#   'sezs'],
#  ['no', 'proposal', 'to', 'divest', 'sail', ':', 'govt'],
#  ['tvs-suzuki', 'reports', '4', '%', 'down', 'in', 'july', 'sales'],
#  ['dd', 'opens', 'fresh', 'bidding', 'for', 'metro', 'primetime'],
#  ['bifr', 'asks', 'torrent', 'to', 'sort', 'differences', 'with', 'creditors'],
#  ['sia', 'has', 'not', 'sought', '49', '%', 'stake', 'in', 'a-i'],
#  ['honda', 'launches', "'", 'activa', "'", 'in', 'delhi'],
#  ['nigeria', 'for', 'technological', 'corp', 'with', 'india'],
#  ['fieo', 'weclomes', "sbi's", 'move', 'to', 'cut', 'plr'],
#  ['nse', 'expels', 'ashoka', 'industrial', 'resources'],
#  ['maruti', 'hikes', 'car', 'prices', 'from', 'today'],
#  ['cvc',
#   'orders',
#   're-tender',
#   'of',
#   'rs',
#   '1',
#   ';',
#   '000',
#   'crore',
#   'dot',
#   'contract'],
#  ['sc', 'transfers', 'enron', 'issue', 'to', 'bombay', 'hc'],
#  ['no', 'differences', 'over', 'ia', ';', 'a-i', 'divestment', ':', 'yadav'],
#  ['catch', "'", 'em', 'young', ':', 'kids', 'as', 'consumers'],
#  ['thermax', 'announces', 'vrs', 'for', 'employees'],
#  ['pcb', 'pulled', 'up', 'for', 'not', 'taking', 'action', 'against', 'eil'],
#  ["enron's", 'dpc', "'", 'extremely', 'pleased', "'", 'with', 'sc', 'ruling'],
#  ['india', ';', 'austria', 'sign', 'double', 'taxation', 'treaty'],
#  ['gartner',
#   'upbeat',
#   'in',
#   'face',
#   'of',
#   "'",
#   'gloomy',
#   ';',
#   'doomy',
#   "'",
#   'it',
#   'mart'],
#  ['jalan', 'declines', 'to', 'comment', 'on', 'ifci', 'bailout'],
#  ['godbole', 'panel', 'report', 'applicable', 'to', 'reliance', 'power'],
#  ['china', 'to', 'revamp', 'economy', 'ahead', 'of', 'wto', 'entry'],
#  ['jk', 'industries', 'to', 'delist', 'from', 'delhi', 'bourse'],
#  ['wheat', 'exports', 'hit', 'new', 'lows', 'despite', 'demand', 'rise'],
#  ['raymond', 'to', 'acquire', 'hindustan', 'gas', 'arm'],
#  ['former', 'uti', 'chief', 'subramanyam', 'gets', 'bail'],
#  ['favouring', 'wireless', 'users', 'causes', 'rs', '24', 'cr', 'loss'],
#  ['govt', 'to', 'give', 'ifci', 'rs', '400', 'cr'],
#  ['sensex', 'slides', 'by', '11', 'points'],
#  ['s', '&', 'p', 'downgrade', 'seen', 'to', 'have', 'little', 'impact'],
#  ['dpc', 'warns', 'mseb', 'on', 'information', 'to', 'prayas'],
#  ['prices', 'of', '3', 'bulk', 'drugs', 'slashed'],
#  ['strength', 'of', 'direct', 'marketing'],
#  ['tatas', 'file', 'fir', 'against', 'dilip', 'pendse', ';', '5', 'others'],
#  ['cement', 'sales', ';', 'production', 'dip', 'in', 'july'],
#  ['gross', 'fiscal', 'deficit', 'soars', 'to', 'rs', '42', ';', '000', 'cr'],
#  ['rupee', 'steady', 'against', 'us', 'dollar'],
#  ['$', '78', 'bn', 'required', 'to', 'improve', 'tele-density', ':', 'paswan'],
#  ['govt', 'may', 'lower', 'bank', 'guarantee', 'for', 'ibp'],
#  ['india', 'proposes', 'changes', 'in', 'wto', 'subsidies', 'pact'],
#  ['bhel', 'bags', 'rs', '280', 'crore', 'order', 'from', 'us'],
#  ['govt', 'may', 'agree', 'to', 'reduce', 'stake', 'in', 'boi'],
#  ['india', 'to', 'take', 'up', 'wto', 'issues', 'with', 'ustr'],
#  ['pnb', 'to', 'extend', 'rs', '300-400', 'cr', 'to', 'uti', 'at', 'sub-plr'],
#  ['govt', 'to', 'issue', 'norms', 'for', 'diagnostic', 'labs'],
#  ['govt', 'clears', 'fdi', 'proposals', 'worth', 'rs', '980', 'cr'],
#  ['telecom', 'deals', 'spearhead', 'm', '&', 'a', 'activity'],
#  ['govt', 'to', 'allow', 'more', 'bilateral', 'flights', 'from', 'kochi'],
#  ['us', 'allows', 'duty-free', 'access', 'to', '42', 'indian', 'goods'],
#  ['honda', 'to', 'export', '2', '-', 'wheelers', 'from', 'india'],
#  ["idbi's", 'finances', 'under', 'spotlight'],
#  ['mid-sized', 'car', 'segment', 'fails', 'to', 'keep', 'promise'],
#  ['s', '&', "p's", 'downgrading', 'attracts', 'mixed', 'reaction'],
#  ['dpc', 'charges', 'power', 'regulator', 'with', 'bias'],
#  ['srichakra', 'to', 'lure', 'young', 'minds', 'with', 'colourful', 'tyres'],
#  ['s', '&', 'p', 'downgrade', 'will', 'affect', 'fdi', ';', 'divestment'],
#  ['bp',
#   'amoco',
#   'told',
#   'to',
#   'pay',
#   'rs',
#   '350',
#   'per',
#   'share',
#   'for',
#   'castrol',
#   'stake'],
#  ['sia', 'can', 'raise', 'stake', 'in', 'a-i', 'post-selloff'],
#  ["it's", 'reality', 'check', 'at', 'entermedia'],
#  ['lock-in', 'period', 'for', 'hughes', 'promoters', 'extended'],
#  ['build', 'customer', 'relationships', ';', 'not', 'sales'],
#  ['satnam', 'to', 'offer', 'ready-to-cook', 'products'],
#  ['investors', 'trust', 'analysts', ';', 'but', 'doubts', 'remain'],
#  ['indo', 'rama', 'keen', 'to', 'invest', 'in', 'butibori', 'plant'],
#  ['dalmia', 'welcomes', 'bp', "amoco's", 'offer', 'for', 'castrol', 'stake'],
#  ['dabhol', 'examining', 'customs', 'duty', 'notice'],
#  ['mills', 'to', 'produce', 'sugar', ';', 'electricity', 'too'],
#  ["moody's", 'slashes', 'india', 'outlook'],
#  ['evangelists', 'to', 'fud-ge', "developer's", 'act'],
#  ['govt', 'headhunters', 'do', 'little', 'placement'],
#  ["it's", 'reality', 'check', 'at', 'entermedia'],
#  ['rating', 'agencies', 'wrong', ':', 'sinha'],
#  ['sinha', 'allays', 'fear', 'of', 'rupee', 'fall'],
#  ['centre', 'not', 'to', 'buy', 'enron', 'holding', 'in', 'dpc'],
#  ['govt', 'to', 'allow', 'more', 'bilateral', 'flights', 'from', 'kochi'],
#  ["dabhol's", '$', '1', 'bn', 'offer', 'too', 'costly', ';', 'says', 'mseb'],
#  ['enron', 'offers', 'to', 'sell', 'stake', 'at', 'cost'],
#  ['slowdown', 'hits', 'car', 'sales'],
#  ['star', 'picks', 'up', 'majority', 'stake', 'in', 'vijay', 'tv'],
#  ['railtel',
#   'corp',
#   'to',
#   'invest',
#   'rs',
#   '700',
#   'cr',
#   'in',
#   'ofc',
#   'network'],
#  ['s', '&', 'p', 'lowers', 'rating', 'outlook', 'for', 'banks'],
#  ['rupee', 'eases', 'marginal', 'ground', 'against', '$'],
#  ['dabhol', 'examining', 'customs', 'duty', 'notice'],
#  ['fdi', 'not', 'up', 'to', 'expectations', ':', 'maran'],
#  ['germany', 'switching', 'over', 'from', 'dm', 'to', 'euro'],
#  ['india', 'called', 'for', 'wto', 'agenda', 'talks'],
#  ['nasscom', 'to', 'promote', 'it', 'adoption'],
#  ['diversify', 'markets', 'for', 'it', 'exports'],
#  ['bpl', ';', 'ispat', 'set', 'to', 'achieve', 'financial', 'closure'],
#  ['russia', 'would', 'welcome', 'mig-at', 'deal', 'with', 'india'],
#  ['govt', 'should', 'extend', 'purchase', 'preference'],
#  ['industrial', 'growth', 'dips', 'to', '1.5', '%', 'in', 'june'],
#  ['vat', 'is', 'a', 'clean', 'tax', 'system', ':', 'sinha'],
#  ['onion', 'exports', 'capped', 'to', 'rein', 'in', 'prices'],
#  ['suspense', 'continues', 'over', "sia's", 'bid', 'for', 'air-india'],
#  ['dpc', 'moves', 'mumbai', 'high', 'court'],
#  ['pil', 'challenging', 'us', '-', '64', 'withdrawn'],
#  ['india',
#   'to',
#   'push',
#   'for',
#   "'",
#   'totalisation',
#   "'",
#   'pact',
#   'with',
#   'us'],
#  ['alembic', 'seeks', 'jvs', 'to', 'enter', 'us', ';', 'european', 'markets'],
#  ['hindujas', 'term', 'show', 'cause', 'notice', 'malafide'],
#  ['sinha', 'finds', 'a', 'friend', 'in', 'king'],
#  ['rbi', 'issues', 'guidelines', 'for', 'financing', 'films'],
#  ['coffee-consuming', 'countries', 'should', 'bail', 'out', 'growers'],
#  ['anti-aids', 'drugs', 'to', 'cost', 'less'],
#  ['sil', 'mulling', 'tie-up', 'with', 'oil', 'psus'],
#  ['fdi', 'not', 'upto', 'expectations', ':', 'maran'],
#  ['govt', 'puts', "idbi's", 'finances', 'under', 'spotlight'],
#  ['it', 'panel', 'to', 'devise', 'hardware', 'action', 'plan'],
#  ['russia', 'open', 'to', 'mig-at', 'deal', 'with', 'india'],
#  ['tatas', 'may', 'buy', "enron's", 'stake', 'in', 'dabhol', 'power'],
#  ['introduction',
#   'of',
#   'vat',
#   'would',
#   'be',
#   'revolutionary',
#   'step',
#   ':',
#   'sinha'],
#  ['cbi', 'arrests', 'ketan', 'parekh'],
#  ['ketan', 'parekh', 'interrogated', 'by', 'the', 'cbi'],
#  ['rupee', 'stages', 'mild', 'rally', 'against', 'us', '$'],
#  ['ttk', 'makes', 'a', "'", 'smart', "'", 'move', 'in', 'cookers', 'world'],
#  ['india', 'to', 'study', "china's", 'likely', 'wto', 'entry'],
#  ['hinduja', 'terms', 'dod', 'notice', 'unfair'],
#  ["leyland's", 'july', 'sales', 'down', '7.6', '%'],
#  ['govt', 'may', 'marginally', 'hike', 'kerosene', ';', 'lpg', 'price'],
#  ['rbi', 'in', 'favour', 'of', 'self-regulatory', 'norms', 'for', 'mfis'],
#  ['ketan', 'parekh', 'back', 'in', 'cbi', 'custody'],
#  ['inter', 'gold', 'launches', "men's", 'jewellery', 'range'],
#  ['amtek', 'auto', 'to', 'acquire', 'whfl'],
#  ['govt', 'heart', 'bleeds', 'for', 'corporates', ';', 'not', 'pensioners'],
#  ['forex',
#   'reserves',
#   'rise',
#   'by',
# ...
#  ['mechanism',
#   'for',
#   'monitoring',
#   'drug',
#   'price',
#   'hikes',
#   'in',
#   'the',
#   'offing'],
#  ['bpl-batata', 'in', 'talks', 'for', "spice's", 'karnataka', 'circle'],
#  ['petroleum', 'product', 'exports', 'vault', 'ten-fold'],
#  ['united', 'to', 'start', 'non-stop', 'us-india', 'flights'],
#  ['it', 'woes', ':', 'no', 'reserve', 'staff', ';', 'recruit', 'on', 'need'],
#  ['ratan', 'tata', 'offers', 'to', 'step', 'down'],
#  ['corporatisation', 'of', 'rlys', 'on', 'cards'],
#  ['pm', 'paints', 'rosy', 'picture', 'amid', 'economic', 'gloom'],
#  ['bangalore', 'bioinformatics', 'company', 'in', 'expansion', 'mode'],
#  ['motorola',
#   'sees',
#   'some',
#   'job',
#   'cuts',
#   'as',
#   'ariz',
#   'chip',
#   'lines',
#   'go'],
#  ['heavyweights', 'steady', 'sensex'],
#  ['coops', "'", 'entry', 'into', 'insurance', 'sector', 'opposed'],
#  ['kinetic', 'eyes', 'non-life', ';', 'life', 'insurance', 'sectors'],
#  ['mechanism',
#   'for',
#   'monitoring',
#   'drug',
#   'price',
#   'hikes',
#   'in',
#   'the',
#   'offing'],
#  ['small', ';', 'medium', 'firms', 'face', 'rough', 'weather'],
#  ['india', 'steamship', 'charts', 'rs', '625', 'crore', 'expansion'],
#  ['tandon', 'appointed', "pepsico's", 'vp'],
#  ['tenth', 'plan', 'approach', 'awaits', 'cabinet', 'nod'],
#  ['bengal', 'govt', 'signs', 'mou', 'with', 'microsoft'],
#  ['reply', 'to', 'notice', 'will', 'be', 'sent', 'to', 'law', 'ministry'],
#  ['hindujas', 'pull', 'out', 'of', 'race', 'for', 'ibp'],
#  ['american', 'general', 'shareholders', 'approve', 'aig', 'bid'],
#  ['krushi', 'bank', 'account', 'frozen', ';', 'board', 'scrapped'],
#  ['philips', 'to', 'outsource', 'vcr', 'production'],
#  ['telco', 'shines', 'despite', 'losses'],
#  ["laloo's", 'it', 'yt', 'website'],
#  ['chandra', 'in', 'talks', 'to', 'offload', 'stake', 'in', 'ztl'],
#  ['nasscom', 'to', 'decentralise', ';', 'open', 'regional', 'chapters'],
#  ['us', 'airways', 'announces', 'three-stage', 'restructuring', 'plan'],
#  ['ua', 'planning', 'more', 'non-stop', 'flights'],
#  ['firms',
#   'floating',
#   'call',
#   'centres',
#   'to',
#   'retain',
#   'subscriber',
#   'base'],
#  ['p', 'coke', 'scale', 'back', 'plans', 'for', 'big', 'joint', 'venture'],
#  ['m',
#   '&',
#   'm',
#   'trims',
#   'over',
#   '2',
#   ';',
#   '200',
#   'jobs',
#   ';',
#   'back',
#   'to',
#   '6',
#   '-',
#   'day',
#   'week'],
#  ['indo', 'rama', 'denies', 'takeover', 'threat'],
#  ['ia',
#   'introduces',
#   "'",
#   'walk-in',
#   "'",
#   'flights',
#   'on',
#   'delhi-mumbai',
#   'sector'],
#  ['tata', 'power', 'to', 'acquire', 'transmission', 'arm'],
#  ['india', 'not', 'isolated', 'at', 'wto', ';', 'asserts', 'maran'],
#  ['bhel', 'bags', 'rs', '2', ';', '079', 'cr', 'order', 'from', 'ntpc'],
#  ['tcs', 'teams', 'with', 'leading', 'telecom', 'cos', 'for', 'voip'],
#  ['cabinet', 'nod', 'to', 'electricity', 'bill'],
#  ['leelaventure', 'eyes', 'hampi', ';', 'hassan'],
#  ['injunction', 'against', 'oyzterbay', 'coo', 'vacated'],
#  ['indo-us', 'agreement', 'on', 'power', 'management'],
#  ['biotech', 'exports', 'total', 'rs', '1072', 'cr'],
#  ['rbi',
#   'to',
#   'transfer',
#   'rs',
#   '9',
#   ';',
#   '350',
#   'cr',
#   'dividend',
#   'to',
#   'govt'],
#  ['japanese', 'firms', 'see', 'chinese', 'imports', 'as', "'", 'threats', "'"],
#  ['maruti', 'to', 'launch', 'cars', 'for', 'disabled'],
#  ['sri',
#   'lankan',
#   'airlines',
#   'to',
#   'resume',
#   'flights',
#   'to',
#   'new',
#   'delhi'],
#  ['asci', 'will', 'spread', 'awareness', 'about', 'misleading', 'ads'],
#  ['whirlpool', 'to', 'expand', 'product', 'base'],
#  ['govt', ';', 'dpc', 'set', 'to', 'begin', 'conciliation', 'process'],
#  ['govt', 'may', 'dilute', 'stake', 'in', 'hindustan', 'zinc'],
#  ['talks', 'with', 'dhabol', 'power', 'to', 'begin', 'tomorrow'],
#  ['centre', 'not', 'to', 'take', 'over', 'dhabol', 'project'],
#  ['kapil', 'dev', 'to', 'promote', 'indian', 'tourism'],
#  ['festival', 'to', 'celebrate', 'harley-davidsons'],
#  ['ia', 'to', 'induct', '4', 'a', '-', '320', 'aircraft'],
#  ['sterlite', 'industries', 'contests', 'notice', 'on', 'disqualification'],
#  ['cabinet', 'nod', 'for', 'insolvency', 'bill'],
#  ['godbole', 'panel', 'to', 'submit', 'report', 'in', '2-3', 'weeks'],
#  ['rupee', 'weakens', 'slightly', 'against', 'dollar'],
#  ['mico', 'bosch', 'fears', 'the', 'pinch'],
#  ['cabinet', 'approves', 'bill', 'to', 'remedy', 'sick', 'industries'],
#  ['dabur', 'scouts', 'partners', 'for', 'genome', 'project'],
#  ['nppa', 'revises', 'prices', 'of', '49', 'formulation', 'packs'],
#  ['news', 'corp', 'earnings', 'slip', ';', 'awaits', 'better', 'times'],
#  ['spammers', 'create', 'havoc', 'in', 'virtual', 'world'],
#  ['white', 'paper', 'on', 'tn', 'reveals', 'fiscal', 'erosion'],
#  ['wipro', 'forges', 'alliance', 'with', 'symantec'],
#  ['kinetic', 'in', 'venture', 'for', 'auto', 'ancillaries'],
#  ['ranbaxy', 'gets', 'dgci', 'nod', 'to', 'market', 'ciprofloxacin'],
#  ['tata', 'finance', 'moves', 'rbi', 'for', 'relief'],
#  ['npcil', 'plans', 'to', 'add', '11', ';', '000', 'mw'],
#  ['rbi', 'to', 'conduct', 'sale', 'of', 'kerala', 'govt', 'bonds'],
#  ['ketan', 'parekh', 'remanded', 'to', 'cbi', 'custody', 'till', 'aug', '24'],
#  ['exodus', 'to', 'survive', 'after', 'a', 'sellout'],
#  ['money', 'wisebrgilts', 'offer', 'safe', 'investment', 'haven'],
#  ['uti', 'seeks', 'nod', 'for', 'trading', 'of', 'us', '-', '64', 'units'],
#  ['ap', 'orders', 'confiscation', 'of', 'properties', 'in', 'krushi', 'case'],
#  ['termination', 'notice', 'to', '35', 'isps'],
#  ['eih', 'withdraws', 'preferential', 'issue'],
#  ['private', 'mutual', 'funds', 'a', 'big', 'draw'],
#  ['centre', 'mulls', 'demand', 'for', 'revival', 'of', 'azmjahi', 'mills'],
#  ['messenger', 'is', 'vulnerable', 'to', 'newer', 'viruses'],
#  ['fm', 'news', 'channels', 'to', 'debut', 'in', 'sept'],
#  ['cbi', 'chargesheet', 'against', '5', 'in', 'century', 'scam'],
#  ['wipro', 'forges', 'alliance', 'with', 'symantec'],
#  ["hardware's", 'hardtalk', 'with', 'fm'],
#  ['fm', 'assures', 'tax', 'sops', 'for', 'it', 'hardware', 'sector'],
#  ['govt', '.', 'mulls', 'revised', 'payment', 'mechanism', 'for', 'ipps'],
#  ['industry', 'captains', 'join', 'hands', 'with', "'", 'water', 'man', "'"],
#  ['coffee', 'earnings', 'fall'],
#  ['cvc', 'awaits', 'report', 'recommending', 'vora', 'as', 'idbi', 'chairman'],
#  ['auto-ancillary',
#   'industry',
#   'looks',
#   'abroad',
#   'for',
#   'a',
#   'fresh',
#   'lease',
#   'of',
#   'life'],
#  ['what', 'the', 'future', 'holds', 'for', 'h1b', 'workers', '?'],
#  ['nutraceutical', 'co', '.', 'british', 'biologicals', 'to', 'enter', 'uk'],
#  ['inflation', 'rises', 'to', '5.22', '%'],
#  ['hsbc', 'to', 'launch', 'new', 'services'],
#  ['infosys', ';', 'reliance', 'most', 'admired', 'companies'],
#  ['cvc', 'favours', 'us', 'model', 'capital', 'market'],
#  ['global', 'slump', 'to', 'drag', 'exports', 'to', '2.7', '%', 'in', '2002'],
#  ['pm', 'plans', 'operation', 'to', 'arrest', 'economic', 'slowdown'],
#  ['shantha', 'biotech', 'wants', 'to', 'move', 'out', 'of', 'andhra'],
#  ['be', 'alert', ';', 'get', 'your', 'vehicle', 'insured'],
#  ['fipb', 'spikes', 'skoda', 'proposal', 'to', 'import', 'octavia', 'cbus'],
#  ['enron',
#   ';',
#   'aes',
#   'issues',
#   'dent',
#   "india's",
#   'image',
#   ':',
#   'us',
#   'regulator'],
#  ['hzl', 'disinvestment'],
#  ['sebi', 'asks', 'thomas', 'cook', 'to', 'explain', 'delay'],
#  ['aes', 'accuses', 'orissa', 'govt', 'of', 'interference'],
#  ['pioneer', 'may', 'hike', 'stake', 'in', 'mf', 'firm'],
#  ['ambani', ';', 'premji', ';', 'n', 'r', 'murthy', 'best', 'ceos'],
#  ['conciliation', 'process', 'on', 'enron', 'adjourned'],
#  ['vittal', 'in', 'favour', 'of', 'us', 'style', 'capital', 'market'],
#  ['assocham', 'to', 'set', 'up', 'body', 'for', 'prudential', 'norms'],
#  ['debt', 'fund', 'is', 'the', 'safest', 'bet', 'today'],
#  ['hoechst', 'to', 'outpace', 'others', 'in', 'profit', 'by', 'q1', '2004'],
#  ['ficci', 'regulation', 'are', 'a', 'hurdle', 'for', 'fdi', 'projects'],
#  ['ifci', 'cheated', ';', 'usha', 'chairman', 'in', 'cbi', 'net'],
#  ['fiis', 'net', 'buyers', 'in', 'equities', 'at', 'rs', '69', 'cr'],
#  ['applying', 'the', 'right', 'pressure', 'to', 'win'],
#  ['govt',
#   'to',
#   'provide',
#   'rs',
#   '130',
#   'cr',
#   'relief',
#   'to',
#   'paradeep',
#   'phosphates'],
#  ['harmonise',
#   'food',
#   'laws',
#   ';',
#   'rationalise',
#   'taxes',
#   ':',
#   'task',
#   'force'],
#  ['will', 'a', '1', ';', '000', 'multiplexes', 'bloom', '?'],
#  ['when', 'will', 'indian', 'investors', 'get', 'independence', '?'],
#  ['assocham', 'moots', 'tourism', 'council', 'for', 'eastern', 'region'],
#  ['rupee', 'steady', 'against', 'dollar'],
#  ['arvind', 'mills', 'chairman', 'to', 'bow', 'out'],
#  ['ansals', 'to', 'set', 'up', 'mega', 'it', 'park', 'in', 'noida'],
#  ['the', 'world', 'of', 'knowledge', 'worker'],
#  ['bharti',
#   'effects',
#   'revamp',
#   ';',
#   'to',
#   'invest',
#   'rs',
#   '1',
#   ';',
#   '500',
#   'crore'],
#  ['dunlop', 'suspends', 'work', 'again', 'at', 'sahajganj', 'factory'],
#  ['hope', 'for', 'developing', 'nations', 'amidst', 'slowdown'],
#  ['india', 'ready', 'to', 'discuss', 'all', 'trade', 'issues', ':', 'pm'],
#  ['world', 'economy', 'in', 'simultaneous', 'slump', ':', 'report'],
#  ['rs', '45', ';', '397', 'cr', 'fdi', 'approved', 'for', 'telecom'],
#  ['passenger', 'car', 'sales', 'maintain', 'growth', 'tempo', 'in', 'july'],
#  ['india', 'faults', 'west', 'on', 'high', 'tariff'],
#  ["cadila's", 'hi-tech', 'plant', 'gets', 'total', 'tga', 'nod'],
#  ['sinha',
#   'seeks',
#   'support',
#   'of',
#   'all',
#   'parties',
#   'to',
#   'pass',
#   'fra',
#   'bill'],
#  ['uk', 'firm', 'discovers', 'oil', 'in', 'kg', 'offshore'],
#  ['cid', 'probe', 'ordered', 'into', 'krushi', 'bank', 'scam'],
#  ['indian',
#   'cos',
#   'have',
#   'to',
#   'think',
#   'globally',
#   'and',
#   'raise',
#   'competitiveness'],
#  ['orange', 'overtakes', 'bpl', 'as', 'no', '.', '1', 'cell', 'operator'],
#  ['low', 'domestic', 'prices', 'hit', 'tea', 'growers', "'", 'returns'],
#  ['ifci', 'bailout', 'may', 'sail', 'through'],
#  ['pm', 'wants', 'a-i', 'divestment', 'hastened'],
#  ["uti's", 'position', 'under', 'threat'],
#  ['fiat', 'set', 'to', 'drive', 'in', 'palio', 'in', 'september'],
#  ['shourie', 'gives', 'tata', 'a', 'clean', 'chit'],
#  ['ifc', ';', 'fmo', ';', 'deg', 'to', 'invest', 'in', 'srei', 'arm'],
#  ['enron', 'moves', 'hc', 'on', 'merc', 'bias'],
#  ['hindujas', 'withdraw', 'bid', 'for', 'jessop', '&', 'co'],
#  ['narasimham', 'not', 'keen', 'to', 'continue'],
#  ['hotel', 'corp', 'selloff', 'runs', 'into', 'deadlock'],
#  ['pioneer', 'may', 'hike', 'stake', 'in', 'mf', 'firm'],
#  ['spender', 'leaves', 'ford', 'india'],
#  ['no', 'basis', 'for', 'basmati', 'patent', 'fears'],
#  ['sensex', 'closes', 'at', '3297.47'],
#  ['patent', 'only', 'for', '3', 'basmati', 'strains', ':', 'us'],
#  ['india',
#   'for',
#   'necessary',
#   'adjustments',
#   'in',
#   'indo-nepal',
#   'trade',
#   'treaty'],
#  ['bor',
#   'eyes',
#   'rs',
#   '80',
#   'cr',
#   'net',
#   ';',
#   'plans',
#   'to',
#   'recover',
#   'rs',
#   '80-85',
#   'cr',
#   'npas'],
#  ['top', 'ten', 'firms', 'post', 'rs', '900', 'cr', 'loss', 'in', 'q1'],
#  ['no', 'need', 'to', 'rush', 'with', 'the', 'competition', 'law'],
#  ['three',
#   'japanese',
#   'firms',
#   'may',
#   'work',
#   'on',
#   "boeing's",
#   'sonic',
#   'jet'],
#  ['govt', 'under', 'no', 'pressure', 'from', 'any', 'industrial', 'house'],
#  ['bill', 'to', 'remove', 'cap', 'on', 'fci', 'borrowings', 'approved'],
#  ['boeing', ';', 'airbus', 'valuers', 'for', "ai's", 'aircraft', 'fleet'],
#  ['fipb', 'okays', '29', 'fdi', 'proposals', 'worth', 'rs', '135', 'cr'],
#  ['auto', 'parts', 'makers', 'look', 'at', 'china', 'for', 'buyouts'],
#  ['npas',
#   'of',
#   'nationalised',
#   'banks',
#   'touch',
#   'rs',
#   '61',
#   ';',
#   '416',
#   'cr'],
#  ['a-i', 'bid', ':', 'tata', 'awaits', 'sia', 'decision'],
#  ['are', 'private', 'placements', 'a', 'safe', 'bet', '?'],
#  ['sebi', 'proposes', ';', 'cbi', 'disposes'],
#  ['core', 'sector', 'registers', '1.2', '%', 'growth'],
#  ['confusion', 'compounded', 'over', 'status', 'of', 'a-i', 'bidders'],
#  ['govt', 'for', 'more', 'independent', 'directors', 'on', 'sebi', 'board'],
#  ['stock', 'scam', 'jpc', 'gets', 'extension'],
#  ['auto', 'parts', 'industry', 'pens', 'a', 'survival', 'agenda'],
#  ['govt',
#   'to',
#   'induct',
#   'more',
#   'independent',
#   'directors',
#   'on',
#   'sebi',
#   'board'],
#  ['hll', 'extends', 'its', 'reach', 'to', 'the', 'door-step'],
#  ['bpcl', 'plans', 'petroleum', 'product', 'exports', 'to', 'bangladesh'],
#  ['bad', 'debts', 'bog', 'down', 'financial', 'institutions'],
#  ['bata', ';', 'reebok', 'tie-up', 'for', 'retailing', 'partnership'],
#  ['slowdown', 'stagnates', 'real', 'estate', 'markets', 'worldwide'],
#  ['canada', '3000', 'to', 'tie', 'up', 'with', 'ia', 'or', 'jet'],
#  ['the', 'dragon', 'turns', 'endearing'],
#  ['saarc', 'concerned', 'over', 'attempts', 'to', 'expand', 'wto', 'agenda'],
#  ['shram', 'awards', 'for', 'nine', 'ntpc', 'employees'],
#  ['spender', 'leaves', 'ford', 'india'],
#  ['govt', 'to', 'review', 'factories', 'act'],
#  ['transfer', 'pricing', 'norms', 'to', 'tax', 'international', 'deals'],
#  ['sky', 'is', 'the', 'limit', 'for', "surat's", 'sari', 'czars'],
#  ['bi', 'to', 'invest', 'rs', '23cr', 'for', 'expansion'],
#  ['zee', 'channels', 'to', 'get', 'a', 'fresh', 'look'],
#  ['krushi', 'bank', 'vice', 'chairman', 'held'],
#  ['royal',
#   'enfield',
#   'to',
#   'roll',
#   'out',
#   'new',
#   'bikes',
#   'every',
#   '6',
#   'months'],
#  ['steel', 'exports', 'register', '5', '%', 'growth', 'in', 'april-july'],
#  ['govt', 'awaiting', 'rbi', 'guidelines', 'on', 'ssi'],
#  ['reliance', 'urged', 'to', 'start', 'gas', 'cracker', 'project'],
#  ['subhash', 'chandra', 'dilutes', 'stake', 'in', 'zee'],
#  ['a-i', 'disinvestment', 'waiting', 'for', 'bidders'],
#  ['mutual', 'funds', 'invest', 'more', 'in', 'debt'],
#  ['mumbai', 'high', 'upgrade', 'hits', 'speedbreaker'],
#  ['assocham', 'to', 'counter', 'flood', 'of', 'chinese', 'goods'],
#  ['govt', 'gets', 'rs', '7.78', 'cr', 'dividend', 'from', 'vijaya', 'bank'],
#  ['basmati', 'exports', 'expected', 'to', 'be', '6', 'lakh', 'tones'],
#  ['uppal', 'leaves', 'volvo'],
#  ['cvc',
#   ';',
#   'cag',
#   'nix',
#   'proposal',
#   'on',
#   'psus',
#   "'",
#   'strategic',
#   'sale'],
#  ['fis', 'to', 'play', 'match-maker', 'in', 'enron', 'sell-off'],
#  ['atlas', 'copco', 'ab', 'hikes', 'share', 'holding', 'in', 'india'],
#  ['market', 'unimpressed', 'by', 'mtnl-bsnl', 'tie-up', 'talks'],
#  ['volvo', 'india', 'eyes', 'diverse', 'roads'],
#  ['cbi', 'to', 'probe', 'forged', 'letter', 'on', 'a-i', 'selloff'],
#  ['hc', 'seeks', 'probe', 'into', "uti's", 'investment', 'in', 'ril'],
#  ['steel', 'ministry', 'seeks', 'rs', '182', '-', 'cr', 'non-plan', 'loan'],
#  ['wide', 'income', 'disparity', 'among', 'chinese', 'workers'],
#  ['dubai', 'media', 'city', 'woos', 'indian', 'firms'],
#  ["tata's", 'taco', 'project', 'bites', 'dust'],
#  ['resolve', 'issues', 'from', 'last', 'round', 'first'],
#  ['corporation',
#   'bank',
#   'top',
#   'brass',
#   'to',
#   'brush',
#   'up',
#   'skills',
#   'in',
#   'iim'],
#  ['fi', 'takes', '18', '%', 'stake', 'in', 'automartindia'],
#  ["united's", 'flight', 'of', 'fantasy'],
#  ['ifc', 'to', 'shore', 'up', 'india', 'portfolio'],
#  ['us', 'curbs', 'on', 'india', 'likely', ';', 'says', 'enron', 'chairman'],
#  ['bidders', 'question', 'a-i', 'balance', 'sheet'],
#  ['crude', 'output', 'slips', '5.7', 'p', '.', 'c', '.', 'in', 'july'],
#  ['rs', '16', '-', 'cr', 'conditional', 'bail', 'for', 'ketan', 'parekh'],
#  ['rcf', 'eyes', 'fertiliser', 'units', 'of', 'sail', ';', 'ppl'],
#  ['brokers', 'optimise', 'derivative', 'incentive', 'scheme'],
#  ['ed', 'seeks', 'details', 'about', "ranbaxy's", 'uk', 'subsidiary'],
#  ['india', 'to', 'expand', 'itec', 'programme'],
#  ['boi', 'revises', 'interest', 'rate', 'on', 'deposits'],
#  ['allied', 'deals', 'opts', 'out', 'of', 'hzl', ';', 'cmc'],
#  ['colorplus', 'goes', 'global', ';', 'expands', 'indian', 'presence'],
#  ['quarter', 'of', 'balco', 'workforce', 'seeks', 'vrs'],
#  ['tcs', 'to', 'set', 'up', 'development', 'centre', 'in', 'hungary'],
#  ['bharti', 'offers', 'bank', 'guarantee', 'to', 'dot'],
#  ['rupee', 'steady', 'against', 'dollar'],
#  ['sbi', 'home', 'finance', 'to', 'raise', 'funds'],
#  ['sensex', 'moves', 'in', 'small', 'range', 'at', 'early', 'stages'],
#  ['sail', 'to', 'submit', 'alternative', 'package', 'for', 'iisco'],
#  ...]

# %%
tokenized[1]
# Out:
# []

# %%
len(tokenized)
# Out:
# 155587

# %% [markdown]
# ### Removing stopwords and punctuation

# %%
stopwords_english= stopwords.words('english')

# %%
cleaned=[[] for _ in range(len(tokenized))]
for i in range(0,len(tokenized)):
    for word in tokenized[i]:
        if (word not in stopwords_english and word not in string.punctuation):
            cleaned[i].append(word)

# %%
cleaned
# Out:
# [['car', 'dealers', 'caught', 'bihar', 'sales', 'tax', 'ruling'],
#  ['re-negotiation', 'best', 'deshmukh', 'lenders', 'sos', 'centre'],
#  ['samsung', 'says', 'hello', 'cellular', 'unit', 'india'],
#  ['govt', 'lifts', 'port-linked', 'curbs', 'imports'],
#  ['ril', 'plans', 'mop', 'rs', '1', '000cr'],
#  ['eicher', 'crashes', 'red', 'cut', '200', 'jobs'],
#  ['indo', 'rama', 'posts', 'rs18cr', 'net'],
#  ['jet', 'sahara', 'wait', 'watch'],
#  ['auto', 'body', 'drives', 'new', 'classification', 'norms'],
#  ['us', '64', 'sunny', 'days'],
#  ['dpc', 'may', 'contest', 'merc', 'jurisdiction'],
#  ['brave', 'new', 'biotech'],
#  ['beginning', 'salary', 'fall'],
#  ['dgca', 'proposal', 'airfares', 'upsets', 'airlines'],
#  ['zee', 'art', 'programming', 'turnaround'],
#  ['learn', 'check', 'right', 'isi', 'mark'],
#  ['mseb', 'plans', 'acid', 'test', 'dpc', 'phase', 'ii'],
#  ['ashok', 'leyland', 'cut', 'jobs', 'divisions'],
#  ['fixing',
#   'former',
#   'dse',
#   'ed',
#   "sodhi's",
#   'pay',
#   'package',
#   'lacks',
#   'transparency'],
#  ['dd', 'metro', 'grabs'],
#  ['dpc', 'signals', 'climb', 'sees', 'scope', 'cut', 'power', 'tariffs'],
#  ['satyam', 'says', 'may', 'face', 'manpower', 'problems'],
#  ['net', 'dips', '54', 'keep', 'payout', '55'],
#  ['better', 'late', 'never', 'nid', 'takes', 'new', 'design'],
#  ['sensex', 'stays', 'bull', 'zone', 'gains', '60', 'points'],
#  ['sail', 'cuts', 'losses', 'half'],
#  ['driving', 'low', 'gear'],
#  ['beware', 'snoopware', 'watching'],
#  ['ia',
#   'divestment',
#   'may',
#   'roadblock',
#   'new',
#   'players',
#   'domestic',
#   'skies'],
#  ['car', 'sales', 'drop', '15', 'april'],
#  ['ia',
#   'divestment',
#   'may',
#   'roadblock',
#   'new',
#   'players',
#   'domestic',
#   'skies'],
#  ['slowdown', 'hits', 'idbi', 'net', '27.3', 'rs', '691', 'cr'],
#  ['car', 'sales', 'drop', '15', 'april'],
#  ['korn', 'ferry', 'search', 'dewang', "mehta's", 'successors'],
#  ['korn', 'ferry', 'search', 'dewang', "mehta's", 'successors'],
#  ['media', 'publications', 'promise', 'big', 'ad', 'spend', 'future'],
#  ['centre', 'unveils', 'bailout', 'package', 'madhavpura', 'bank'],
#  ['goodyear', 'rolls', 'tubeless', 'radial', 'tyres', 'india'],
#  ['nationwide', 'bank', 'strike', 'july', '4'],
#  ['mtnl', 'execute', 'cdma-wll', 'service', 'soon'],
#  ['trai', 'moots', 'allotment', 'codes', 'std', 'operators'],
#  ['bharti-singtel', 'jv', 'gets', 'loi', 'std', 'services'],
#  ['hc', 'restrains', 'govt', 'recovering', "whisky's", 'price', 'difference'],
#  ['ia', 'review', 'flexi-fare', 'july-august'],
#  ['sportier', 'image', 'import', 'lotus', 'elise'],
#  ['bnp', 'paribas', 'may', 'acquire', 'indian', 'bank'],
#  ['crude', 'oil', 'production', 'skids', 'fiscal'],
#  ['govt', 'nod', '13', 'pvt', 'parties', 'start', 'air', 'services'],
#  ['bsp', 'mp', 'charges', 'sebi', 'unwillingness', 'probe', 'rpl'],
#  ['fipb', 'clears', '32', 'fdi', 'proposals', 'worth', 'rs', '477', 'cr'],
#  ['lg', 'launches', 'healthcare', 'products'],
#  ['jaswant', 'holds', 'talks', 'bilateral', 'trade', 'wto'],
#  ['proposal', 'enhance', 'petro', 'prices', 'naik'],
#  ['sabeer', "bhatia's", 'arzoo', 'remains', 'unfulfilled'],
#  ['ranbaxy', 'sues', 'wilmark', 'using', 'similar', 'brand', 'name'],
#  ['dumped', 'dd', 'goes', 'rebid', 'slots'],
#  ['8', 'global', 'fis', 'join', "rpl's", '500', 'loan', 'syndicate'],
#  ['jaswant', 'holds', 'talks', 'bilateral', 'trade', 'wto'],
#  ['yamaha', 'appeals', 'fake', 'bikes', 'china'],
#  ['satyam', 'wary', 'growth', 'despite', 'robust', '2000-01'],
#  ['a-i', 'present', 'profitable', 'budget', '2001-02'],
#  ['software', 'parks', 'question', "satyam's", 'export', 'revenues'],
#  ['indian', 'american', 'disney', 'interactive', 'top', 'post'],
#  ['us', 'lends', 'ears', 'india', 'steel'],
#  ['rupee', 'ends', 'mildly', 'higher', 'dollar'],
#  ['en-masse', 'transfers', "balco's", 'delhi', 'office'],
#  ['six-point', 'strategy', 'speed', 'fdi', 'flows'],
#  ['i-t', 'hauls', 'firms', 'banks', 'fis', 'investing', 'tax-free', 'bonds'],
#  ['dpc', 'mseb', 'fight', 'legal', 'battle'],
#  ['tcs', 'sets', 'asia-pacific', 'hq', 'singapore'],
#  ['imports', '300', 'sensitive', 'items', '11'],
#  ['rpl', 'gets', 'cabinet', 'nod', 'dilute', 'reliance', 'shares'],
#  ['daewoo', 'reworks', 'marketing', 'strategy'],
#  ['enron', 'debacle', 'would', 'dampen', 'flow', 'fdi', 'india'],
#  ['nissan', 'mitsubishi', 'cut', 'global', 'vehicle', 'output', 'may'],
#  ['strategic', 'partner', 'may', 'get', '5', 'directors', 'a-i', 'board'],
#  ['duty', 'drawback', 'rates', 'partially', 'rolled', 'back'],
#  ['distress', 'export', 'diesel', 'ram', 'naik'],
#  ['world', 'bank', 'announces', '913.8', 'million', 'aid', 'india'],
#  ['summertime', 'iim', 'easy', 'street'],
#  ['tatas', 'sia', 'videocon', 'cases', 'referred', 'cabinet'],
#  ['hll', 'unveils', 'action-plan', 'food', 'revolution'],
#  ['subsidies', 'lpg', 'kerosene', 'stay', 'naik'],
#  ['prasar', 'bharati', 'seeks', 'agency', 'monitor', 'dd', 'reach'],
#  ['siemens', 'buy-back', 'offer', 'begin', 'june', '25'],
#  ['china-russia', 'trade', 'hits', 'record', 'level'],
#  ['meet', 'finalise', 'madhavpura', 'revival', 'plan', 'june', '25'],
#  ["satellite's", 'corrupt', 'cops', 'still', 'run'],
#  ['us', 'loses', 'key', 'wto', 'case', 'eu'],
#  ['forex', 'reserves', 'swell', '153', '43', '160'],
#  ['gaz', 'de', 'france', 'hedge', "petronet's", 'risk'],
#  ['hdfc', 'buy', '8', 'stake', 'positra', 'sez', 'rs', '150', 'cr'],
#  ['media', 'lab', 'takes', 'have-nots'],
#  ['lord', 'paul', 'vested', 'interests', 'open', 'trade'],
#  ['without', 'reforms', 'sustained', 'bull', 'run'],
#  ['desperately', 'seeking', 'disinvestment'],
#  ['global', 'oil', 'majors', 'queue', 'ibp', 'pie'],
#  ['balmer', 'lawrie', 'demerged'],
#  ['dolphin', 'gets', 'aggressive', 'slashes', 'call', 'rate'],
#  ['cellular', 'giant', 'born'],
#  ['official', 'batata', 'bpl', 'announce', 'merger'],
#  ['a-i', 'share', 'deal', 'boost', 'sell-off', 'price'],
#  ['hindujas', 'pulling', 'shourie'],
#  ['panel', 'calls', 'freeing', 'agricultural', 'marketing'],
#  ['toontown', 'reaches', 'india'],
#  ['govt', 'package', 'face', 'difficulty', 'redeeming', 'us', '64', 'fully'],
#  ['grasim', 'industries', 'workers', 'reach', 'closure', 'agreement'],
#  ['dse', 'provides', 'liquidity', 'us', '64', 'small', 'investors'],
#  ['price', 'rigging', 'needs', 'checked'],
#  ['pak', 'studying', 'response', 'indian', 'offer', 'reduce', 'tariffs'],
#  ['g', '8', 'finance', 'ministers', 'hold', 'summit', 'rome'],
#  ['china', 'dumping', 'goods', 'india', 'cii'],
#  ['fall', 'volumes', 'may', 'force', 'dse', 'merge', 'bse'],
#  ['telecom', 'small', 'firms', 'see', 'space', 'survive'],
#  ['making', 'mission', 'possible'],
#  ['make', 'uti', 'asset', 'management', 'firm'],
#  ['us', '64', 'paid', 'earned', 'less'],
#  ['godbole', 'panel', 'recommends', 'privatisation', 'mseb'],
#  ['us', '64', 'crisis', 'disastrous', 'amfi', 'chief'],
#  ['strenghten', 'indo-pak', 'trade', 'ties', 'cii'],
#  ['infosys',
#   'sees',
#   'rs',
#   '800',
#   'cr',
#   'profit',
#   'fiscal',
#   'q1',
#   'net',
#   'soars',
#   '56'],
#  ['distacom', 'sell', '49', 'stake', 'spice'],
#  ['bpl', 'buy', 'france', 'telecom', 'batata'],
#  ['us', 'slowdown', 'takes', 'toll', 'infosys'],
#  ['indian', 'oil', 'reliance', 'among', 'forbes', 'international', '500'],
#  ['npp', 'exempt', 'r', 'd-savvy', 'dpco'],
#  ['bharti', 'cellular', 'reduces', 'airtime', 'tariff', 'magic'],
#  ['ongc', 'nod', 'increasing', 'production', 'major', 'fields'],
#  ['rupee', 'ends', 'barely', 'changed', 'dollar'],
#  ['essar', 'slashes', 'airtime', 'tariff', 'cash', 'card'],
#  ['dupont', 'expansion', 'drive', 'india'],
#  ['essel', 'sells', '50', 'lakh', 'zee', 'shares', 'us', 'investor'],
#  ['bad', 'news', 'growth', 'front'],
#  ['controls', 'sugar', 'industry', 'go', 'soon', 'shanta'],
#  ['shourie', 'denies', 'favouring', 'tatas', 'air', 'india', 'bid'],
#  ['uti', 'package', 'likely', 'today'],
#  ['dupont', 'expansion', 'drive', 'india'],
#  ['pak', 'click', 'indian', 'training', 'cos'],
#  ['maharaja', 'fly', 'chennai-hk', 'direct'],
#  ['investor', 'protection', 'fund', 'likely', 'next', 'week'],
#  ['hc', 'issues', 'contempt', 'notice', 'netware', 'infosys'],
#  ['biocon', 'transcorp', 'technology', 'battle'],
#  ['govt', 'may', 'amend', 'act', 'allow', 'rbi', 'lower', 'slr'],
#  ['investors', 'urge', 'centre', 'intervene', 'us', '64', 'scheme'],
#  ['wilful', 'defaulters', 'sent', 'jail', 'sinha'],
#  ['jpc', 'govt', 'set', 'train', 'guns', 'hfcl', 'zee'],
#  ['berger', 'ici', 'form', 'jv', 'make', 'auto', 'ind', 'coatings'],
#  ['eli',
#   'lilly',
#   'make',
#   'india',
#   'global',
#   'bulk',
#   'drug',
#   'outsourcing',
#   'hub'],
#  ['rupee', 'stages', 'mild', 'rally'],
#  ['guidelines', 'advisors', 'bidders', 'disinvestment'],
#  ['sinha', 'confident', 'achieving', 'indirect', 'tax', 'target'],
#  ['uti', 'redemptions', 'rs', '2', '265', 'crore', 'june', 'amfi'],
#  ['skumars', 'flip-flop', 'e-com', 'venture'],
#  ['improve', 'quality', 'boost', 'exports', 'thai', 'minister'],
#  ['hc', 'orders', 'bajaj', 'auto', 'make', '701', 'workers', 'permanent'],
#  ['b', 'k', 'modi', 'meet', 'fis', 'today'],
#  ['promoters', 'stake', 'zee', 'telefilms', '59'],
#  ['murdoch', 'upbeat', 'indian', 'market'],
#  ['bengal', 'sets', 'panel', 'decide', 'fate', 'psus'],
#  ['sinha', 'meets', 'banks', 'fis', 'tackle', 'slowdown'],
#  ['improve', 'quality', 'boost', 'exports', 'thai', 'minister'],
#  ['sugar', 'industry', 'stands', 'gain', 'wto', 'regime'],
#  ['uti', 'get', 'bank', 'loan', 'equity', 'holding'],
#  ['divestment', 'norms', 'affect', 'morgan', 'stanely'],
#  ['hunt', 'nasscom', 'president', 'last', 'leg'],
#  ['fis', 'stay', 'away', 'modi', 'rubber', 'open', 'offer'],
#  ['brokers', 'meet', 'july', '17', 'chart', 'action', 'plan'],
#  ['indo-myanmar', 'border', 'trade', 'declining'],
#  ['militancy', 'reduces', 'poverty', 'kashmir'],
#  ['money', 'wise', 'brsensex', 'faces', 'roller', 'coaster'],
#  ['forex', 'reserves', 'swell', '141', 'mn', '43', '596', 'mn'],
#  ['mphasis', 'shareholders', 'okay', 'equity', 'sale', 'chrysalis'],
#  ['financial', 'sector', 'reforms', 'jeopardise', 'economy'],
#  ['uti', 'board', 'fails', 'firm', 'exit', 'route', 'us', '64'],
#  ['commemorative', 'coin', "beijing's", 'olympic', 'bid', 'success'],
#  ['transfer', 'pricing', 'rules', 'aid', 'higher', 'tax', 'collections'],
#  ['rs', '28', 'cr', 'citigroup', 'funding', 'daksh'],
#  ['fiis', 'net', 'buyers', 'equities', 'rs', '261.2', 'crore'],
#  ['uti', 'offers', 'limited', 'exit', 'announce', 'nav', 'jan'],
#  ['spice', 'talks', 'cellphone', 'majors', 'merger'],
#  ['nri', 'industrialists', 'optimistic', 'indo-pak', 'summit'],
#  ['indian', 'languages', 'bridge', 'digital', 'gulf'],
#  ['small', 'uti', 'investors', 'heave', 'sigh', 'relief'],
#  ['entreprenuer', 'vanguard', 'growth'],
#  ['gdp', 'projected', 'grow', '6.3', 'cmie'],
#  ['rbi', 'governor', 'says', 'economy', 'good', 'shape'],
#  ['inflation', 'rises', '5.16'],
#  ['active', 'govt', 'role', 'needed', 'tackle', 'fakes'],
#  ['textile', 'policy', 'envisages', 'export', 'target', '50', 'b'],
#  ['fis', 'seek', 'rs', '45', 'crore', 'guarantee', 'modis'],
#  ["dpc's", 'lng', 'carrier', 'deployed', 'spot', 'market'],
#  ['nri', 'industrialists', 'optimistic', 'indo-pak', 'summit'],
#  ['maruti', 'invest', 'rs', '550', 'crore'],
#  ['fiis', 'stake', 'mrl', 'may', 'purnendu', "chatterjee's", 'holding'],
#  ['lower', 'manufacturing', 'calls', 'vat', 'internal', 'competition'],
#  ['govt', 'amending', 'i-t', 'laws', 'tax', 'e-commerce', 'firms'],
#  ['somebody', 'errs', 'others', 'pay', 'price'],
#  ['niit', 'cut', 'back', 'spending'],
#  ['banks', 'need', 'funds', 'become', 'technologically', 'competent'],
#  ['mp-based', 'companies', 'record', '13', 'growth', 'cmie', 'report'],
#  ['companies', 'q3', 'turning', 'point'],
#  ['tisco', 'seeks', 'acquisition', 'opportunities', 'select', 'fields'],
#  ['dod', 'may', 'consider', 'liberalising', 'terms', 'ia', 'selloff'],
#  ['market', 'cool', 'agra', 'talks'],
#  ['ntpc', 'buy', 'enron', 'equity', 'centre'],
#  ['j', 'j', 'irani', 'stresses', 'achieving', 'targets'],
#  ['govt', 'get', 'rs', '1', '486', 'cr', '4th', 'cellular', 'slot'],
#  ['telco', 'among', 'top', '10', 'losers'],
#  ['rupee', 'gains'],
#  ['us', '64', 'losing', 'game', 'investors'],
#  ['block', 'deals', 'limelight', 'listless', 'market'],
#  ['sc', 'allows', 'balco', 'plea', 'discrimination'],
#  ['strategic', 'sale', 'holdings', 'least', 'priority', 'uti', 'chief'],
#  ['relief', 'investors', '3', '000', 'units', 'soon'],
#  ['coca', 'cola', 'closes', '2', 'plants', 'mumbai', 'pune'],
#  ['satellite-based', 'system', 'airports', 'soon'],
#  ['psu', 'bank', 'chiefs', 'meet', 'uti', 'chief', 'us', '64', 'assistance'],
#  ['tyco', 'make', "b'lore", 'plant', 'global', 'sourcing', 'base'],
#  ['hll', 'eyes', 'organic', 'tea', 'segment'],
#  ['give', 'grants', 'poor', 'countries', 'us', 'tells', 'wb'],
#  ['increase', 'bonus', 'policy-holders', 'lic'],
#  ['hc', 'stops', 'govt', 'finalising', 'cellular', 'bids'],
#  ['saga', 'it-aided', 'design'],
#  ['states', 'may', 'fix', 'margin', 'pds', 'shops', 'govt'],
#  ['insurance', 'claims', 'settled', '7', 'days'],
#  ['car', 'wars', 'global', 'models', 'indian', 'prices'],
#  ['moet-hennessy', 'market', 'cognac', 'champagne', 'india'],
#  ['mf', 'industry', 'grew', '46.49', '1999-2000'],
#  ['auto', 'car', 'two-wheeler', 'sales', 'june'],
#  ['bids', '4th', 'cellular', 'slot', 'received'],
#  ['hyundai', 'sonata', 'makes', 'debut'],
#  ['ketan', 'denies', 'foreign', 'bank', 'account', 'ownerships'],
#  ['siemens', 'q3', 'net', 'profit', '48.97'],
#  ['pay', 'first', 'fis', 'tell', 'modis'],
#  ['tisco', 'top', 'steel', 'maker', 'q1', 'net', 'crashes', '79'],
#  ['india', 'inc', 'pessimistic', 'industrial', 'recovery'],
#  ['ub', 'group', 'launch', 'flavoured', 'water'],
#  ['govt', 'targets', '50', 'bn', 'textile', 'exports', '2010'],
#  ['mid-air', 'duel', "a-i's", 'future'],
#  ['a-i', 'maruti', 'hoc', 'divested', 'joshi'],
#  ['bse', 'sub-panel', 'oversee', 'corporatisation', 'process'],
#  ['business', 'bhailateralism'],
#  ['rupee', 'stages', 'smart', 'rally', 'dollar'],
#  ["bush's", 'wb', 'plan', 'hit', 'india'],
#  ['badla', 'operators', 'route', 'rs', '2', '000', 'cr', 'mfs'],
#  ['vassal', 'blames', 'sebi', 'us', '64', 'crisis'],
#  ['maruti', 'prices', 'go', 'soon'],
#  ['biotech', 'regulator', 'may', 'face', 'hurdle'],
#  ['bajaj', 'eliminator', 'hits', 'road'],
#  ['govt', 'may', 'raise', 'cess', 'petrol', 'diesel'],
#  ['rbi', 'favours', 'greater', 'freedom', 'co-op', 'banks'],
#  ['rbi', 'foresees', 'higher', 'agri', 'growth', 'fiscal'],
#  ['govt', 'move', 'sc', '4th', 'cellular', 'slot', 'paswan'],
#  ['top', 'uti', 'officials', 'charged', 'fraud'],
#  ['itc', 'net', '21', 'rs', '301', 'crore', 'q1'],
#  ['forex', 'reserves', 'decline', '37', 'mn', '43', '559', 'mn'],
#  ['tax', 'collections', 'plunge', '13', 'q1'],
#  ['ipcl', 'net', '64', 'rs', '12.67', 'cr', 'q1'],
#  ['rural', 'telesubscribers', 'get', 'cheap', 'deal'],
#  ['say', 'cheese', 'desi', 'pizzas', 'rs', '20'],
#  ['sailing', 'gloom', 'time'],
#  ['money', 'wisebrlessons', 'us', '64', 'debacle'],
#  ['merrill', 'lynch', 'pays', 'playing', 'bull', 'boom'],
#  ['reliance', 'dot', 'ink', 'basic', 'circles', 'pact'],
#  ['vsnl', 'venture', 'provide', 'services', 'nepal'],
#  ['cbi', 'arrests', 'subramanyam'],
#  ['fis', 'yet', 'finalise', 'participation', "modi's", 'open', 'offer'],
#  ['bharti', 'moves', 'hc', 'dot', 'follow'],
#  ['rising', 'fuel', 'costs', 'dent', "a-i's", 'bottomline'],
#  ['yashwant', 'quit', 'demands', 'cpi'],
#  ['india', 'disinvest', 'kashmir'],
#  ['us', 'slump', 'may', 'last', 'longer', 'expected'],
#  ['pc', 'sales', 'revolution', 'sight'],
#  ['one', 'ikon', 'many', 'models'],
#  ['mbt', 'shelves', 'ipo', 'plans', 'pvt', 'placement'],
#  ['digvijay', 'reviews', 'finance', "department's", 'functioning'],
#  ['boost', 'demand', 'revive', 'economy'],
#  ['smoke', 'pipe', 'line', 'peace'],
#  ['sebi', 'raise', 'issue', 'brokers', 'funding', 'rbi', 'says', 'mehta'],
#  ['bollywood', 'warms', 'india', 'inc'],
#  ['exide', 'jv', 'austrian', 'firm'],
#  ['crude', 'production', 'dips', '7.5', '2.48', 'mt', 'june'],
#  ['govt', 'awaits', 'hc', 'ruling'],
#  ['telco', 'drive', 'comm', 'vehicles', 'sales', 'q2'],
#  ['rupee', 'opens', 'slightly', 'weak'],
#  ['power',
#   'grid',
#   'corporation',
#   'invest',
#   'rs',
#   '1',
#   '100',
#   'crores',
#   'telecom'],
#  ['brokers', 'go', 'one-day', 'strike'],
#  ['dragon', 'tiger', 'china', 'eye', 'india'],
#  ['bharti-singtel', 'pulls', 'vsnl', 'bidding'],
#  ['software', 'becomes', 'free'],
#  ['rural', 'credit', 'likely', 'go', 'rs', '86', '000', 'crore', 'report'],
#  ['centre', 'chart', 'fresh', 'norms', 'ia', 'sell-off'],
#  ['uti', 'suspends', 'officials', 'cbi', 'investigation'],
#  ['multiple', 'zones', 'buy', 'back', 'mail.com', 'stake'],
#  ['stock', 'brokers', 'embark', 'nationwide', 'strike'],
#  ['india', 'scores', 'size', 'loses', 'red', 'tape', 'fdi'],
#  ['indian', 'households', 'ditch', 'stock', 'market', 'small', 'savings'],
#  ['ril', 'invest', 'rs', '1', '500', 'cr', 'oil', 'exploration'],
#  ['sebi', 'suspends', 'ace', 'stock', 'broker', 'nikhil', 'shah'],
#  ['action', 'initiated', 'bpl', 'videocon'],
#  ['3', 'member', 'panel', 'probe', "uti's", 'investment', 'decision'],
#  ['govt', 'may', 'mull', 'compensation', 'vsnl'],
#  ['govt',
#   'file',
#   'caveat',
#   'sc',
#   'tomorrow',
#   '4th',
#   'cellular',
#   'slot',
#   'issue'],
#  ["vsnl's", 'participation', 'cellular', 'bid', 'dismissed'],
#  ['disinvestment', 'commission', 'reconstituted'],
#  ['a-i', 'flights', 'hong', 'kong', 'singapore', 'mumbai'],
#  ['modis', 'hive', 'tyre', 'business'],
#  ['videocon', 'withdraws', 'ia', 'bid', 'decide', 'shortly', 'vsnl'],
#  ['top', 'brass', 'simply', 'peanuts'],
#  ['bse', 'suspends', 'trading', 'dsq', 'software', 'july', '30'],
#  ['indian', 'tea', 'exports', 'hit', 'iran', 'ban'],
#  ['telco', 'losses'],
#  ['kawasaki', 'source', 'parts', 'bajaj'],
#  ['tarapore', 'mum', 'uti', 'seeks', 'stronger', 'regulatory', 'capability'],
#  ['vat',
#   'panels',
#   'probe',
#   'revenue',
#   'loss',
#   'due',
#   'vat',
#   'vat',
#   'services'],
#  ['sbi', 'icici', 'bank', 'outsmart', 'others', '3', 'years'],
#  ['ramadorai', 'appointed', 'tata', 'tech', 'chief'],
#  ['specialty', 'ranbaxy', 'call', 'day'],
#  ['hiten', "dalal's", 'arrest', 'deferred'],
#  ['hindujas', 'sterlite', 'csfb', 'issued', 'show-cause', 'notices'],
#  ['verdict', 'ketan', "parekh's", 'bail', 'plea', 'tomorrow'],
#  ['hll', 'net', 'rises', 'pay', '250'],
#  ['sbi', 'q1', 'net', 'rises', '26', 'rs', '580', 'cr'],
#  ['samsung', 'india', 'h1', 'sales', '38', 'rs', '1', '247cr'],
#  ['ibm', 'invests', '10m', 'chrysalis'],
#  ['irda', 'warns', 'lic', 'gic', 'uti', 'equity', 'exposure'],
#  ['states', 'pay', 'rs', '18', '000cr', 'ntpc'],
#  ['tatas', 'sack', 'five', 'top', 'executives'],
#  ['uti', 'talks', 'private', 'banks', 'us', '64', 'package'],
#  ['global', 'tele', 'arm', 'plans', 'techcompetency', 'centres'],
#  ['ril', 'acquire', 'oil', 'gas', 'blocks', 'tullow'],
#  ['imf', 'wb', 'pressure', 'simplify', 'loan', 'terms'],
#  ['purple', 'yogi', 'plans', 'makeover'],
#  ['equities', 'suffer', 'setback', 'selling', 'pressure'],
#  ['4th', 'round', 'cellular', 'bids', 'stays', 'hold'],
#  ['dunlop', 'sees', 'exodus', 'executives', 'last', '7', 'months'],
#  ['us', '64', 'separated', 'schemes'],
#  ['court', 'rejects', 'ketan', "parekh's", 'bail', 'plea'],
#  ['shares', 'finish', 'lower', 'sustained', 'selling'],
#  ['icici', 'lombard', 'may', 'get', 'irda', 'nod', 'tomorrow'],
#  ['govt', 'seeks', "sebi's", 'opinion', 'hzl', 'delisting'],
#  ['govt', 'reduce', 'stake', 'idbi', 'panel'],
#  ['gspc', 'stops', 'gas', 'supply', 'essar', 'steel', 'plant'],
#  ['cii', 'discusses', 'jvs', 'british', 'counterpart'],
#  ['cbi', 'interrogates', 'arvind', 'johari', 'cyberspace'],
#  ['former', 'bse', 'president', 'damani', 'dead'],
#  ['4', 'states', 'ready', 'buy', 'dpc', 'power'],
#  ['vsnl', 'ibp', 'shareholders', 'nod', 'likely', 'sept'],
#  ['rupee', 'weakens', 'slightly', 'dollar'],
#  ['apollo', 'tyres', 'net', 'profit', 'drops', '30', 'per', 'cent'],
#  ['carrier', 'net', 'plunges', '75', 'rs', '2.55', 'cr'],
#  ['canada', '3000', 'begin', 'mumbai-toronto', 'flight'],
#  ['beer', 'battle', 'hots'],
#  ['sebi', 'begins', 'proceedings', 'broker', 'rahul', 'bajaj'],
#  ['business', 'india', 'uk', 'exceeds', 'target'],
#  ['ec', 'launches', 'antitrust', 'proceedings', 'de', 'beers'],
#  ['nandas', 'enter', 'entertainment'],
#  ['devanhalli', 'airport', 'project', 'hits', 'roadblock'],
#  ['polaris', 'picks', '25', 'stake', 'eternet', 'inc'],
#  ['uti', 'may', 'hike', 'redemption', 'limit', 'small', 'investors'],
#  ['govt', 'gives', 'nod', 'investor', 'protection', 'fund'],
#  ['lots', 'store', 'hitachi', 'india'],
#  ['royal', 'philips', 'buy', 'cg', 'glass'],
#  ['589', 'wb', 'loan', 'upgrade', 'grand', 'trunk', 'road'],
#  ['indian', 'techies'],
#  ['vsnl', 'q1', 'net', '4.54'],
#  ['icici', 'net', '13'],
#  ['rpl', 'exports', '1.4', 'mt', 'petro', 'products', 'q1'],
#  ['month-end', 'pressure', 'weakens', 'rupee'],
#  ['bhel', 'bags', 'rs', '18', 'cr', 'supply', 'order', 'apgenco'],
#  ['dull', 'head-hunters', 'find', 'work', 'finance', 'insurance'],
#  ['uti', 'split'],
#  ['sensex', 'worst', 'yet', 'come'],
#  ['retain', 'depb', 'export', 'incentive', 'scheme', 'exporters'],
#  ['underinvoicing', 'hits', 'mmtc', 'edible', 'oil', 'imports'],
#  ['chinese', 'bikes', 'threat', 'india', 'yamaha'],
#  ['duraline', 'hike', 'capacity', 'goa', 'plant'],
#  ['taxing', 'times'],
#  ['subramanyam', '3', 'others', 'remanded', 'police', 'custody'],
#  ['philips', 'carbon', 'stops', 'operation'],
#  ['us', 'power', 'major', 'aes', 'quit', 'cesco'],
#  ['a-i', 'valuation', 'may', 'fall', 'way', 'expectations'],
#  ['psus', 'spearhead', 'growth', 'q1'],
#  ['four', 'states', 'buy', 'power', 'current', 'rates'],
#  ['ongc', 'board', 'clears', 'recast', 'plan'],
#  ['lnm', 'group', 'acquires', "romania's", 'sidex'],
#  ['godrej', 'q1', 'net', 'profit', 'rs', '11.18', 'cr'],
#  ["maharashtra's", 'offer', 'unrealistic', 'dpc'],
#  ['chandra', 'open', 'diluting', 'stake', 'zee', '50'],
#  ['bajaj', 'auto', 'q1', 'net', 'inches', 'rs', '121cr'],
#  ['ipa', 'moots', 'open', 'production', 'critical', 'patented', 'drugs'],
#  ['banks', 'fis', 'owe', 'rs', '900', 'cr', 'taxes'],
#  ['hc', 'hear', 'pil', 'us', '64', 'scheme', 'aug', '1'],
#  ['investment', 'decision', 'making', 'powers', 'bsnl', 'mooted'],
#  ['cse', 'set', 'forge', 'pact', 'bse', 'derivatives'],
#  ['bob', 'offers', 'rs', '300', 'cr', 'uti'],
#  ['adobe', 'india', 'may', 'provide', 'software', 'state', 'govts'],
#  ['cse', 'worried', 'cancellation', '14', 'mn', 'dsq', 'shares'],
#  ['oil', 'traders', 'nationwide', 'stir', 'august', '20'],
#  ['haldia', 'petrochem', 'may', 'find', 'saviour'],
#  ['infosys', 'continues', 'top', 'growth', 'fund'],
#  ['tea', 'exports', 'may', 'fall', 'year'],
#  ['uti', 'grapples', 'potential', 'rs', '1', '700', 'cr', 'pay-out'],
#  ['land', 'compensation', 'market', 'value', 'sc'],
#  ['top', 'business', 'magazine', 'cut', 'staff'],
#  ['subsidy', 'petro', 'products', 'rises'],
#  ['china', 'enter', 'wto', 'challenges', 'india'],
#  ['aig', 'pick', '12', 'stake', 'nagarjuna', 'refinery'],
#  ['cmc', 'htl', 'sell-off', 'likely', 'august'],
#  ['bpl', 'leowe', 'pact', 'sees', 'big', 'picture'],
#  ['drt', 'hear', 'boi', 'suits', "ketan's", 'cos'],
#  ['next', 'godbole', 'panel', 'meeting', 'may', 'cancelled'],
#  ['convergence', 'bill', 'tabled', 'session'],
#  ['revamp', 'corporatisation', 'uti', 'demanded'],
#  ['bnp', 'paribas', 'buy', 'taiwanese', 'investment', 'trust', 'report'],
#  ['lohani', 'takes', 'new', 'itdc', 'chairman'],
#  ['cars', 'bikes', 'exports', 'scooters', 'muvs', 'q1'],
#  ['carrier', 'forms', 'panel', 'recast'],
#  ['rupee', 'weakens', 'slightly'],
#  ['bajaj', 'capital', '3rd', 'admired', 'financial', 'firm'],
#  ['cbi', 'begins', 'probe', 'cyberspace', 'share', 'transaction'],
#  ['singhanias', 'stake', 'raymond', '30'],
#  ['wockhardt', 'q2', 'net', '70.68'],
#  ['fresh', 'bids', 'appointing', 'a-i', 'valuers', 'likely'],
#  ['body', 'language', 'speaks', 'louder', 'speech'],
#  ['govt', 'working', 'package', 'coal', 'india'],
#  ['raymond', 'forays', "women's", 'wear'],
#  ['modern', 'under-valued', 'anz', 'grindlays', 'cag'],
#  ['raymond', 'earns', 'rs', '1', '150', 'cr', 'steel', 'cement', 'hive'],
#  ['reshuffle', 'give', 'professional', 'touch', 'itdc', 'kumar'],
#  ['rupee', 'ends', 'marginally', 'better'],
#  ['injunctions', 'fail', 'prevent', 'film', 'piracy'],
#  ['balco', 'kicks', 'vrs', 'unions', 'appeal', 'rejection'],
#  ['move', 'raise', 'import', 'duty', 'cigarettes', 'sinha'],
#  ['imports', 'mmtc', 'cloud', 'cbi', 'probe', 'recommended'],
#  ["pm's", 'offer', 'quit', 'makes', 'short', 'impact', 'scrips'],
#  ['p', 'srivastava', 'takes', 'cbdt', 'chairman'],
#  ['zee', 'net', '13', 'rs', '36.3', 'cr'],
#  ['govt', 'planning', 'regulator', 'coal', 'sector'],
#  ['table', 'phone', 'transcripts', 'uti', 'deals', 'sena'],
#  ['titan', 'ind', 'records', 'rs', '14.6', 'cr', 'net', 'loss'],
#  ['hc', 'issues', 'fresh', 'contempt', 'notice', 'netware', 'infosys'],
#  ['agrani', 'selects', 'alcatel', 'satellite', 'system'],
#  ['maharashtra', 'okays', 'divestment', 'bill'],
#  ['uti', 'meets', 'eye'],
#  ['bat', 'q2', 'profit', 'rises', '7.9', 'europe', 'asia'],
#  ['k', 'j', 'udeshi', 'rbi', 'executive', 'director'],
#  ['reliance', 'keen', "enron's", 'stake', 'dpc'],
#  ['ioc', 'set', 'lpg', 'dispensing', 'stations', 'gangwar'],
#  ['uti', 'heed', "jpc's", 'warning', 'sinha'],
#  ['us', 'exim', 'set', 'move', 'sc', 'dabhol', 'row'],
#  ['govt', 'faces', 'criticism', 'bail-outs'],
#  ['govt', 'okays', 'rs', '1', '000', 'cr', 'bail-out', 'ifci'],
#  ['fin', 'posts', '28', 'rise', 'profit'],
#  ['lic', 'picks', '9', 'stake', 'obc', 'market'],
#  ['electronics', 'exports', 'jump', '72.5', '2000-01'],
#  ['indo-pak', 'sugar', 'trade', 'dispute', 'erupts'],
#  ['committee', 'asks', 'govt', 'withdraw', 'tot'],
#  ['rupee', 'rock', 'steady'],
#  ["sbi's", 'fraud', 'cases', 'amount', 'rs', '269.15', 'cr'],
#  ['uti', 'readies', 'war', 'chest', 'us', '64', 'redemptions'],
#  ['exports', 'dip', '5', 'trade', 'deficit', 'widens', '34'],
#  ['tvs', 'suzuki', 'net', 'skids', '46', 'per', 'cent'],
#  ['icra', 'unveil', 'corp', 'governance', 'ratings', 'india'],
#  ['uti', 'participated', "rpl's", 'gdr', 'offer'],
#  ['birla', 'century', 'net', '18.98', 'q1'],
#  ['maruti', 'sales', '12', 'july'],
#  ['single', 'rate', 'vat', 'may', 'boost', 'economy'],
#  ['icici', 'lombard', 'get', 'nod', 'irda'],
#  ['bob', 'tie', 'amc', 'life', 'insurance'],
#  ['cbi', 'asks', 'sebi', 'take', 'action', 'ed'],
#  ['industrial', 'slowdown', 'lead', 'recession'],
#  ['bharti', 'offers', 'rs', '258', 'cr', 'payment'],
#  ['wipro', 'sharpens', 'focus', 'embedded', 'software'],
#  ['dip', 'exports', 'due', 'international', 'slowdown'],
#  ['zen', 'wagonr', 'drive', 'mul', 'sales'],
#  ['firm', 'garners', 'rs', '20', 'cr', 'german', 'fair'],
#  ['rupee', 'strengthens'],
#  ['uti', 'reserves', 'turn', 'negative'],
#  ['arunachal', 'decentralise', 'tea', 'cultivation'],
#  ['videocon', 'may', 'sell', 'stake', 'ravva', 'venture'],
#  ['nine', 'psus', 'empanelled', 'divestment'],
#  ['german', 'bank', 'credit', 'power', 'telecom', 'projects'],
#  ['general', 'motors', 'investment', 'india'],
#  ['indo-china', 'trade', 'get', 'boost'],
#  ['b', 'muthuraman', 'new', 'tisco', 'md'],
#  ['lukewarm', 'response', 'uti', 'repurchase'],
#  ['vrs', 'central', 'govt', 'employees', 'soon', 'shourie'],
#  ['indian', 'beer', 'wins', 'international', 'acclaim'],
#  ['cse', 'may', 'suspend', 'trading', 'dsq', 'software'],
#  ['bajaj', "auto's", 'vrs', 'gets', 'lukewarm', 'response'],
#  ['us', 'bankers', 'follow', 'shariah', 'strike', 'gold'],
#  ['cii', 'delegates', 'meet', 'us', 'officials', 'steel'],
#  ['karnik', 'looks', 'rebuild', 'nasscom'],
#  ['uti', 'crisis', 'usual', 'public', 'pays', 'price'],
#  ['anti-dumping', 'duties', 'theophylline', 'caffeine', 'import'],
#  ['aes', 'pullout', 'affect', 'privatisation', 'prabhu'],
#  ['bentley', 'car', 'rs', '1', 'cr'],
#  ['uti', 'chief', 'promises', 'cleanup', 'job'],
#  ['cancelling', 'dpc', 'phase-i', 'revival', 'phase-ii', 'mistake'],
#  ['mrtpc', 'gives', 'clean', 'chit', 'daewoo'],
#  ['financial', 'sector', 'facing', 'crisis', 'confidence', 'vittal'],
#  ['bank', 'india', 'open', 'branches', 'china', 'vietnam'],
#  ['uti', 'receives', 'applications', 'repurchases', '2.22', 'crore', 'units'],
#  ['india', 'potential', 'garner', '100', 'bn', 'fdi', '5', 'yrs'],
#  ['equities', 'rise', 'smartly', 'nse'],
#  ['singling', 'rbi', 'nominees', 'appropriate'],
#  ['kyoto', 'enjoys', 'backing', 'g', '77', 'nations'],
#  ['petronet', 'seals', 'lng', 'chain', 'inks', 'gas', 'sale', 'mous'],
#  ['closure', 'psus', 'last', 'resort', 'govt'],
#  ['china', 'lifts', 'restrictions', 'pvt', 'enterprises'],
#  ['sony', 'gets', '808', 'mn', 'credit', 'line'],
#  ['govt', 'allays', 'fear', 'inflation'],
#  ['aes', 'pulls', 'orissa', 'crisis', 'galore'],
#  ['ifci', 'enquire', 'modern', 'syntex', 'accounts'],
#  ['sahara', 'tie', 'foreign', 'airline'],
#  ['bhel', 'bags', 'rs', '10', 'cr', 'order', 'ongc'],
#  ['resignation', 'help', 'sinha'],
#  ['uti', 'may', 'dig', 'reserve', 'fund'],
#  ['mps', 'love', 'bombay', 'high'],
#  ['sensex', 'recovers', '2.27', 'last', 'week'],
#  ['sinha', 'rules', 'resignation', 'uti', 'muddle'],
#  ['data', 'storage', 'dominate', 'spending'],
#  ['uti', 'firm', 'strategic', 'sale', 'dud', 'firms'],
#  ['air', 'nz', 'deal', 'forcing', 'sia', 'rethink', 'a-i'],
#  ['ulip', 'keeping', 'uti', 'flag', 'high'],
#  ['uti', 'may', 'suspend', 'us', '64', 'sales', 'indefinitely'],
#  ['former', 'wiproites', 'make', 'big', 'techie', 'world'],
#  ['cyberspace', 'wrong', 'investment', 'decision', 'sinha'],
#  ['potential', 'tap', '100', 'bn', 'fdi', '5', 'yrs'],
#  ['itc', 'open', 'related', 'areas'],
#  ['hdfc', 'standard', 'life', 'break', 'even', '5', 'years'],
#  ['itc', 'chairman', 'bat', 'increasing', 'stake', 'vst'],
#  ['wll', 'mobile', 'phones', 'punjab', 'march', '2002'],
#  ['save', 'dabhol'],
#  ['sbi', 'forex', 'profit', 'downswing'],
#  ['ioc', 'hikes', 'servo', 'prices'],
#  ['voltas', 'exonerated', 'unfair', 'trade', 'charges'],
#  ['hpcl', 'complete', 'bhatinda', 'refinery', 'dec', '2005'],
#  ['fiiss', 'mfs', 'operated', 'contrast', 'july', 'sebi'],
#  ['kiran', 'karnik', 'succeed'],
#  ['bharti', 'initiates', 'talks', 'rs', '3000', 'cr', 'debt'],
#  ['b2b', 'transaction', 'volumes', 'touch', 'rs', '51', '000', 'cr'],
#  ['cse', 'board', 'discuss', 'dsq', 'suspension', 'tuesday'],
#  ['face', 'offbrthe', 'silver', 'lining', 'hcl'],
#  ['forced', 'rescind', 'ppa', 'mseb'],
#  ['niit', 'add', '2', 'sbus', 'retail', 'transport'],
#  ['regulatory', 'framework', 'must', 'media', 'industry'],
#  ['tough', 'time', 'consumer', 'durables', 'firms', 'warns', 'icra'],
#  ['cyberspace', 'scam', 'gets', 'financiers', 'trapped'],
#  ['bpl', 'appoints', 'i-sec', 'sell', 'maharashtra', 'cellular', 'licence'],
#  ['pharma', 'growth', 'plans', 'enchant', 'industry', 'analysts'],
#  ['a-i', 'earns', 'rs', '245', 'cr', 'via', 'seat', 'sharing'],
#  ['telco', 'bajaj', 'forsee', 'higher', 'growth', 'net', 'profit'],
#  ['vsnl', 'notified', 'vrs', 'employees'],
#  ['parliament', 'approves', 'repeal', 'banking', 'companies', 'act'],
#  ['anti-dumping', 'case', 'porcelain', 'tile', 'import', 'china'],
#  ['ford', 'reduces', 'cost', 'ownership'],
#  ['crompton', 'greaves', 'recasts', 'come', 'red'],
#  ['tatas', 'file', 'fir', 'dilip', 'pendse', '5', 'others'],
#  ['india', 'press', 'limited', 'agenda', 'wto', 'talks'],
#  ['tata', 'hughes', 'exploring', 'telecoms', 'tie-up'],
#  ['indian', 'firms', 'invited', 'set', 'units', "china's", 'sezs'],
#  ['proposal', 'divest', 'sail', 'govt'],
#  ['tvs-suzuki', 'reports', '4', 'july', 'sales'],
#  ['dd', 'opens', 'fresh', 'bidding', 'metro', 'primetime'],
#  ['bifr', 'asks', 'torrent', 'sort', 'differences', 'creditors'],
#  ['sia', 'sought', '49', 'stake', 'a-i'],
#  ['honda', 'launches', 'activa', 'delhi'],
#  ['nigeria', 'technological', 'corp', 'india'],
#  ['fieo', 'weclomes', "sbi's", 'move', 'cut', 'plr'],
#  ['nse', 'expels', 'ashoka', 'industrial', 'resources'],
#  ['maruti', 'hikes', 'car', 'prices', 'today'],
#  ['cvc', 'orders', 're-tender', 'rs', '1', '000', 'crore', 'dot', 'contract'],
#  ['sc', 'transfers', 'enron', 'issue', 'bombay', 'hc'],
#  ['differences', 'ia', 'a-i', 'divestment', 'yadav'],
#  ['catch', 'em', 'young', 'kids', 'consumers'],
#  ['thermax', 'announces', 'vrs', 'employees'],
#  ['pcb', 'pulled', 'taking', 'action', 'eil'],
#  ["enron's", 'dpc', 'extremely', 'pleased', 'sc', 'ruling'],
#  ['india', 'austria', 'sign', 'double', 'taxation', 'treaty'],
#  ['gartner', 'upbeat', 'face', 'gloomy', 'doomy', 'mart'],
#  ['jalan', 'declines', 'comment', 'ifci', 'bailout'],
#  ['godbole', 'panel', 'report', 'applicable', 'reliance', 'power'],
#  ['china', 'revamp', 'economy', 'ahead', 'wto', 'entry'],
#  ['jk', 'industries', 'delist', 'delhi', 'bourse'],
#  ['wheat', 'exports', 'hit', 'new', 'lows', 'despite', 'demand', 'rise'],
#  ['raymond', 'acquire', 'hindustan', 'gas', 'arm'],
#  ['former', 'uti', 'chief', 'subramanyam', 'gets', 'bail'],
#  ['favouring', 'wireless', 'users', 'causes', 'rs', '24', 'cr', 'loss'],
#  ['govt', 'give', 'ifci', 'rs', '400', 'cr'],
#  ['sensex', 'slides', '11', 'points'],
#  ['p', 'downgrade', 'seen', 'little', 'impact'],
#  ['dpc', 'warns', 'mseb', 'information', 'prayas'],
#  ['prices', '3', 'bulk', 'drugs', 'slashed'],
#  ['strength', 'direct', 'marketing'],
#  ['tatas', 'file', 'fir', 'dilip', 'pendse', '5', 'others'],
#  ['cement', 'sales', 'production', 'dip', 'july'],
#  ['gross', 'fiscal', 'deficit', 'soars', 'rs', '42', '000', 'cr'],
#  ['rupee', 'steady', 'us', 'dollar'],
#  ['78', 'bn', 'required', 'improve', 'tele-density', 'paswan'],
#  ['govt', 'may', 'lower', 'bank', 'guarantee', 'ibp'],
#  ['india', 'proposes', 'changes', 'wto', 'subsidies', 'pact'],
#  ['bhel', 'bags', 'rs', '280', 'crore', 'order', 'us'],
#  ['govt', 'may', 'agree', 'reduce', 'stake', 'boi'],
#  ['india', 'take', 'wto', 'issues', 'ustr'],
#  ['pnb', 'extend', 'rs', '300-400', 'cr', 'uti', 'sub-plr'],
#  ['govt', 'issue', 'norms', 'diagnostic', 'labs'],
#  ['govt', 'clears', 'fdi', 'proposals', 'worth', 'rs', '980', 'cr'],
#  ['telecom', 'deals', 'spearhead', 'activity'],
#  ['govt', 'allow', 'bilateral', 'flights', 'kochi'],
#  ['us', 'allows', 'duty-free', 'access', '42', 'indian', 'goods'],
#  ['honda', 'export', '2', 'wheelers', 'india'],
#  ["idbi's", 'finances', 'spotlight'],
#  ['mid-sized', 'car', 'segment', 'fails', 'keep', 'promise'],
#  ["p's", 'downgrading', 'attracts', 'mixed', 'reaction'],
#  ['dpc', 'charges', 'power', 'regulator', 'bias'],
#  ['srichakra', 'lure', 'young', 'minds', 'colourful', 'tyres'],
#  ['p', 'downgrade', 'affect', 'fdi', 'divestment'],
#  ['bp',
#   'amoco',
#   'told',
#   'pay',
#   'rs',
#   '350',
#   'per',
#   'share',
#   'castrol',
#   'stake'],
#  ['sia', 'raise', 'stake', 'a-i', 'post-selloff'],
#  ['reality', 'check', 'entermedia'],
#  ['lock-in', 'period', 'hughes', 'promoters', 'extended'],
#  ['build', 'customer', 'relationships', 'sales'],
#  ['satnam', 'offer', 'ready-to-cook', 'products'],
#  ['investors', 'trust', 'analysts', 'doubts', 'remain'],
#  ['indo', 'rama', 'keen', 'invest', 'butibori', 'plant'],
#  ['dalmia', 'welcomes', 'bp', "amoco's", 'offer', 'castrol', 'stake'],
#  ['dabhol', 'examining', 'customs', 'duty', 'notice'],
#  ['mills', 'produce', 'sugar', 'electricity'],
#  ["moody's", 'slashes', 'india', 'outlook'],
#  ['evangelists', 'fud-ge', "developer's", 'act'],
#  ['govt', 'headhunters', 'little', 'placement'],
#  ['reality', 'check', 'entermedia'],
#  ['rating', 'agencies', 'wrong', 'sinha'],
#  ['sinha', 'allays', 'fear', 'rupee', 'fall'],
#  ['centre', 'buy', 'enron', 'holding', 'dpc'],
#  ['govt', 'allow', 'bilateral', 'flights', 'kochi'],
#  ["dabhol's", '1', 'bn', 'offer', 'costly', 'says', 'mseb'],
#  ['enron', 'offers', 'sell', 'stake', 'cost'],
#  ['slowdown', 'hits', 'car', 'sales'],
#  ['star', 'picks', 'majority', 'stake', 'vijay', 'tv'],
#  ['railtel', 'corp', 'invest', 'rs', '700', 'cr', 'ofc', 'network'],
#  ['p', 'lowers', 'rating', 'outlook', 'banks'],
#  ['rupee', 'eases', 'marginal', 'ground'],
#  ['dabhol', 'examining', 'customs', 'duty', 'notice'],
#  ['fdi', 'expectations', 'maran'],
#  ['germany', 'switching', 'dm', 'euro'],
#  ['india', 'called', 'wto', 'agenda', 'talks'],
#  ['nasscom', 'promote', 'adoption'],
#  ['diversify', 'markets', 'exports'],
#  ['bpl', 'ispat', 'set', 'achieve', 'financial', 'closure'],
#  ['russia', 'would', 'welcome', 'mig-at', 'deal', 'india'],
#  ['govt', 'extend', 'purchase', 'preference'],
#  ['industrial', 'growth', 'dips', '1.5', 'june'],
#  ['vat', 'clean', 'tax', 'system', 'sinha'],
#  ['onion', 'exports', 'capped', 'rein', 'prices'],
#  ['suspense', 'continues', "sia's", 'bid', 'air-india'],
#  ['dpc', 'moves', 'mumbai', 'high', 'court'],
#  ['pil', 'challenging', 'us', '64', 'withdrawn'],
#  ['india', 'push', 'totalisation', 'pact', 'us'],
#  ['alembic', 'seeks', 'jvs', 'enter', 'us', 'european', 'markets'],
#  ['hindujas', 'term', 'show', 'cause', 'notice', 'malafide'],
#  ['sinha', 'finds', 'friend', 'king'],
#  ['rbi', 'issues', 'guidelines', 'financing', 'films'],
#  ['coffee-consuming', 'countries', 'bail', 'growers'],
#  ['anti-aids', 'drugs', 'cost', 'less'],
#  ['sil', 'mulling', 'tie-up', 'oil', 'psus'],
#  ['fdi', 'upto', 'expectations', 'maran'],
#  ['govt', 'puts', "idbi's", 'finances', 'spotlight'],
#  ['panel', 'devise', 'hardware', 'action', 'plan'],
#  ['russia', 'open', 'mig-at', 'deal', 'india'],
#  ['tatas', 'may', 'buy', "enron's", 'stake', 'dabhol', 'power'],
#  ['introduction', 'vat', 'would', 'revolutionary', 'step', 'sinha'],
#  ['cbi', 'arrests', 'ketan', 'parekh'],
#  ['ketan', 'parekh', 'interrogated', 'cbi'],
#  ['rupee', 'stages', 'mild', 'rally', 'us'],
#  ['ttk', 'makes', 'smart', 'move', 'cookers', 'world'],
#  ['india', 'study', "china's", 'likely', 'wto', 'entry'],
#  ['hinduja', 'terms', 'dod', 'notice', 'unfair'],
#  ["leyland's", 'july', 'sales', '7.6'],
#  ['govt', 'may', 'marginally', 'hike', 'kerosene', 'lpg', 'price'],
#  ['rbi', 'favour', 'self-regulatory', 'norms', 'mfis'],
#  ['ketan', 'parekh', 'back', 'cbi', 'custody'],
#  ['inter', 'gold', 'launches', "men's", 'jewellery', 'range'],
#  ['amtek', 'auto', 'acquire', 'whfl'],
#  ['govt', 'heart', 'bleeds', 'corporates', 'pensioners'],
#  ['forex', 'reserves', 'rise', '127', '43', '809'],
#  ['skoda', 'charts', 'new', 'plan', 'import', 'car', 'india'],
#  ['asia', 'pacific', 'enterprise', 'meet', 'tomorrow'],
#  ['check', 'safe', 'index', 'fund'],
#  ['pollution', 'free', 'energy', 'fuel', 'cells'],
#  ["india's", 'crude', 'production', 'dips', '7.5'],
#  ['iip', 'grow', '4.5', '2001-02'],
#  ["enron's", 'exit', 'countdown', 'begins', 'nov', '19', '2001'],
#  ['imc', 'moots', 'plan', 'revive', 'economy'],
#  ['bhel', 'implements', 'montek', 'committee', 'recommendations'],
#  ['igniting', 'espresso', 'engine'],
#  ['dalmias', 'may', 'acquire', '40', 'stake', 'revathi', 'equipment'],
#  ['cse', 'working', 'introducing', 'margin', 'trading'],
#  ["peta's", 'demand', 'could', 'adversely', 'affect', 'leather', 'industry'],
#  ['tea', 'board', 'hires', 'f', 'ferguson', 'review', 'functioning'],
#  ['malwa', 'forays', 'sewing', 'threads', 'oswal', 'name'],
#  ['fiis', 'net', 'buyers', 'equities', 'rs', '168.5', 'cr'],
#  ['century', 'extrusions', 'submit', 'fresh', 'rehab', 'scheme'],
#  ['fis', 'agree', 'fund', '16', '000', 'mw', 'pvt', 'projects'],
#  ['centre', 'ask', 'ntpc', 'buy', 'enron', 'stake', 'dabhol'],
#  ['b', 'volvo', 'approaches', 'hc', 'protect', 'brand', 'name'],
#  ['inflation', 'remains', 'stuck', '4.96'],
#  ['sales', 'top', '10', 'companies', '14', 'q1'],
#  ['india', 'inc', 'salutes', 'winners', 'among', 'winners'],
#  ['vat', 'would', 'result', 'registered', 'traders'],
#  ['idbi', 'fix', 'ifci', 'bailout'],
#  ['india', 'records', 'healthy', '6', 'growth', 'power', 'generation'],
#  ['plea', 'bifr', 'order', 'gtc', 'case', 'dismissed'],
#  ['export', 'promotion', 'schemes', 'proving', 'expensive'],
#  ['exports', 'vegetarian', 'foods', 'rise'],
#  ['ongc', 'bids', '400', 'ril', '350', "enron's", 'panna-mukta', 'stake'],
#  ['mig', 'man', 'mohanty', 'next', 'hal', 'chairman'],
#  ['centre', 'unveil', 'medium', 'term', 'export', 'policy'],
#  ['alstom', 'focus', 'core', 'business', 'revamp', 'bid'],
#  ['police', 'seize', 'documents', 'ex-md', 'tata', 'finance'],
#  ['fiis', 'reduce', 'stake', 'dabur', 'india', '6.43'],
#  ['sebi', 'tells', 'dse', 'retain', 'davar', 'board'],
#  ['ril', 'hll', 'fall', 'selling', 'pressure'],
#  ['bajoria', 'holding', 'bombay', 'dyeing', 'crosses', '5'],
#  ['govt', 'may', 'buy', 'back', 'equity', 'neyveli', 'lignite'],
#  ['ap', 'set', 'get', 'six', 'power', 'projects'],
#  ['ongc', 'bids', '400m', "enron's", 'panna-mukta'],
#  ['kingfisher', 'sells', '614m', 'pounds', 'properties'],
#  ['new', 'ba', 'services', 'take', 'competition'],
#  ['export', 'finance', 'rate', 'may', 'see', 'downward', 'trend'],
#  ['uti', 'investors', 'die-hard', 'loyalists'],
#  ['govt', 'decide', 'hindujas', 'a-i', 'bid', '10', 'days'],
#  ['telco', 'cuts', 'rights', 'issue'],
#  ['cabinet', 'panel', 'clears', 'projects', 'worth', 'rs', '590', 'cr'],
#  ['deeshe', 'offer', 'cheapest', 'colour', 'tvs'],
#  ['unocal', 'proposes', 'jv', 'ioc'],
#  ['stocks', 'lead', 'recovery', 'fresh', 'fii', 'buying'],
#  ['rupee', 'eases', 'marginally', 'dollar'],
#  ['uti', 'sought', 'fresh', 'loans'],
#  ['indusind', 'launch', 'news', 'channel'],
#  ['ia', 'cuts', 'mumbai-delhi', 'one-way', 'economy', 'fare'],
#  ['samsung', 'eyes', 'rs', '1', '300', 'crore', 'turnover'],
#  ['rbi', 'supercession', 'krushi', 'board'],
#  ['icici', 'maintain', 'growth', 'despite', 'slowdown'],
#  ['letter', 'comfort', 'issued', 'ifci', 'bailout'],
#  ['hindujas', 'keen', 'buying', "enron's", 'dpc', 'stake'],
#  ['sebi', 'announce', 'futures', 'trading'],
#  ['sterlite', 'buyback', 'offer', 'clouded', 'sebi', 'ban'],
#  ['ccea', 'clears', 'rail', 'power', 'projects'],
#  ['uti', 'advance', 'us', '64', 'nav', 'announcement'],
#  ['sebi', 'allows', 'banks', 'fiis', 'derivatives', 'market'],
#  ['skilling', 'quits', 'jolts', 'enron'],
#  ['stock', 'market', 'functioning', 'reformed', 'pm'],
#  ['medium', 'term', 'export', 'strategy', 'september'],
#  ['foreign', 'carriers', 'lower', 'commissions'],
#  ['clash', 'titans'],
#  ['anti-dumping', 'probe', 'panel', 'set'],
#  ['mechanism', 'monitoring', 'drug', 'price', 'hikes', 'offing'],
#  ['bpl-batata', 'talks', "spice's", 'karnataka', 'circle'],
#  ['petroleum', 'product', 'exports', 'vault', 'ten-fold'],
#  ['united', 'start', 'non-stop', 'us-india', 'flights'],
#  ['woes', 'reserve', 'staff', 'recruit', 'need'],
#  ['ratan', 'tata', 'offers', 'step'],
#  ['corporatisation', 'rlys', 'cards'],
#  ['pm', 'paints', 'rosy', 'picture', 'amid', 'economic', 'gloom'],
#  ['bangalore', 'bioinformatics', 'company', 'expansion', 'mode'],
#  ['motorola', 'sees', 'job', 'cuts', 'ariz', 'chip', 'lines', 'go'],
#  ['heavyweights', 'steady', 'sensex'],
#  ['coops', 'entry', 'insurance', 'sector', 'opposed'],
#  ['kinetic', 'eyes', 'non-life', 'life', 'insurance', 'sectors'],
#  ['mechanism', 'monitoring', 'drug', 'price', 'hikes', 'offing'],
#  ['small', 'medium', 'firms', 'face', 'rough', 'weather'],
#  ['india', 'steamship', 'charts', 'rs', '625', 'crore', 'expansion'],
#  ['tandon', 'appointed', "pepsico's", 'vp'],
#  ['tenth', 'plan', 'approach', 'awaits', 'cabinet', 'nod'],
#  ['bengal', 'govt', 'signs', 'mou', 'microsoft'],
#  ['reply', 'notice', 'sent', 'law', 'ministry'],
#  ['hindujas', 'pull', 'race', 'ibp'],
#  ['american', 'general', 'shareholders', 'approve', 'aig', 'bid'],
#  ['krushi', 'bank', 'account', 'frozen', 'board', 'scrapped'],
#  ['philips', 'outsource', 'vcr', 'production'],
#  ['telco', 'shines', 'despite', 'losses'],
#  ["laloo's", 'yt', 'website'],
#  ['chandra', 'talks', 'offload', 'stake', 'ztl'],
#  ['nasscom', 'decentralise', 'open', 'regional', 'chapters'],
#  ['us', 'airways', 'announces', 'three-stage', 'restructuring', 'plan'],
#  ['ua', 'planning', 'non-stop', 'flights'],
#  ['firms', 'floating', 'call', 'centres', 'retain', 'subscriber', 'base'],
#  ['p', 'coke', 'scale', 'back', 'plans', 'big', 'joint', 'venture'],
#  ['trims', '2', '200', 'jobs', 'back', '6', 'day', 'week'],
#  ['indo', 'rama', 'denies', 'takeover', 'threat'],
#  ['ia', 'introduces', 'walk-in', 'flights', 'delhi-mumbai', 'sector'],
#  ['tata', 'power', 'acquire', 'transmission', 'arm'],
#  ['india', 'isolated', 'wto', 'asserts', 'maran'],
#  ['bhel', 'bags', 'rs', '2', '079', 'cr', 'order', 'ntpc'],
#  ['tcs', 'teams', 'leading', 'telecom', 'cos', 'voip'],
#  ['cabinet', 'nod', 'electricity', 'bill'],
#  ['leelaventure', 'eyes', 'hampi', 'hassan'],
#  ['injunction', 'oyzterbay', 'coo', 'vacated'],
#  ['indo-us', 'agreement', 'power', 'management'],
#  ['biotech', 'exports', 'total', 'rs', '1072', 'cr'],
#  ['rbi', 'transfer', 'rs', '9', '350', 'cr', 'dividend', 'govt'],
#  ['japanese', 'firms', 'see', 'chinese', 'imports', 'threats'],
#  ['maruti', 'launch', 'cars', 'disabled'],
#  ['sri', 'lankan', 'airlines', 'resume', 'flights', 'new', 'delhi'],
#  ['asci', 'spread', 'awareness', 'misleading', 'ads'],
#  ['whirlpool', 'expand', 'product', 'base'],
#  ['govt', 'dpc', 'set', 'begin', 'conciliation', 'process'],
#  ['govt', 'may', 'dilute', 'stake', 'hindustan', 'zinc'],
#  ['talks', 'dhabol', 'power', 'begin', 'tomorrow'],
#  ['centre', 'take', 'dhabol', 'project'],
#  ['kapil', 'dev', 'promote', 'indian', 'tourism'],
#  ['festival', 'celebrate', 'harley-davidsons'],
#  ['ia', 'induct', '4', '320', 'aircraft'],
#  ['sterlite', 'industries', 'contests', 'notice', 'disqualification'],
#  ['cabinet', 'nod', 'insolvency', 'bill'],
#  ['godbole', 'panel', 'submit', 'report', '2-3', 'weeks'],
#  ['rupee', 'weakens', 'slightly', 'dollar'],
#  ['mico', 'bosch', 'fears', 'pinch'],
#  ['cabinet', 'approves', 'bill', 'remedy', 'sick', 'industries'],
#  ['dabur', 'scouts', 'partners', 'genome', 'project'],
#  ['nppa', 'revises', 'prices', '49', 'formulation', 'packs'],
#  ['news', 'corp', 'earnings', 'slip', 'awaits', 'better', 'times'],
#  ['spammers', 'create', 'havoc', 'virtual', 'world'],
#  ['white', 'paper', 'tn', 'reveals', 'fiscal', 'erosion'],
#  ['wipro', 'forges', 'alliance', 'symantec'],
#  ['kinetic', 'venture', 'auto', 'ancillaries'],
#  ['ranbaxy', 'gets', 'dgci', 'nod', 'market', 'ciprofloxacin'],
#  ['tata', 'finance', 'moves', 'rbi', 'relief'],
#  ['npcil', 'plans', 'add', '11', '000', 'mw'],
#  ['rbi', 'conduct', 'sale', 'kerala', 'govt', 'bonds'],
#  ['ketan', 'parekh', 'remanded', 'cbi', 'custody', 'till', 'aug', '24'],
#  ['exodus', 'survive', 'sellout'],
#  ['money', 'wisebrgilts', 'offer', 'safe', 'investment'],
#  ['uti', 'seeks', 'nod', 'trading', 'us', '64', 'units'],
#  ['ap', 'orders', 'confiscation', 'properties', 'krushi', 'case'],
#  ['termination', 'notice', '35', 'isps'],
#  ['eih', 'withdraws', 'preferential', 'issue'],
#  ['private', 'mutual', 'funds', 'big', 'draw'],
#  ['centre', 'mulls', 'demand', 'revival', 'azmjahi', 'mills'],
#  ['messenger', 'vulnerable', 'newer', 'viruses'],
#  ['fm', 'news', 'channels', 'debut', 'sept'],
#  ['cbi', 'chargesheet', '5', 'century', 'scam'],
#  ['wipro', 'forges', 'alliance', 'symantec'],
#  ["hardware's", 'hardtalk', 'fm'],
#  ['fm', 'assures', 'tax', 'sops', 'hardware', 'sector'],
#  ['govt', 'mulls', 'revised', 'payment', 'mechanism', 'ipps'],
#  ['industry', 'captains', 'join', 'hands', 'water', 'man'],
#  ['coffee', 'earnings', 'fall'],
#  ['cvc', 'awaits', 'report', 'recommending', 'vora', 'idbi', 'chairman'],
#  ['auto-ancillary', 'industry', 'looks', 'abroad', 'fresh', 'lease', 'life'],
#  ['future', 'holds', 'h1b', 'workers'],
#  ['nutraceutical', 'co', 'british', 'biologicals', 'enter', 'uk'],
#  ['inflation', 'rises', '5.22'],
#  ['hsbc', 'launch', 'new', 'services'],
#  ['infosys', 'reliance', 'admired', 'companies'],
#  ['cvc', 'favours', 'us', 'model', 'capital', 'market'],
#  ['global', 'slump', 'drag', 'exports', '2.7', '2002'],
#  ['pm', 'plans', 'operation', 'arrest', 'economic', 'slowdown'],
#  ['shantha', 'biotech', 'wants', 'move', 'andhra'],
#  ['alert', 'get', 'vehicle', 'insured'],
#  ['fipb', 'spikes', 'skoda', 'proposal', 'import', 'octavia', 'cbus'],
#  ['enron', 'aes', 'issues', 'dent', "india's", 'image', 'us', 'regulator'],
#  ['hzl', 'disinvestment'],
#  ['sebi', 'asks', 'thomas', 'cook', 'explain', 'delay'],
#  ['aes', 'accuses', 'orissa', 'govt', 'interference'],
#  ['pioneer', 'may', 'hike', 'stake', 'mf', 'firm'],
#  ['ambani', 'premji', 'n', 'r', 'murthy', 'best', 'ceos'],
#  ['conciliation', 'process', 'enron', 'adjourned'],
#  ['vittal', 'favour', 'us', 'style', 'capital', 'market'],
#  ['assocham', 'set', 'body', 'prudential', 'norms'],
#  ['debt', 'fund', 'safest', 'bet', 'today'],
#  ['hoechst', 'outpace', 'others', 'profit', 'q1', '2004'],
#  ['ficci', 'regulation', 'hurdle', 'fdi', 'projects'],
#  ['ifci', 'cheated', 'usha', 'chairman', 'cbi', 'net'],
#  ['fiis', 'net', 'buyers', 'equities', 'rs', '69', 'cr'],
#  ['applying', 'right', 'pressure', 'win'],
#  ['govt', 'provide', 'rs', '130', 'cr', 'relief', 'paradeep', 'phosphates'],
#  ['harmonise', 'food', 'laws', 'rationalise', 'taxes', 'task', 'force'],
#  ['1', '000', 'multiplexes', 'bloom'],
#  ['indian', 'investors', 'get', 'independence'],
#  ['assocham', 'moots', 'tourism', 'council', 'eastern', 'region'],
#  ['rupee', 'steady', 'dollar'],
#  ['arvind', 'mills', 'chairman', 'bow'],
#  ['ansals', 'set', 'mega', 'park', 'noida'],
#  ['world', 'knowledge', 'worker'],
#  ['bharti', 'effects', 'revamp', 'invest', 'rs', '1', '500', 'crore'],
#  ['dunlop', 'suspends', 'work', 'sahajganj', 'factory'],
#  ['hope', 'developing', 'nations', 'amidst', 'slowdown'],
#  ['india', 'ready', 'discuss', 'trade', 'issues', 'pm'],
#  ['world', 'economy', 'simultaneous', 'slump', 'report'],
#  ['rs', '45', '397', 'cr', 'fdi', 'approved', 'telecom'],
#  ['passenger', 'car', 'sales', 'maintain', 'growth', 'tempo', 'july'],
#  ['india', 'faults', 'west', 'high', 'tariff'],
#  ["cadila's", 'hi-tech', 'plant', 'gets', 'total', 'tga', 'nod'],
#  ['sinha', 'seeks', 'support', 'parties', 'pass', 'fra', 'bill'],
#  ['uk', 'firm', 'discovers', 'oil', 'kg', 'offshore'],
#  ['cid', 'probe', 'ordered', 'krushi', 'bank', 'scam'],
#  ['indian', 'cos', 'think', 'globally', 'raise', 'competitiveness'],
#  ['orange', 'overtakes', 'bpl', '1', 'cell', 'operator'],
#  ['low', 'domestic', 'prices', 'hit', 'tea', 'growers', 'returns'],
#  ['ifci', 'bailout', 'may', 'sail'],
#  ['pm', 'wants', 'a-i', 'divestment', 'hastened'],
#  ["uti's", 'position', 'threat'],
#  ['fiat', 'set', 'drive', 'palio', 'september'],
#  ['shourie', 'gives', 'tata', 'clean', 'chit'],
#  ['ifc', 'fmo', 'deg', 'invest', 'srei', 'arm'],
#  ['enron', 'moves', 'hc', 'merc', 'bias'],
#  ['hindujas', 'withdraw', 'bid', 'jessop', 'co'],
#  ['narasimham', 'keen', 'continue'],
#  ['hotel', 'corp', 'selloff', 'runs', 'deadlock'],
#  ['pioneer', 'may', 'hike', 'stake', 'mf', 'firm'],
#  ['spender', 'leaves', 'ford', 'india'],
#  ['basis', 'basmati', 'patent', 'fears'],
#  ['sensex', 'closes', '3297.47'],
#  ['patent', '3', 'basmati', 'strains', 'us'],
#  ['india', 'necessary', 'adjustments', 'indo-nepal', 'trade', 'treaty'],
#  ['bor',
#   'eyes',
#   'rs',
#   '80',
#   'cr',
#   'net',
#   'plans',
#   'recover',
#   'rs',
#   '80-85',
#   'cr',
#   'npas'],
#  ['top', 'ten', 'firms', 'post', 'rs', '900', 'cr', 'loss', 'q1'],
#  ['need', 'rush', 'competition', 'law'],
#  ['three', 'japanese', 'firms', 'may', 'work', "boeing's", 'sonic', 'jet'],
#  ['govt', 'pressure', 'industrial', 'house'],
#  ['bill', 'remove', 'cap', 'fci', 'borrowings', 'approved'],
#  ['boeing', 'airbus', 'valuers', "ai's", 'aircraft', 'fleet'],
#  ['fipb', 'okays', '29', 'fdi', 'proposals', 'worth', 'rs', '135', 'cr'],
#  ['auto', 'parts', 'makers', 'look', 'china', 'buyouts'],
#  ['npas', 'nationalised', 'banks', 'touch', 'rs', '61', '416', 'cr'],
#  ['a-i', 'bid', 'tata', 'awaits', 'sia', 'decision'],
#  ['private', 'placements', 'safe', 'bet'],
#  ['sebi', 'proposes', 'cbi', 'disposes'],
#  ['core', 'sector', 'registers', '1.2', 'growth'],
#  ['confusion', 'compounded', 'status', 'a-i', 'bidders'],
#  ['govt', 'independent', 'directors', 'sebi', 'board'],
#  ['stock', 'scam', 'jpc', 'gets', 'extension'],
#  ['auto', 'parts', 'industry', 'pens', 'survival', 'agenda'],
#  ['govt', 'induct', 'independent', 'directors', 'sebi', 'board'],
#  ['hll', 'extends', 'reach', 'door-step'],
#  ['bpcl', 'plans', 'petroleum', 'product', 'exports', 'bangladesh'],
#  ['bad', 'debts', 'bog', 'financial', 'institutions'],
#  ['bata', 'reebok', 'tie-up', 'retailing', 'partnership'],
#  ['slowdown', 'stagnates', 'real', 'estate', 'markets', 'worldwide'],
#  ['canada', '3000', 'tie', 'ia', 'jet'],
#  ['dragon', 'turns', 'endearing'],
#  ['saarc', 'concerned', 'attempts', 'expand', 'wto', 'agenda'],
#  ['shram', 'awards', 'nine', 'ntpc', 'employees'],
#  ['spender', 'leaves', 'ford', 'india'],
#  ['govt', 'review', 'factories', 'act'],
#  ['transfer', 'pricing', 'norms', 'tax', 'international', 'deals'],
#  ['sky', 'limit', "surat's", 'sari', 'czars'],
#  ['bi', 'invest', 'rs', '23cr', 'expansion'],
#  ['zee', 'channels', 'get', 'fresh', 'look'],
#  ['krushi', 'bank', 'vice', 'chairman', 'held'],
#  ['royal', 'enfield', 'roll', 'new', 'bikes', 'every', '6', 'months'],
#  ['steel', 'exports', 'register', '5', 'growth', 'april-july'],
#  ['govt', 'awaiting', 'rbi', 'guidelines', 'ssi'],
#  ['reliance', 'urged', 'start', 'gas', 'cracker', 'project'],
#  ['subhash', 'chandra', 'dilutes', 'stake', 'zee'],
#  ['a-i', 'disinvestment', 'waiting', 'bidders'],
#  ['mutual', 'funds', 'invest', 'debt'],
#  ['mumbai', 'high', 'upgrade', 'hits', 'speedbreaker'],
#  ['assocham', 'counter', 'flood', 'chinese', 'goods'],
#  ['govt', 'gets', 'rs', '7.78', 'cr', 'dividend', 'vijaya', 'bank'],
#  ['basmati', 'exports', 'expected', '6', 'lakh', 'tones'],
#  ['uppal', 'leaves', 'volvo'],
#  ['cvc', 'cag', 'nix', 'proposal', 'psus', 'strategic', 'sale'],
#  ['fis', 'play', 'match-maker', 'enron', 'sell-off'],
#  ['atlas', 'copco', 'ab', 'hikes', 'share', 'holding', 'india'],
#  ['market', 'unimpressed', 'mtnl-bsnl', 'tie-up', 'talks'],
#  ['volvo', 'india', 'eyes', 'diverse', 'roads'],
#  ['cbi', 'probe', 'forged', 'letter', 'a-i', 'selloff'],
#  ['hc', 'seeks', 'probe', "uti's", 'investment', 'ril'],
#  ['steel', 'ministry', 'seeks', 'rs', '182', 'cr', 'non-plan', 'loan'],
#  ['wide', 'income', 'disparity', 'among', 'chinese', 'workers'],
#  ['dubai', 'media', 'city', 'woos', 'indian', 'firms'],
#  ["tata's", 'taco', 'project', 'bites', 'dust'],
#  ['resolve', 'issues', 'last', 'round', 'first'],
#  ['corporation', 'bank', 'top', 'brass', 'brush', 'skills', 'iim'],
#  ['fi', 'takes', '18', 'stake', 'automartindia'],
#  ["united's", 'flight', 'fantasy'],
#  ['ifc', 'shore', 'india', 'portfolio'],
#  ['us', 'curbs', 'india', 'likely', 'says', 'enron', 'chairman'],
#  ['bidders', 'question', 'a-i', 'balance', 'sheet'],
#  ['crude', 'output', 'slips', '5.7', 'p', 'c', 'july'],
#  ['rs', '16', 'cr', 'conditional', 'bail', 'ketan', 'parekh'],
#  ['rcf', 'eyes', 'fertiliser', 'units', 'sail', 'ppl'],
#  ['brokers', 'optimise', 'derivative', 'incentive', 'scheme'],
#  ['ed', 'seeks', 'details', "ranbaxy's", 'uk', 'subsidiary'],
#  ['india', 'expand', 'itec', 'programme'],
#  ['boi', 'revises', 'interest', 'rate', 'deposits'],
#  ['allied', 'deals', 'opts', 'hzl', 'cmc'],
#  ['colorplus', 'goes', 'global', 'expands', 'indian', 'presence'],
#  ['quarter', 'balco', 'workforce', 'seeks', 'vrs'],
#  ['tcs', 'set', 'development', 'centre', 'hungary'],
#  ['bharti', 'offers', 'bank', 'guarantee', 'dot'],
#  ['rupee', 'steady', 'dollar'],
#  ['sbi', 'home', 'finance', 'raise', 'funds'],
#  ['sensex', 'moves', 'small', 'range', 'early', 'stages'],
#  ['sail', 'submit', 'alternative', 'package', 'iisco'],
#  ...]

# %% [markdown]
# ### Stemming

# %%
stemmer= PorterStemmer()
stemmed=[[] for _ in range(len(cleaned))]
for i in range(0,len(cleaned)):
    for word in cleaned[i]:
        stem_word= stemmer.stem(word)
        stemmed[i].append(stem_word)

# %%
stemmed
# Out:
# [['car', 'dealer', 'caught', 'bihar', 'sale', 'tax', 'rule'],
#  ['re-negoti', 'best', 'deshmukh', 'lender', 'so', 'centr'],
#  ['samsung', 'say', 'hello', 'cellular', 'unit', 'india'],
#  ['govt', 'lift', 'port-link', 'curb', 'import'],
#  ['ril', 'plan', 'mop', 'rs', '1', '000cr'],
#  ['eicher', 'crash', 'red', 'cut', '200', 'job'],
#  ['indo', 'rama', 'post', 'rs18cr', 'net'],
#  ['jet', 'sahara', 'wait', 'watch'],
#  ['auto', 'bodi', 'drive', 'new', 'classif', 'norm'],
#  ['us', '64', 'sunni', 'day'],
#  ['dpc', 'may', 'contest', 'merc', 'jurisdict'],
#  ['brave', 'new', 'biotech'],
#  ['begin', 'salari', 'fall'],
#  ['dgca', 'propos', 'airfar', 'upset', 'airlin'],
#  ['zee', 'art', 'program', 'turnaround'],
#  ['learn', 'check', 'right', 'isi', 'mark'],
#  ['mseb', 'plan', 'acid', 'test', 'dpc', 'phase', 'ii'],
#  ['ashok', 'leyland', 'cut', 'job', 'divis'],
#  ['fix', 'former', 'dse', 'ed', "sodhi'", 'pay', 'packag', 'lack', 'transpar'],
#  ['dd', 'metro', 'grab'],
#  ['dpc', 'signal', 'climb', 'see', 'scope', 'cut', 'power', 'tariff'],
#  ['satyam', 'say', 'may', 'face', 'manpow', 'problem'],
#  ['net', 'dip', '54', 'keep', 'payout', '55'],
#  ['better', 'late', 'never', 'nid', 'take', 'new', 'design'],
#  ['sensex', 'stay', 'bull', 'zone', 'gain', '60', 'point'],
#  ['sail', 'cut', 'loss', 'half'],
#  ['drive', 'low', 'gear'],
#  ['bewar', 'snoopwar', 'watch'],
#  ['ia', 'divest', 'may', 'roadblock', 'new', 'player', 'domest', 'sky'],
#  ['car', 'sale', 'drop', '15', 'april'],
#  ['ia', 'divest', 'may', 'roadblock', 'new', 'player', 'domest', 'sky'],
#  ['slowdown', 'hit', 'idbi', 'net', '27.3', 'rs', '691', 'cr'],
#  ['car', 'sale', 'drop', '15', 'april'],
#  ['korn', 'ferri', 'search', 'dewang', "mehta'", 'successor'],
#  ['korn', 'ferri', 'search', 'dewang', "mehta'", 'successor'],
#  ['media', 'public', 'promis', 'big', 'ad', 'spend', 'futur'],
#  ['centr', 'unveil', 'bailout', 'packag', 'madhavpura', 'bank'],
#  ['goodyear', 'roll', 'tubeless', 'radial', 'tyre', 'india'],
#  ['nationwid', 'bank', 'strike', 'juli', '4'],
#  ['mtnl', 'execut', 'cdma-wll', 'servic', 'soon'],
#  ['trai', 'moot', 'allot', 'code', 'std', 'oper'],
#  ['bharti-singtel', 'jv', 'get', 'loi', 'std', 'servic'],
#  ['hc', 'restrain', 'govt', 'recov', "whisky'", 'price', 'differ'],
#  ['ia', 'review', 'flexi-far', 'july-august'],
#  ['sportier', 'imag', 'import', 'lotu', 'elis'],
#  ['bnp', 'pariba', 'may', 'acquir', 'indian', 'bank'],
#  ['crude', 'oil', 'product', 'skid', 'fiscal'],
#  ['govt', 'nod', '13', 'pvt', 'parti', 'start', 'air', 'servic'],
#  ['bsp', 'mp', 'charg', 'sebi', 'unwilling', 'probe', 'rpl'],
#  ['fipb', 'clear', '32', 'fdi', 'propos', 'worth', 'rs', '477', 'cr'],
#  ['lg', 'launch', 'healthcar', 'product'],
#  ['jaswant', 'hold', 'talk', 'bilater', 'trade', 'wto'],
#  ['propos', 'enhanc', 'petro', 'price', 'naik'],
#  ['sabeer', "bhatia'", 'arzoo', 'remain', 'unfulfil'],
#  ['ranbaxi', 'sue', 'wilmark', 'use', 'similar', 'brand', 'name'],
#  ['dump', 'dd', 'goe', 'rebid', 'slot'],
#  ['8', 'global', 'fi', 'join', "rpl'", '500', 'loan', 'syndic'],
#  ['jaswant', 'hold', 'talk', 'bilater', 'trade', 'wto'],
#  ['yamaha', 'appeal', 'fake', 'bike', 'china'],
#  ['satyam', 'wari', 'growth', 'despit', 'robust', '2000-01'],
#  ['a-i', 'present', 'profit', 'budget', '2001-02'],
#  ['softwar', 'park', 'question', "satyam'", 'export', 'revenu'],
#  ['indian', 'american', 'disney', 'interact', 'top', 'post'],
#  ['us', 'lend', 'ear', 'india', 'steel'],
#  ['rupe', 'end', 'mildli', 'higher', 'dollar'],
#  ['en-mass', 'transfer', "balco'", 'delhi', 'offic'],
#  ['six-point', 'strategi', 'speed', 'fdi', 'flow'],
#  ['i-t', 'haul', 'firm', 'bank', 'fi', 'invest', 'tax-fre', 'bond'],
#  ['dpc', 'mseb', 'fight', 'legal', 'battl'],
#  ['tc', 'set', 'asia-pacif', 'hq', 'singapor'],
#  ['import', '300', 'sensit', 'item', '11'],
#  ['rpl', 'get', 'cabinet', 'nod', 'dilut', 'relianc', 'share'],
#  ['daewoo', 'rework', 'market', 'strategi'],
#  ['enron', 'debacl', 'would', 'dampen', 'flow', 'fdi', 'india'],
#  ['nissan', 'mitsubishi', 'cut', 'global', 'vehicl', 'output', 'may'],
#  ['strateg', 'partner', 'may', 'get', '5', 'director', 'a-i', 'board'],
#  ['duti', 'drawback', 'rate', 'partial', 'roll', 'back'],
#  ['distress', 'export', 'diesel', 'ram', 'naik'],
#  ['world', 'bank', 'announc', '913.8', 'million', 'aid', 'india'],
#  ['summertim', 'iim', 'easi', 'street'],
#  ['tata', 'sia', 'videocon', 'case', 'refer', 'cabinet'],
#  ['hll', 'unveil', 'action-plan', 'food', 'revolut'],
#  ['subsidi', 'lpg', 'kerosen', 'stay', 'naik'],
#  ['prasar', 'bharati', 'seek', 'agenc', 'monitor', 'dd', 'reach'],
#  ['siemen', 'buy-back', 'offer', 'begin', 'june', '25'],
#  ['china-russia', 'trade', 'hit', 'record', 'level'],
#  ['meet', 'finalis', 'madhavpura', 'reviv', 'plan', 'june', '25'],
#  ["satellite'", 'corrupt', 'cop', 'still', 'run'],
#  ['us', 'lose', 'key', 'wto', 'case', 'eu'],
#  ['forex', 'reserv', 'swell', '153', '43', '160'],
#  ['gaz', 'de', 'franc', 'hedg', "petronet'", 'risk'],
#  ['hdfc', 'buy', '8', 'stake', 'positra', 'sez', 'rs', '150', 'cr'],
#  ['media', 'lab', 'take', 'have-not'],
#  ['lord', 'paul', 'vest', 'interest', 'open', 'trade'],
#  ['without', 'reform', 'sustain', 'bull', 'run'],
#  ['desper', 'seek', 'disinvest'],
#  ['global', 'oil', 'major', 'queue', 'ibp', 'pie'],
#  ['balmer', 'lawri', 'demerg'],
#  ['dolphin', 'get', 'aggress', 'slash', 'call', 'rate'],
#  ['cellular', 'giant', 'born'],
#  ['offici', 'batata', 'bpl', 'announc', 'merger'],
#  ['a-i', 'share', 'deal', 'boost', 'sell-off', 'price'],
#  ['hinduja', 'pull', 'shouri'],
#  ['panel', 'call', 'free', 'agricultur', 'market'],
#  ['toontown', 'reach', 'india'],
#  ['govt', 'packag', 'face', 'difficulti', 'redeem', 'us', '64', 'fulli'],
#  ['grasim', 'industri', 'worker', 'reach', 'closur', 'agreement'],
#  ['dse', 'provid', 'liquid', 'us', '64', 'small', 'investor'],
#  ['price', 'rig', 'need', 'check'],
#  ['pak', 'studi', 'respons', 'indian', 'offer', 'reduc', 'tariff'],
#  ['g', '8', 'financ', 'minist', 'hold', 'summit', 'rome'],
#  ['china', 'dump', 'good', 'india', 'cii'],
#  ['fall', 'volum', 'may', 'forc', 'dse', 'merg', 'bse'],
#  ['telecom', 'small', 'firm', 'see', 'space', 'surviv'],
#  ['make', 'mission', 'possibl'],
#  ['make', 'uti', 'asset', 'manag', 'firm'],
#  ['us', '64', 'paid', 'earn', 'less'],
#  ['godbol', 'panel', 'recommend', 'privatis', 'mseb'],
#  ['us', '64', 'crisi', 'disastr', 'amfi', 'chief'],
#  ['strenghten', 'indo-pak', 'trade', 'tie', 'cii'],
#  ['infosi',
#   'see',
#   'rs',
#   '800',
#   'cr',
#   'profit',
#   'fiscal',
#   'q1',
#   'net',
#   'soar',
#   '56'],
#  ['distacom', 'sell', '49', 'stake', 'spice'],
#  ['bpl', 'buy', 'franc', 'telecom', 'batata'],
#  ['us', 'slowdown', 'take', 'toll', 'infosi'],
#  ['indian', 'oil', 'relianc', 'among', 'forb', 'intern', '500'],
#  ['npp', 'exempt', 'r', 'd-savvi', 'dpco'],
#  ['bharti', 'cellular', 'reduc', 'airtim', 'tariff', 'magic'],
#  ['ongc', 'nod', 'increas', 'product', 'major', 'field'],
#  ['rupe', 'end', 'bare', 'chang', 'dollar'],
#  ['essar', 'slash', 'airtim', 'tariff', 'cash', 'card'],
#  ['dupont', 'expans', 'drive', 'india'],
#  ['essel', 'sell', '50', 'lakh', 'zee', 'share', 'us', 'investor'],
#  ['bad', 'news', 'growth', 'front'],
#  ['control', 'sugar', 'industri', 'go', 'soon', 'shanta'],
#  ['shouri', 'deni', 'favour', 'tata', 'air', 'india', 'bid'],
#  ['uti', 'packag', 'like', 'today'],
#  ['dupont', 'expans', 'drive', 'india'],
#  ['pak', 'click', 'indian', 'train', 'co'],
#  ['maharaja', 'fli', 'chennai-hk', 'direct'],
#  ['investor', 'protect', 'fund', 'like', 'next', 'week'],
#  ['hc', 'issu', 'contempt', 'notic', 'netwar', 'infosi'],
#  ['biocon', 'transcorp', 'technolog', 'battl'],
#  ['govt', 'may', 'amend', 'act', 'allow', 'rbi', 'lower', 'slr'],
#  ['investor', 'urg', 'centr', 'interven', 'us', '64', 'scheme'],
#  ['wil', 'default', 'sent', 'jail', 'sinha'],
#  ['jpc', 'govt', 'set', 'train', 'gun', 'hfcl', 'zee'],
#  ['berger', 'ici', 'form', 'jv', 'make', 'auto', 'ind', 'coat'],
#  ['eli',
#   'lilli',
#   'make',
#   'india',
#   'global',
#   'bulk',
#   'drug',
#   'outsourc',
#   'hub'],
#  ['rupe', 'stage', 'mild', 'ralli'],
#  ['guidelin', 'advisor', 'bidder', 'disinvest'],
#  ['sinha', 'confid', 'achiev', 'indirect', 'tax', 'target'],
#  ['uti', 'redempt', 'rs', '2', '265', 'crore', 'june', 'amfi'],
#  ['skumar', 'flip-flop', 'e-com', 'ventur'],
#  ['improv', 'qualiti', 'boost', 'export', 'thai', 'minist'],
#  ['hc', 'order', 'bajaj', 'auto', 'make', '701', 'worker', 'perman'],
#  ['b', 'k', 'modi', 'meet', 'fi', 'today'],
#  ['promot', 'stake', 'zee', 'telefilm', '59'],
#  ['murdoch', 'upbeat', 'indian', 'market'],
#  ['bengal', 'set', 'panel', 'decid', 'fate', 'psu'],
#  ['sinha', 'meet', 'bank', 'fi', 'tackl', 'slowdown'],
#  ['improv', 'qualiti', 'boost', 'export', 'thai', 'minist'],
#  ['sugar', 'industri', 'stand', 'gain', 'wto', 'regim'],
#  ['uti', 'get', 'bank', 'loan', 'equiti', 'hold'],
#  ['divest', 'norm', 'affect', 'morgan', 'stane'],
#  ['hunt', 'nasscom', 'presid', 'last', 'leg'],
#  ['fi', 'stay', 'away', 'modi', 'rubber', 'open', 'offer'],
#  ['broker', 'meet', 'juli', '17', 'chart', 'action', 'plan'],
#  ['indo-myanmar', 'border', 'trade', 'declin'],
#  ['milit', 'reduc', 'poverti', 'kashmir'],
#  ['money', 'wise', 'brsensex', 'face', 'roller', 'coaster'],
#  ['forex', 'reserv', 'swell', '141', 'mn', '43', '596', 'mn'],
#  ['mphasi', 'sharehold', 'okay', 'equiti', 'sale', 'chrysali'],
#  ['financi', 'sector', 'reform', 'jeopardis', 'economi'],
#  ['uti', 'board', 'fail', 'firm', 'exit', 'rout', 'us', '64'],
#  ['commemor', 'coin', "beijing'", 'olymp', 'bid', 'success'],
#  ['transfer', 'price', 'rule', 'aid', 'higher', 'tax', 'collect'],
#  ['rs', '28', 'cr', 'citigroup', 'fund', 'daksh'],
#  ['fii', 'net', 'buyer', 'equiti', 'rs', '261.2', 'crore'],
#  ['uti', 'offer', 'limit', 'exit', 'announc', 'nav', 'jan'],
#  ['spice', 'talk', 'cellphon', 'major', 'merger'],
#  ['nri', 'industrialist', 'optimist', 'indo-pak', 'summit'],
#  ['indian', 'languag', 'bridg', 'digit', 'gulf'],
#  ['small', 'uti', 'investor', 'heav', 'sigh', 'relief'],
#  ['entreprenu', 'vanguard', 'growth'],
#  ['gdp', 'project', 'grow', '6.3', 'cmie'],
#  ['rbi', 'governor', 'say', 'economi', 'good', 'shape'],
#  ['inflat', 'rise', '5.16'],
#  ['activ', 'govt', 'role', 'need', 'tackl', 'fake'],
#  ['textil', 'polici', 'envisag', 'export', 'target', '50', 'b'],
#  ['fi', 'seek', 'rs', '45', 'crore', 'guarante', 'modi'],
#  ["dpc'", 'lng', 'carrier', 'deploy', 'spot', 'market'],
#  ['nri', 'industrialist', 'optimist', 'indo-pak', 'summit'],
#  ['maruti', 'invest', 'rs', '550', 'crore'],
#  ['fii', 'stake', 'mrl', 'may', 'purnendu', "chatterjee'", 'hold'],
#  ['lower', 'manufactur', 'call', 'vat', 'intern', 'competit'],
#  ['govt', 'amend', 'i-t', 'law', 'tax', 'e-commerc', 'firm'],
#  ['somebodi', 'err', 'other', 'pay', 'price'],
#  ['niit', 'cut', 'back', 'spend'],
#  ['bank', 'need', 'fund', 'becom', 'technolog', 'compet'],
#  ['mp-base', 'compani', 'record', '13', 'growth', 'cmie', 'report'],
#  ['compani', 'q3', 'turn', 'point'],
#  ['tisco', 'seek', 'acquisit', 'opportun', 'select', 'field'],
#  ['dod', 'may', 'consid', 'liberalis', 'term', 'ia', 'selloff'],
#  ['market', 'cool', 'agra', 'talk'],
#  ['ntpc', 'buy', 'enron', 'equiti', 'centr'],
#  ['j', 'j', 'irani', 'stress', 'achiev', 'target'],
#  ['govt', 'get', 'rs', '1', '486', 'cr', '4th', 'cellular', 'slot'],
#  ['telco', 'among', 'top', '10', 'loser'],
#  ['rupe', 'gain'],
#  ['us', '64', 'lose', 'game', 'investor'],
#  ['block', 'deal', 'limelight', 'listless', 'market'],
#  ['sc', 'allow', 'balco', 'plea', 'discrimin'],
#  ['strateg', 'sale', 'hold', 'least', 'prioriti', 'uti', 'chief'],
#  ['relief', 'investor', '3', '000', 'unit', 'soon'],
#  ['coca', 'cola', 'close', '2', 'plant', 'mumbai', 'pune'],
#  ['satellite-bas', 'system', 'airport', 'soon'],
#  ['psu', 'bank', 'chief', 'meet', 'uti', 'chief', 'us', '64', 'assist'],
#  ['tyco', 'make', "b'lore", 'plant', 'global', 'sourc', 'base'],
#  ['hll', 'eye', 'organ', 'tea', 'segment'],
#  ['give', 'grant', 'poor', 'countri', 'us', 'tell', 'wb'],
#  ['increas', 'bonu', 'policy-hold', 'lic'],
#  ['hc', 'stop', 'govt', 'finalis', 'cellular', 'bid'],
#  ['saga', 'it-aid', 'design'],
#  ['state', 'may', 'fix', 'margin', 'pd', 'shop', 'govt'],
#  ['insur', 'claim', 'settl', '7', 'day'],
#  ['car', 'war', 'global', 'model', 'indian', 'price'],
#  ['moet-hennessi', 'market', 'cognac', 'champagn', 'india'],
#  ['mf', 'industri', 'grew', '46.49', '1999-2000'],
#  ['auto', 'car', 'two-wheel', 'sale', 'june'],
#  ['bid', '4th', 'cellular', 'slot', 'receiv'],
#  ['hyundai', 'sonata', 'make', 'debut'],
#  ['ketan', 'deni', 'foreign', 'bank', 'account', 'ownership'],
#  ['siemen', 'q3', 'net', 'profit', '48.97'],
#  ['pay', 'first', 'fi', 'tell', 'modi'],
#  ['tisco', 'top', 'steel', 'maker', 'q1', 'net', 'crash', '79'],
#  ['india', 'inc', 'pessimist', 'industri', 'recoveri'],
#  ['ub', 'group', 'launch', 'flavour', 'water'],
#  ['govt', 'target', '50', 'bn', 'textil', 'export', '2010'],
#  ['mid-air', 'duel', "a-i'", 'futur'],
#  ['a-i', 'maruti', 'hoc', 'divest', 'joshi'],
#  ['bse', 'sub-panel', 'overse', 'corporatis', 'process'],
#  ['busi', 'bhailater'],
#  ['rupe', 'stage', 'smart', 'ralli', 'dollar'],
#  ["bush'", 'wb', 'plan', 'hit', 'india'],
#  ['badla', 'oper', 'rout', 'rs', '2', '000', 'cr', 'mf'],
#  ['vassal', 'blame', 'sebi', 'us', '64', 'crisi'],
#  ['maruti', 'price', 'go', 'soon'],
#  ['biotech', 'regul', 'may', 'face', 'hurdl'],
#  ['bajaj', 'elimin', 'hit', 'road'],
#  ['govt', 'may', 'rais', 'cess', 'petrol', 'diesel'],
#  ['rbi', 'favour', 'greater', 'freedom', 'co-op', 'bank'],
#  ['rbi', 'forese', 'higher', 'agri', 'growth', 'fiscal'],
#  ['govt', 'move', 'sc', '4th', 'cellular', 'slot', 'paswan'],
#  ['top', 'uti', 'offici', 'charg', 'fraud'],
#  ['itc', 'net', '21', 'rs', '301', 'crore', 'q1'],
#  ['forex', 'reserv', 'declin', '37', 'mn', '43', '559', 'mn'],
#  ['tax', 'collect', 'plung', '13', 'q1'],
#  ['ipcl', 'net', '64', 'rs', '12.67', 'cr', 'q1'],
#  ['rural', 'telesubscrib', 'get', 'cheap', 'deal'],
#  ['say', 'chees', 'desi', 'pizza', 'rs', '20'],
#  ['sail', 'gloom', 'time'],
#  ['money', 'wisebrlesson', 'us', '64', 'debacl'],
#  ['merril', 'lynch', 'pay', 'play', 'bull', 'boom'],
#  ['relianc', 'dot', 'ink', 'basic', 'circl', 'pact'],
#  ['vsnl', 'ventur', 'provid', 'servic', 'nepal'],
#  ['cbi', 'arrest', 'subramanyam'],
#  ['fi', 'yet', 'finalis', 'particip', "modi'", 'open', 'offer'],
#  ['bharti', 'move', 'hc', 'dot', 'follow'],
#  ['rise', 'fuel', 'cost', 'dent', "a-i'", 'bottomlin'],
#  ['yashwant', 'quit', 'demand', 'cpi'],
#  ['india', 'disinvest', 'kashmir'],
#  ['us', 'slump', 'may', 'last', 'longer', 'expect'],
#  ['pc', 'sale', 'revolut', 'sight'],
#  ['one', 'ikon', 'mani', 'model'],
#  ['mbt', 'shelv', 'ipo', 'plan', 'pvt', 'placement'],
#  ['digvijay', 'review', 'financ', "department'", 'function'],
#  ['boost', 'demand', 'reviv', 'economi'],
#  ['smoke', 'pipe', 'line', 'peac'],
#  ['sebi', 'rais', 'issu', 'broker', 'fund', 'rbi', 'say', 'mehta'],
#  ['bollywood', 'warm', 'india', 'inc'],
#  ['exid', 'jv', 'austrian', 'firm'],
#  ['crude', 'product', 'dip', '7.5', '2.48', 'mt', 'june'],
#  ['govt', 'await', 'hc', 'rule'],
#  ['telco', 'drive', 'comm', 'vehicl', 'sale', 'q2'],
#  ['rupe', 'open', 'slightli', 'weak'],
#  ['power', 'grid', 'corpor', 'invest', 'rs', '1', '100', 'crore', 'telecom'],
#  ['broker', 'go', 'one-day', 'strike'],
#  ['dragon', 'tiger', 'china', 'eye', 'india'],
#  ['bharti-singtel', 'pull', 'vsnl', 'bid'],
#  ['softwar', 'becom', 'free'],
#  ['rural', 'credit', 'like', 'go', 'rs', '86', '000', 'crore', 'report'],
#  ['centr', 'chart', 'fresh', 'norm', 'ia', 'sell-off'],
#  ['uti', 'suspend', 'offici', 'cbi', 'investig'],
#  ['multipl', 'zone', 'buy', 'back', 'mail.com', 'stake'],
#  ['stock', 'broker', 'embark', 'nationwid', 'strike'],
#  ['india', 'score', 'size', 'lose', 'red', 'tape', 'fdi'],
#  ['indian', 'household', 'ditch', 'stock', 'market', 'small', 'save'],
#  ['ril', 'invest', 'rs', '1', '500', 'cr', 'oil', 'explor'],
#  ['sebi', 'suspend', 'ace', 'stock', 'broker', 'nikhil', 'shah'],
#  ['action', 'initi', 'bpl', 'videocon'],
#  ['3', 'member', 'panel', 'probe', "uti'", 'invest', 'decis'],
#  ['govt', 'may', 'mull', 'compens', 'vsnl'],
#  ['govt',
#   'file',
#   'caveat',
#   'sc',
#   'tomorrow',
#   '4th',
#   'cellular',
#   'slot',
#   'issu'],
#  ["vsnl'", 'particip', 'cellular', 'bid', 'dismiss'],
#  ['disinvest', 'commiss', 'reconstitut'],
#  ['a-i', 'flight', 'hong', 'kong', 'singapor', 'mumbai'],
#  ['modi', 'hive', 'tyre', 'busi'],
#  ['videocon', 'withdraw', 'ia', 'bid', 'decid', 'shortli', 'vsnl'],
#  ['top', 'brass', 'simpli', 'peanut'],
#  ['bse', 'suspend', 'trade', 'dsq', 'softwar', 'juli', '30'],
#  ['indian', 'tea', 'export', 'hit', 'iran', 'ban'],
#  ['telco', 'loss'],
#  ['kawasaki', 'sourc', 'part', 'bajaj'],
#  ['tarapor', 'mum', 'uti', 'seek', 'stronger', 'regulatori', 'capabl'],
#  ['vat', 'panel', 'probe', 'revenu', 'loss', 'due', 'vat', 'vat', 'servic'],
#  ['sbi', 'icici', 'bank', 'outsmart', 'other', '3', 'year'],
#  ['ramadorai', 'appoint', 'tata', 'tech', 'chief'],
#  ['specialti', 'ranbaxi', 'call', 'day'],
#  ['hiten', "dalal'", 'arrest', 'defer'],
#  ['hinduja', 'sterlit', 'csfb', 'issu', 'show-caus', 'notic'],
#  ['verdict', 'ketan', "parekh'", 'bail', 'plea', 'tomorrow'],
#  ['hll', 'net', 'rise', 'pay', '250'],
#  ['sbi', 'q1', 'net', 'rise', '26', 'rs', '580', 'cr'],
#  ['samsung', 'india', 'h1', 'sale', '38', 'rs', '1', '247cr'],
#  ['ibm', 'invest', '10m', 'chrysali'],
#  ['irda', 'warn', 'lic', 'gic', 'uti', 'equiti', 'exposur'],
#  ['state', 'pay', 'rs', '18', '000cr', 'ntpc'],
#  ['tata', 'sack', 'five', 'top', 'execut'],
#  ['uti', 'talk', 'privat', 'bank', 'us', '64', 'packag'],
#  ['global', 'tele', 'arm', 'plan', 'techcompet', 'centr'],
#  ['ril', 'acquir', 'oil', 'ga', 'block', 'tullow'],
#  ['imf', 'wb', 'pressur', 'simplifi', 'loan', 'term'],
#  ['purpl', 'yogi', 'plan', 'makeov'],
#  ['equiti', 'suffer', 'setback', 'sell', 'pressur'],
#  ['4th', 'round', 'cellular', 'bid', 'stay', 'hold'],
#  ['dunlop', 'see', 'exodu', 'execut', 'last', '7', 'month'],
#  ['us', '64', 'separ', 'scheme'],
#  ['court', 'reject', 'ketan', "parekh'", 'bail', 'plea'],
#  ['share', 'finish', 'lower', 'sustain', 'sell'],
#  ['icici', 'lombard', 'may', 'get', 'irda', 'nod', 'tomorrow'],
#  ['govt', 'seek', "sebi'", 'opinion', 'hzl', 'delist'],
#  ['govt', 'reduc', 'stake', 'idbi', 'panel'],
#  ['gspc', 'stop', 'ga', 'suppli', 'essar', 'steel', 'plant'],
#  ['cii', 'discuss', 'jv', 'british', 'counterpart'],
#  ['cbi', 'interrog', 'arvind', 'johari', 'cyberspac'],
#  ['former', 'bse', 'presid', 'damani', 'dead'],
#  ['4', 'state', 'readi', 'buy', 'dpc', 'power'],
#  ['vsnl', 'ibp', 'sharehold', 'nod', 'like', 'sept'],
#  ['rupe', 'weaken', 'slightli', 'dollar'],
#  ['apollo', 'tyre', 'net', 'profit', 'drop', '30', 'per', 'cent'],
#  ['carrier', 'net', 'plung', '75', 'rs', '2.55', 'cr'],
#  ['canada', '3000', 'begin', 'mumbai-toronto', 'flight'],
#  ['beer', 'battl', 'hot'],
#  ['sebi', 'begin', 'proceed', 'broker', 'rahul', 'bajaj'],
#  ['busi', 'india', 'uk', 'exce', 'target'],
#  ['ec', 'launch', 'antitrust', 'proceed', 'de', 'beer'],
#  ['nanda', 'enter', 'entertain'],
#  ['devanh', 'airport', 'project', 'hit', 'roadblock'],
#  ['polari', 'pick', '25', 'stake', 'eternet', 'inc'],
#  ['uti', 'may', 'hike', 'redempt', 'limit', 'small', 'investor'],
#  ['govt', 'give', 'nod', 'investor', 'protect', 'fund'],
#  ['lot', 'store', 'hitachi', 'india'],
#  ['royal', 'philip', 'buy', 'cg', 'glass'],
#  ['589', 'wb', 'loan', 'upgrad', 'grand', 'trunk', 'road'],
#  ['indian', 'techi'],
#  ['vsnl', 'q1', 'net', '4.54'],
#  ['icici', 'net', '13'],
#  ['rpl', 'export', '1.4', 'mt', 'petro', 'product', 'q1'],
#  ['month-end', 'pressur', 'weaken', 'rupe'],
#  ['bhel', 'bag', 'rs', '18', 'cr', 'suppli', 'order', 'apgenco'],
#  ['dull', 'head-hunt', 'find', 'work', 'financ', 'insur'],
#  ['uti', 'split'],
#  ['sensex', 'worst', 'yet', 'come'],
#  ['retain', 'depb', 'export', 'incent', 'scheme', 'export'],
#  ['underinvo', 'hit', 'mmtc', 'edibl', 'oil', 'import'],
#  ['chines', 'bike', 'threat', 'india', 'yamaha'],
#  ['duralin', 'hike', 'capac', 'goa', 'plant'],
#  ['tax', 'time'],
#  ['subramanyam', '3', 'other', 'remand', 'polic', 'custodi'],
#  ['philip', 'carbon', 'stop', 'oper'],
#  ['us', 'power', 'major', 'ae', 'quit', 'cesco'],
#  ['a-i', 'valuat', 'may', 'fall', 'way', 'expect'],
#  ['psu', 'spearhead', 'growth', 'q1'],
#  ['four', 'state', 'buy', 'power', 'current', 'rate'],
#  ['ongc', 'board', 'clear', 'recast', 'plan'],
#  ['lnm', 'group', 'acquir', "romania'", 'sidex'],
#  ['godrej', 'q1', 'net', 'profit', 'rs', '11.18', 'cr'],
#  ["maharashtra'", 'offer', 'unrealist', 'dpc'],
#  ['chandra', 'open', 'dilut', 'stake', 'zee', '50'],
#  ['bajaj', 'auto', 'q1', 'net', 'inch', 'rs', '121cr'],
#  ['ipa', 'moot', 'open', 'product', 'critic', 'patent', 'drug'],
#  ['bank', 'fi', 'owe', 'rs', '900', 'cr', 'tax'],
#  ['hc', 'hear', 'pil', 'us', '64', 'scheme', 'aug', '1'],
#  ['invest', 'decis', 'make', 'power', 'bsnl', 'moot'],
#  ['cse', 'set', 'forg', 'pact', 'bse', 'deriv'],
#  ['bob', 'offer', 'rs', '300', 'cr', 'uti'],
#  ['adob', 'india', 'may', 'provid', 'softwar', 'state', 'govt'],
#  ['cse', 'worri', 'cancel', '14', 'mn', 'dsq', 'share'],
#  ['oil', 'trader', 'nationwid', 'stir', 'august', '20'],
#  ['haldia', 'petrochem', 'may', 'find', 'saviour'],
#  ['infosi', 'continu', 'top', 'growth', 'fund'],
#  ['tea', 'export', 'may', 'fall', 'year'],
#  ['uti', 'grappl', 'potenti', 'rs', '1', '700', 'cr', 'pay-out'],
#  ['land', 'compens', 'market', 'valu', 'sc'],
#  ['top', 'busi', 'magazin', 'cut', 'staff'],
#  ['subsidi', 'petro', 'product', 'rise'],
#  ['china', 'enter', 'wto', 'challeng', 'india'],
#  ['aig', 'pick', '12', 'stake', 'nagarjuna', 'refineri'],
#  ['cmc', 'htl', 'sell-off', 'like', 'august'],
#  ['bpl', 'leow', 'pact', 'see', 'big', 'pictur'],
#  ['drt', 'hear', 'boi', 'suit', "ketan'", 'co'],
#  ['next', 'godbol', 'panel', 'meet', 'may', 'cancel'],
#  ['converg', 'bill', 'tabl', 'session'],
#  ['revamp', 'corporatis', 'uti', 'demand'],
#  ['bnp', 'pariba', 'buy', 'taiwanes', 'invest', 'trust', 'report'],
#  ['lohani', 'take', 'new', 'itdc', 'chairman'],
#  ['car', 'bike', 'export', 'scooter', 'muv', 'q1'],
#  ['carrier', 'form', 'panel', 'recast'],
#  ['rupe', 'weaken', 'slightli'],
#  ['bajaj', 'capit', '3rd', 'admir', 'financi', 'firm'],
#  ['cbi', 'begin', 'probe', 'cyberspac', 'share', 'transact'],
#  ['singhania', 'stake', 'raymond', '30'],
#  ['wockhardt', 'q2', 'net', '70.68'],
#  ['fresh', 'bid', 'appoint', 'a-i', 'valuer', 'like'],
#  ['bodi', 'languag', 'speak', 'louder', 'speech'],
#  ['govt', 'work', 'packag', 'coal', 'india'],
#  ['raymond', 'foray', "women'", 'wear'],
#  ['modern', 'under-valu', 'anz', 'grindlay', 'cag'],
#  ['raymond', 'earn', 'rs', '1', '150', 'cr', 'steel', 'cement', 'hive'],
#  ['reshuffl', 'give', 'profession', 'touch', 'itdc', 'kumar'],
#  ['rupe', 'end', 'margin', 'better'],
#  ['injunct', 'fail', 'prevent', 'film', 'piraci'],
#  ['balco', 'kick', 'vr', 'union', 'appeal', 'reject'],
#  ['move', 'rais', 'import', 'duti', 'cigarett', 'sinha'],
#  ['import', 'mmtc', 'cloud', 'cbi', 'probe', 'recommend'],
#  ["pm'", 'offer', 'quit', 'make', 'short', 'impact', 'scrip'],
#  ['p', 'srivastava', 'take', 'cbdt', 'chairman'],
#  ['zee', 'net', '13', 'rs', '36.3', 'cr'],
#  ['govt', 'plan', 'regul', 'coal', 'sector'],
#  ['tabl', 'phone', 'transcript', 'uti', 'deal', 'sena'],
#  ['titan', 'ind', 'record', 'rs', '14.6', 'cr', 'net', 'loss'],
#  ['hc', 'issu', 'fresh', 'contempt', 'notic', 'netwar', 'infosi'],
#  ['agrani', 'select', 'alcatel', 'satellit', 'system'],
#  ['maharashtra', 'okay', 'divest', 'bill'],
#  ['uti', 'meet', 'eye'],
#  ['bat', 'q2', 'profit', 'rise', '7.9', 'europ', 'asia'],
#  ['k', 'j', 'udeshi', 'rbi', 'execut', 'director'],
#  ['relianc', 'keen', "enron'", 'stake', 'dpc'],
#  ['ioc', 'set', 'lpg', 'dispens', 'station', 'gangwar'],
#  ['uti', 'heed', "jpc'", 'warn', 'sinha'],
#  ['us', 'exim', 'set', 'move', 'sc', 'dabhol', 'row'],
#  ['govt', 'face', 'critic', 'bail-out'],
#  ['govt', 'okay', 'rs', '1', '000', 'cr', 'bail-out', 'ifci'],
#  ['fin', 'post', '28', 'rise', 'profit'],
#  ['lic', 'pick', '9', 'stake', 'obc', 'market'],
#  ['electron', 'export', 'jump', '72.5', '2000-01'],
#  ['indo-pak', 'sugar', 'trade', 'disput', 'erupt'],
#  ['committe', 'ask', 'govt', 'withdraw', 'tot'],
#  ['rupe', 'rock', 'steadi'],
#  ["sbi'", 'fraud', 'case', 'amount', 'rs', '269.15', 'cr'],
#  ['uti', 'readi', 'war', 'chest', 'us', '64', 'redempt'],
#  ['export', 'dip', '5', 'trade', 'deficit', 'widen', '34'],
#  ['tv', 'suzuki', 'net', 'skid', '46', 'per', 'cent'],
#  ['icra', 'unveil', 'corp', 'govern', 'rate', 'india'],
#  ['uti', 'particip', "rpl'", 'gdr', 'offer'],
#  ['birla', 'centuri', 'net', '18.98', 'q1'],
#  ['maruti', 'sale', '12', 'juli'],
#  ['singl', 'rate', 'vat', 'may', 'boost', 'economi'],
#  ['icici', 'lombard', 'get', 'nod', 'irda'],
#  ['bob', 'tie', 'amc', 'life', 'insur'],
#  ['cbi', 'ask', 'sebi', 'take', 'action', 'ed'],
#  ['industri', 'slowdown', 'lead', 'recess'],
#  ['bharti', 'offer', 'rs', '258', 'cr', 'payment'],
#  ['wipro', 'sharpen', 'focu', 'embed', 'softwar'],
#  ['dip', 'export', 'due', 'intern', 'slowdown'],
#  ['zen', 'wagonr', 'drive', 'mul', 'sale'],
#  ['firm', 'garner', 'rs', '20', 'cr', 'german', 'fair'],
#  ['rupe', 'strengthen'],
#  ['uti', 'reserv', 'turn', 'neg'],
#  ['arunach', 'decentralis', 'tea', 'cultiv'],
#  ['videocon', 'may', 'sell', 'stake', 'ravva', 'ventur'],
#  ['nine', 'psu', 'empanel', 'divest'],
#  ['german', 'bank', 'credit', 'power', 'telecom', 'project'],
#  ['gener', 'motor', 'invest', 'india'],
#  ['indo-china', 'trade', 'get', 'boost'],
#  ['b', 'muthuraman', 'new', 'tisco', 'md'],
#  ['lukewarm', 'respons', 'uti', 'repurchas'],
#  ['vr', 'central', 'govt', 'employe', 'soon', 'shouri'],
#  ['indian', 'beer', 'win', 'intern', 'acclaim'],
#  ['cse', 'may', 'suspend', 'trade', 'dsq', 'softwar'],
#  ['bajaj', "auto'", 'vr', 'get', 'lukewarm', 'respons'],
#  ['us', 'banker', 'follow', 'shariah', 'strike', 'gold'],
#  ['cii', 'deleg', 'meet', 'us', 'offici', 'steel'],
#  ['karnik', 'look', 'rebuild', 'nasscom'],
#  ['uti', 'crisi', 'usual', 'public', 'pay', 'price'],
#  ['anti-dump', 'duti', 'theophyllin', 'caffein', 'import'],
#  ['ae', 'pullout', 'affect', 'privatis', 'prabhu'],
#  ['bentley', 'car', 'rs', '1', 'cr'],
#  ['uti', 'chief', 'promis', 'cleanup', 'job'],
#  ['cancel', 'dpc', 'phase-i', 'reviv', 'phase-ii', 'mistak'],
#  ['mrtpc', 'give', 'clean', 'chit', 'daewoo'],
#  ['financi', 'sector', 'face', 'crisi', 'confid', 'vittal'],
#  ['bank', 'india', 'open', 'branch', 'china', 'vietnam'],
#  ['uti', 'receiv', 'applic', 'repurchas', '2.22', 'crore', 'unit'],
#  ['india', 'potenti', 'garner', '100', 'bn', 'fdi', '5', 'yr'],
#  ['equiti', 'rise', 'smartli', 'nse'],
#  ['singl', 'rbi', 'nomine', 'appropri'],
#  ['kyoto', 'enjoy', 'back', 'g', '77', 'nation'],
#  ['petronet', 'seal', 'lng', 'chain', 'ink', 'ga', 'sale', 'mou'],
#  ['closur', 'psu', 'last', 'resort', 'govt'],
#  ['china', 'lift', 'restrict', 'pvt', 'enterpris'],
#  ['soni', 'get', '808', 'mn', 'credit', 'line'],
#  ['govt', 'allay', 'fear', 'inflat'],
#  ['ae', 'pull', 'orissa', 'crisi', 'galor'],
#  ['ifci', 'enquir', 'modern', 'syntex', 'account'],
#  ['sahara', 'tie', 'foreign', 'airlin'],
#  ['bhel', 'bag', 'rs', '10', 'cr', 'order', 'ongc'],
#  ['resign', 'help', 'sinha'],
#  ['uti', 'may', 'dig', 'reserv', 'fund'],
#  ['mp', 'love', 'bombay', 'high'],
#  ['sensex', 'recov', '2.27', 'last', 'week'],
#  ['sinha', 'rule', 'resign', 'uti', 'muddl'],
#  ['data', 'storag', 'domin', 'spend'],
#  ['uti', 'firm', 'strateg', 'sale', 'dud', 'firm'],
#  ['air', 'nz', 'deal', 'forc', 'sia', 'rethink', 'a-i'],
#  ['ulip', 'keep', 'uti', 'flag', 'high'],
#  ['uti', 'may', 'suspend', 'us', '64', 'sale', 'indefinit'],
#  ['former', 'wiproit', 'make', 'big', 'techi', 'world'],
#  ['cyberspac', 'wrong', 'invest', 'decis', 'sinha'],
#  ['potenti', 'tap', '100', 'bn', 'fdi', '5', 'yr'],
#  ['itc', 'open', 'relat', 'area'],
#  ['hdfc', 'standard', 'life', 'break', 'even', '5', 'year'],
#  ['itc', 'chairman', 'bat', 'increas', 'stake', 'vst'],
#  ['wll', 'mobil', 'phone', 'punjab', 'march', '2002'],
#  ['save', 'dabhol'],
#  ['sbi', 'forex', 'profit', 'downsw'],
#  ['ioc', 'hike', 'servo', 'price'],
#  ['volta', 'exoner', 'unfair', 'trade', 'charg'],
#  ['hpcl', 'complet', 'bhatinda', 'refineri', 'dec', '2005'],
#  ['fiiss', 'mf', 'oper', 'contrast', 'juli', 'sebi'],
#  ['kiran', 'karnik', 'succeed'],
#  ['bharti', 'initi', 'talk', 'rs', '3000', 'cr', 'debt'],
#  ['b2b', 'transact', 'volum', 'touch', 'rs', '51', '000', 'cr'],
#  ['cse', 'board', 'discuss', 'dsq', 'suspens', 'tuesday'],
#  ['face', 'offbrth', 'silver', 'line', 'hcl'],
#  ['forc', 'rescind', 'ppa', 'mseb'],
#  ['niit', 'add', '2', 'sbu', 'retail', 'transport'],
#  ['regulatori', 'framework', 'must', 'media', 'industri'],
#  ['tough', 'time', 'consum', 'durabl', 'firm', 'warn', 'icra'],
#  ['cyberspac', 'scam', 'get', 'financi', 'trap'],
#  ['bpl', 'appoint', 'i-sec', 'sell', 'maharashtra', 'cellular', 'licenc'],
#  ['pharma', 'growth', 'plan', 'enchant', 'industri', 'analyst'],
#  ['a-i', 'earn', 'rs', '245', 'cr', 'via', 'seat', 'share'],
#  ['telco', 'bajaj', 'forse', 'higher', 'growth', 'net', 'profit'],
#  ['vsnl', 'notifi', 'vr', 'employe'],
#  ['parliament', 'approv', 'repeal', 'bank', 'compani', 'act'],
#  ['anti-dump', 'case', 'porcelain', 'tile', 'import', 'china'],
#  ['ford', 'reduc', 'cost', 'ownership'],
#  ['crompton', 'greav', 'recast', 'come', 'red'],
#  ['tata', 'file', 'fir', 'dilip', 'pends', '5', 'other'],
#  ['india', 'press', 'limit', 'agenda', 'wto', 'talk'],
#  ['tata', 'hugh', 'explor', 'telecom', 'tie-up'],
#  ['indian', 'firm', 'invit', 'set', 'unit', "china'", 'sez'],
#  ['propos', 'divest', 'sail', 'govt'],
#  ['tvs-suzuki', 'report', '4', 'juli', 'sale'],
#  ['dd', 'open', 'fresh', 'bid', 'metro', 'primetim'],
#  ['bifr', 'ask', 'torrent', 'sort', 'differ', 'creditor'],
#  ['sia', 'sought', '49', 'stake', 'a-i'],
#  ['honda', 'launch', 'activa', 'delhi'],
#  ['nigeria', 'technolog', 'corp', 'india'],
#  ['fieo', 'weclom', "sbi'", 'move', 'cut', 'plr'],
#  ['nse', 'expel', 'ashoka', 'industri', 'resourc'],
#  ['maruti', 'hike', 'car', 'price', 'today'],
#  ['cvc', 'order', 're-tend', 'rs', '1', '000', 'crore', 'dot', 'contract'],
#  ['sc', 'transfer', 'enron', 'issu', 'bombay', 'hc'],
#  ['differ', 'ia', 'a-i', 'divest', 'yadav'],
#  ['catch', 'em', 'young', 'kid', 'consum'],
#  ['thermax', 'announc', 'vr', 'employe'],
#  ['pcb', 'pull', 'take', 'action', 'eil'],
#  ["enron'", 'dpc', 'extrem', 'pleas', 'sc', 'rule'],
#  ['india', 'austria', 'sign', 'doubl', 'taxat', 'treati'],
#  ['gartner', 'upbeat', 'face', 'gloomi', 'doomi', 'mart'],
#  ['jalan', 'declin', 'comment', 'ifci', 'bailout'],
#  ['godbol', 'panel', 'report', 'applic', 'relianc', 'power'],
#  ['china', 'revamp', 'economi', 'ahead', 'wto', 'entri'],
#  ['jk', 'industri', 'delist', 'delhi', 'bours'],
#  ['wheat', 'export', 'hit', 'new', 'low', 'despit', 'demand', 'rise'],
#  ['raymond', 'acquir', 'hindustan', 'ga', 'arm'],
#  ['former', 'uti', 'chief', 'subramanyam', 'get', 'bail'],
#  ['favour', 'wireless', 'user', 'caus', 'rs', '24', 'cr', 'loss'],
#  ['govt', 'give', 'ifci', 'rs', '400', 'cr'],
#  ['sensex', 'slide', '11', 'point'],
#  ['p', 'downgrad', 'seen', 'littl', 'impact'],
#  ['dpc', 'warn', 'mseb', 'inform', 'praya'],
#  ['price', '3', 'bulk', 'drug', 'slash'],
#  ['strength', 'direct', 'market'],
#  ['tata', 'file', 'fir', 'dilip', 'pends', '5', 'other'],
#  ['cement', 'sale', 'product', 'dip', 'juli'],
#  ['gross', 'fiscal', 'deficit', 'soar', 'rs', '42', '000', 'cr'],
#  ['rupe', 'steadi', 'us', 'dollar'],
#  ['78', 'bn', 'requir', 'improv', 'tele-dens', 'paswan'],
#  ['govt', 'may', 'lower', 'bank', 'guarante', 'ibp'],
#  ['india', 'propos', 'chang', 'wto', 'subsidi', 'pact'],
#  ['bhel', 'bag', 'rs', '280', 'crore', 'order', 'us'],
#  ['govt', 'may', 'agre', 'reduc', 'stake', 'boi'],
#  ['india', 'take', 'wto', 'issu', 'ustr'],
#  ['pnb', 'extend', 'rs', '300-400', 'cr', 'uti', 'sub-plr'],
#  ['govt', 'issu', 'norm', 'diagnost', 'lab'],
#  ['govt', 'clear', 'fdi', 'propos', 'worth', 'rs', '980', 'cr'],
#  ['telecom', 'deal', 'spearhead', 'activ'],
#  ['govt', 'allow', 'bilater', 'flight', 'kochi'],
#  ['us', 'allow', 'duty-fre', 'access', '42', 'indian', 'good'],
#  ['honda', 'export', '2', 'wheeler', 'india'],
#  ["idbi'", 'financ', 'spotlight'],
#  ['mid-siz', 'car', 'segment', 'fail', 'keep', 'promis'],
#  ["p'", 'downgrad', 'attract', 'mix', 'reaction'],
#  ['dpc', 'charg', 'power', 'regul', 'bia'],
#  ['srichakra', 'lure', 'young', 'mind', 'colour', 'tyre'],
#  ['p', 'downgrad', 'affect', 'fdi', 'divest'],
#  ['bp',
#   'amoco',
#   'told',
#   'pay',
#   'rs',
#   '350',
#   'per',
#   'share',
#   'castrol',
#   'stake'],
#  ['sia', 'rais', 'stake', 'a-i', 'post-selloff'],
#  ['realiti', 'check', 'entermedia'],
#  ['lock-in', 'period', 'hugh', 'promot', 'extend'],
#  ['build', 'custom', 'relationship', 'sale'],
#  ['satnam', 'offer', 'ready-to-cook', 'product'],
#  ['investor', 'trust', 'analyst', 'doubt', 'remain'],
#  ['indo', 'rama', 'keen', 'invest', 'butibori', 'plant'],
#  ['dalmia', 'welcom', 'bp', "amoco'", 'offer', 'castrol', 'stake'],
#  ['dabhol', 'examin', 'custom', 'duti', 'notic'],
#  ['mill', 'produc', 'sugar', 'electr'],
#  ["moody'", 'slash', 'india', 'outlook'],
#  ['evangelist', 'fud-g', "developer'", 'act'],
#  ['govt', 'headhunt', 'littl', 'placement'],
#  ['realiti', 'check', 'entermedia'],
#  ['rate', 'agenc', 'wrong', 'sinha'],
#  ['sinha', 'allay', 'fear', 'rupe', 'fall'],
#  ['centr', 'buy', 'enron', 'hold', 'dpc'],
#  ['govt', 'allow', 'bilater', 'flight', 'kochi'],
#  ["dabhol'", '1', 'bn', 'offer', 'costli', 'say', 'mseb'],
#  ['enron', 'offer', 'sell', 'stake', 'cost'],
#  ['slowdown', 'hit', 'car', 'sale'],
#  ['star', 'pick', 'major', 'stake', 'vijay', 'tv'],
#  ['railtel', 'corp', 'invest', 'rs', '700', 'cr', 'ofc', 'network'],
#  ['p', 'lower', 'rate', 'outlook', 'bank'],
#  ['rupe', 'eas', 'margin', 'ground'],
#  ['dabhol', 'examin', 'custom', 'duti', 'notic'],
#  ['fdi', 'expect', 'maran'],
#  ['germani', 'switch', 'dm', 'euro'],
#  ['india', 'call', 'wto', 'agenda', 'talk'],
#  ['nasscom', 'promot', 'adopt'],
#  ['diversifi', 'market', 'export'],
#  ['bpl', 'ispat', 'set', 'achiev', 'financi', 'closur'],
#  ['russia', 'would', 'welcom', 'mig-at', 'deal', 'india'],
#  ['govt', 'extend', 'purchas', 'prefer'],
#  ['industri', 'growth', 'dip', '1.5', 'june'],
#  ['vat', 'clean', 'tax', 'system', 'sinha'],
#  ['onion', 'export', 'cap', 'rein', 'price'],
#  ['suspens', 'continu', "sia'", 'bid', 'air-india'],
#  ['dpc', 'move', 'mumbai', 'high', 'court'],
#  ['pil', 'challeng', 'us', '64', 'withdrawn'],
#  ['india', 'push', 'totalis', 'pact', 'us'],
#  ['alemb', 'seek', 'jv', 'enter', 'us', 'european', 'market'],
#  ['hinduja', 'term', 'show', 'caus', 'notic', 'malafid'],
#  ['sinha', 'find', 'friend', 'king'],
#  ['rbi', 'issu', 'guidelin', 'financ', 'film'],
#  ['coffee-consum', 'countri', 'bail', 'grower'],
#  ['anti-aid', 'drug', 'cost', 'less'],
#  ['sil', 'mull', 'tie-up', 'oil', 'psu'],
#  ['fdi', 'upto', 'expect', 'maran'],
#  ['govt', 'put', "idbi'", 'financ', 'spotlight'],
#  ['panel', 'devis', 'hardwar', 'action', 'plan'],
#  ['russia', 'open', 'mig-at', 'deal', 'india'],
#  ['tata', 'may', 'buy', "enron'", 'stake', 'dabhol', 'power'],
#  ['introduct', 'vat', 'would', 'revolutionari', 'step', 'sinha'],
#  ['cbi', 'arrest', 'ketan', 'parekh'],
#  ['ketan', 'parekh', 'interrog', 'cbi'],
#  ['rupe', 'stage', 'mild', 'ralli', 'us'],
#  ['ttk', 'make', 'smart', 'move', 'cooker', 'world'],
#  ['india', 'studi', "china'", 'like', 'wto', 'entri'],
#  ['hinduja', 'term', 'dod', 'notic', 'unfair'],
#  ["leyland'", 'juli', 'sale', '7.6'],
#  ['govt', 'may', 'margin', 'hike', 'kerosen', 'lpg', 'price'],
#  ['rbi', 'favour', 'self-regulatori', 'norm', 'mfi'],
#  ['ketan', 'parekh', 'back', 'cbi', 'custodi'],
#  ['inter', 'gold', 'launch', "men'", 'jewelleri', 'rang'],
#  ['amtek', 'auto', 'acquir', 'whfl'],
#  ['govt', 'heart', 'bleed', 'corpor', 'pension'],
#  ['forex', 'reserv', 'rise', '127', '43', '809'],
#  ['skoda', 'chart', 'new', 'plan', 'import', 'car', 'india'],
#  ['asia', 'pacif', 'enterpris', 'meet', 'tomorrow'],
#  ['check', 'safe', 'index', 'fund'],
#  ['pollut', 'free', 'energi', 'fuel', 'cell'],
#  ["india'", 'crude', 'product', 'dip', '7.5'],
#  ['iip', 'grow', '4.5', '2001-02'],
#  ["enron'", 'exit', 'countdown', 'begin', 'nov', '19', '2001'],
#  ['imc', 'moot', 'plan', 'reviv', 'economi'],
#  ['bhel', 'implement', 'montek', 'committe', 'recommend'],
#  ['ignit', 'espresso', 'engin'],
#  ['dalmia', 'may', 'acquir', '40', 'stake', 'revathi', 'equip'],
#  ['cse', 'work', 'introduc', 'margin', 'trade'],
#  ["peta'", 'demand', 'could', 'advers', 'affect', 'leather', 'industri'],
#  ['tea', 'board', 'hire', 'f', 'ferguson', 'review', 'function'],
#  ['malwa', 'foray', 'sew', 'thread', 'oswal', 'name'],
#  ['fii', 'net', 'buyer', 'equiti', 'rs', '168.5', 'cr'],
#  ['centuri', 'extrus', 'submit', 'fresh', 'rehab', 'scheme'],
#  ['fi', 'agre', 'fund', '16', '000', 'mw', 'pvt', 'project'],
#  ['centr', 'ask', 'ntpc', 'buy', 'enron', 'stake', 'dabhol'],
#  ['b', 'volvo', 'approach', 'hc', 'protect', 'brand', 'name'],
#  ['inflat', 'remain', 'stuck', '4.96'],
#  ['sale', 'top', '10', 'compani', '14', 'q1'],
#  ['india', 'inc', 'salut', 'winner', 'among', 'winner'],
#  ['vat', 'would', 'result', 'regist', 'trader'],
#  ['idbi', 'fix', 'ifci', 'bailout'],
#  ['india', 'record', 'healthi', '6', 'growth', 'power', 'gener'],
#  ['plea', 'bifr', 'order', 'gtc', 'case', 'dismiss'],
#  ['export', 'promot', 'scheme', 'prove', 'expens'],
#  ['export', 'vegetarian', 'food', 'rise'],
#  ['ongc', 'bid', '400', 'ril', '350', "enron'", 'panna-mukta', 'stake'],
#  ['mig', 'man', 'mohanti', 'next', 'hal', 'chairman'],
#  ['centr', 'unveil', 'medium', 'term', 'export', 'polici'],
#  ['alstom', 'focu', 'core', 'busi', 'revamp', 'bid'],
#  ['polic', 'seiz', 'document', 'ex-md', 'tata', 'financ'],
#  ['fii', 'reduc', 'stake', 'dabur', 'india', '6.43'],
#  ['sebi', 'tell', 'dse', 'retain', 'davar', 'board'],
#  ['ril', 'hll', 'fall', 'sell', 'pressur'],
#  ['bajoria', 'hold', 'bombay', 'dye', 'cross', '5'],
#  ['govt', 'may', 'buy', 'back', 'equiti', 'neyv', 'lignit'],
#  ['ap', 'set', 'get', 'six', 'power', 'project'],
#  ['ongc', 'bid', '400m', "enron'", 'panna-mukta'],
#  ['kingfish', 'sell', '614m', 'pound', 'properti'],
#  ['new', 'ba', 'servic', 'take', 'competit'],
#  ['export', 'financ', 'rate', 'may', 'see', 'downward', 'trend'],
#  ['uti', 'investor', 'die-hard', 'loyalist'],
#  ['govt', 'decid', 'hinduja', 'a-i', 'bid', '10', 'day'],
#  ['telco', 'cut', 'right', 'issu'],
#  ['cabinet', 'panel', 'clear', 'project', 'worth', 'rs', '590', 'cr'],
#  ['deesh', 'offer', 'cheapest', 'colour', 'tv'],
#  ['unoc', 'propos', 'jv', 'ioc'],
#  ['stock', 'lead', 'recoveri', 'fresh', 'fii', 'buy'],
#  ['rupe', 'eas', 'margin', 'dollar'],
#  ['uti', 'sought', 'fresh', 'loan'],
#  ['indusind', 'launch', 'news', 'channel'],
#  ['ia', 'cut', 'mumbai-delhi', 'one-way', 'economi', 'fare'],
#  ['samsung', 'eye', 'rs', '1', '300', 'crore', 'turnov'],
#  ['rbi', 'supercess', 'krushi', 'board'],
#  ['icici', 'maintain', 'growth', 'despit', 'slowdown'],
#  ['letter', 'comfort', 'issu', 'ifci', 'bailout'],
#  ['hinduja', 'keen', 'buy', "enron'", 'dpc', 'stake'],
#  ['sebi', 'announc', 'futur', 'trade'],
#  ['sterlit', 'buyback', 'offer', 'cloud', 'sebi', 'ban'],
#  ['ccea', 'clear', 'rail', 'power', 'project'],
#  ['uti', 'advanc', 'us', '64', 'nav', 'announc'],
#  ['sebi', 'allow', 'bank', 'fii', 'deriv', 'market'],
#  ['skill', 'quit', 'jolt', 'enron'],
#  ['stock', 'market', 'function', 'reform', 'pm'],
#  ['medium', 'term', 'export', 'strategi', 'septemb'],
#  ['foreign', 'carrier', 'lower', 'commiss'],
#  ['clash', 'titan'],
#  ['anti-dump', 'probe', 'panel', 'set'],
#  ['mechan', 'monitor', 'drug', 'price', 'hike', 'of'],
#  ['bpl-batata', 'talk', "spice'", 'karnataka', 'circl'],
#  ['petroleum', 'product', 'export', 'vault', 'ten-fold'],
#  ['unit', 'start', 'non-stop', 'us-india', 'flight'],
#  ['woe', 'reserv', 'staff', 'recruit', 'need'],
#  ['ratan', 'tata', 'offer', 'step'],
#  ['corporatis', 'rli', 'card'],
#  ['pm', 'paint', 'rosi', 'pictur', 'amid', 'econom', 'gloom'],
#  ['bangalor', 'bioinformat', 'compani', 'expans', 'mode'],
#  ['motorola', 'see', 'job', 'cut', 'ariz', 'chip', 'line', 'go'],
#  ['heavyweight', 'steadi', 'sensex'],
#  ['coop', 'entri', 'insur', 'sector', 'oppos'],
#  ['kinet', 'eye', 'non-lif', 'life', 'insur', 'sector'],
#  ['mechan', 'monitor', 'drug', 'price', 'hike', 'of'],
#  ['small', 'medium', 'firm', 'face', 'rough', 'weather'],
#  ['india', 'steamship', 'chart', 'rs', '625', 'crore', 'expans'],
#  ['tandon', 'appoint', "pepsico'", 'vp'],
#  ['tenth', 'plan', 'approach', 'await', 'cabinet', 'nod'],
#  ['bengal', 'govt', 'sign', 'mou', 'microsoft'],
#  ['repli', 'notic', 'sent', 'law', 'ministri'],
#  ['hinduja', 'pull', 'race', 'ibp'],
#  ['american', 'gener', 'sharehold', 'approv', 'aig', 'bid'],
#  ['krushi', 'bank', 'account', 'frozen', 'board', 'scrap'],
#  ['philip', 'outsourc', 'vcr', 'product'],
#  ['telco', 'shine', 'despit', 'loss'],
#  ["laloo'", 'yt', 'websit'],
#  ['chandra', 'talk', 'offload', 'stake', 'ztl'],
#  ['nasscom', 'decentralis', 'open', 'region', 'chapter'],
#  ['us', 'airway', 'announc', 'three-stag', 'restructur', 'plan'],
#  ['ua', 'plan', 'non-stop', 'flight'],
#  ['firm', 'float', 'call', 'centr', 'retain', 'subscrib', 'base'],
#  ['p', 'coke', 'scale', 'back', 'plan', 'big', 'joint', 'ventur'],
#  ['trim', '2', '200', 'job', 'back', '6', 'day', 'week'],
#  ['indo', 'rama', 'deni', 'takeov', 'threat'],
#  ['ia', 'introduc', 'walk-in', 'flight', 'delhi-mumbai', 'sector'],
#  ['tata', 'power', 'acquir', 'transmiss', 'arm'],
#  ['india', 'isol', 'wto', 'assert', 'maran'],
#  ['bhel', 'bag', 'rs', '2', '079', 'cr', 'order', 'ntpc'],
#  ['tc', 'team', 'lead', 'telecom', 'co', 'voip'],
#  ['cabinet', 'nod', 'electr', 'bill'],
#  ['leelaventur', 'eye', 'hampi', 'hassan'],
#  ['injunct', 'oyzterbay', 'coo', 'vacat'],
#  ['indo-u', 'agreement', 'power', 'manag'],
#  ['biotech', 'export', 'total', 'rs', '1072', 'cr'],
#  ['rbi', 'transfer', 'rs', '9', '350', 'cr', 'dividend', 'govt'],
#  ['japanes', 'firm', 'see', 'chines', 'import', 'threat'],
#  ['maruti', 'launch', 'car', 'disabl'],
#  ['sri', 'lankan', 'airlin', 'resum', 'flight', 'new', 'delhi'],
#  ['asci', 'spread', 'awar', 'mislead', 'ad'],
#  ['whirlpool', 'expand', 'product', 'base'],
#  ['govt', 'dpc', 'set', 'begin', 'concili', 'process'],
#  ['govt', 'may', 'dilut', 'stake', 'hindustan', 'zinc'],
#  ['talk', 'dhabol', 'power', 'begin', 'tomorrow'],
#  ['centr', 'take', 'dhabol', 'project'],
#  ['kapil', 'dev', 'promot', 'indian', 'tourism'],
#  ['festiv', 'celebr', 'harley-davidson'],
#  ['ia', 'induct', '4', '320', 'aircraft'],
#  ['sterlit', 'industri', 'contest', 'notic', 'disqualif'],
#  ['cabinet', 'nod', 'insolv', 'bill'],
#  ['godbol', 'panel', 'submit', 'report', '2-3', 'week'],
#  ['rupe', 'weaken', 'slightli', 'dollar'],
#  ['mico', 'bosch', 'fear', 'pinch'],
#  ['cabinet', 'approv', 'bill', 'remedi', 'sick', 'industri'],
#  ['dabur', 'scout', 'partner', 'genom', 'project'],
#  ['nppa', 'revis', 'price', '49', 'formul', 'pack'],
#  ['news', 'corp', 'earn', 'slip', 'await', 'better', 'time'],
#  ['spammer', 'creat', 'havoc', 'virtual', 'world'],
#  ['white', 'paper', 'tn', 'reveal', 'fiscal', 'eros'],
#  ['wipro', 'forg', 'allianc', 'symantec'],
#  ['kinet', 'ventur', 'auto', 'ancillari'],
#  ['ranbaxi', 'get', 'dgci', 'nod', 'market', 'ciprofloxacin'],
#  ['tata', 'financ', 'move', 'rbi', 'relief'],
#  ['npcil', 'plan', 'add', '11', '000', 'mw'],
#  ['rbi', 'conduct', 'sale', 'kerala', 'govt', 'bond'],
#  ['ketan', 'parekh', 'remand', 'cbi', 'custodi', 'till', 'aug', '24'],
#  ['exodu', 'surviv', 'sellout'],
#  ['money', 'wisebrgilt', 'offer', 'safe', 'invest'],
#  ['uti', 'seek', 'nod', 'trade', 'us', '64', 'unit'],
#  ['ap', 'order', 'confisc', 'properti', 'krushi', 'case'],
#  ['termin', 'notic', '35', 'isp'],
#  ['eih', 'withdraw', 'preferenti', 'issu'],
#  ['privat', 'mutual', 'fund', 'big', 'draw'],
#  ['centr', 'mull', 'demand', 'reviv', 'azmjahi', 'mill'],
#  ['messeng', 'vulner', 'newer', 'virus'],
#  ['fm', 'news', 'channel', 'debut', 'sept'],
#  ['cbi', 'chargesheet', '5', 'centuri', 'scam'],
#  ['wipro', 'forg', 'allianc', 'symantec'],
#  ["hardware'", 'hardtalk', 'fm'],
#  ['fm', 'assur', 'tax', 'sop', 'hardwar', 'sector'],
#  ['govt', 'mull', 'revis', 'payment', 'mechan', 'ipp'],
#  ['industri', 'captain', 'join', 'hand', 'water', 'man'],
#  ['coffe', 'earn', 'fall'],
#  ['cvc', 'await', 'report', 'recommend', 'vora', 'idbi', 'chairman'],
#  ['auto-ancillari', 'industri', 'look', 'abroad', 'fresh', 'leas', 'life'],
#  ['futur', 'hold', 'h1b', 'worker'],
#  ['nutraceut', 'co', 'british', 'biolog', 'enter', 'uk'],
#  ['inflat', 'rise', '5.22'],
#  ['hsbc', 'launch', 'new', 'servic'],
#  ['infosi', 'relianc', 'admir', 'compani'],
#  ['cvc', 'favour', 'us', 'model', 'capit', 'market'],
#  ['global', 'slump', 'drag', 'export', '2.7', '2002'],
#  ['pm', 'plan', 'oper', 'arrest', 'econom', 'slowdown'],
#  ['shantha', 'biotech', 'want', 'move', 'andhra'],
#  ['alert', 'get', 'vehicl', 'insur'],
#  ['fipb', 'spike', 'skoda', 'propos', 'import', 'octavia', 'cbu'],
#  ['enron', 'ae', 'issu', 'dent', "india'", 'imag', 'us', 'regul'],
#  ['hzl', 'disinvest'],
#  ['sebi', 'ask', 'thoma', 'cook', 'explain', 'delay'],
#  ['ae', 'accus', 'orissa', 'govt', 'interfer'],
#  ['pioneer', 'may', 'hike', 'stake', 'mf', 'firm'],
#  ['ambani', 'premji', 'n', 'r', 'murthi', 'best', 'ceo'],
#  ['concili', 'process', 'enron', 'adjourn'],
#  ['vittal', 'favour', 'us', 'style', 'capit', 'market'],
#  ['assocham', 'set', 'bodi', 'prudenti', 'norm'],
#  ['debt', 'fund', 'safest', 'bet', 'today'],
#  ['hoechst', 'outpac', 'other', 'profit', 'q1', '2004'],
#  ['ficci', 'regul', 'hurdl', 'fdi', 'project'],
#  ['ifci', 'cheat', 'usha', 'chairman', 'cbi', 'net'],
#  ['fii', 'net', 'buyer', 'equiti', 'rs', '69', 'cr'],
#  ['appli', 'right', 'pressur', 'win'],
#  ['govt', 'provid', 'rs', '130', 'cr', 'relief', 'paradeep', 'phosphat'],
#  ['harmonis', 'food', 'law', 'rationalis', 'tax', 'task', 'forc'],
#  ['1', '000', 'multiplex', 'bloom'],
#  ['indian', 'investor', 'get', 'independ'],
#  ['assocham', 'moot', 'tourism', 'council', 'eastern', 'region'],
#  ['rupe', 'steadi', 'dollar'],
#  ['arvind', 'mill', 'chairman', 'bow'],
#  ['ansal', 'set', 'mega', 'park', 'noida'],
#  ['world', 'knowledg', 'worker'],
#  ['bharti', 'effect', 'revamp', 'invest', 'rs', '1', '500', 'crore'],
#  ['dunlop', 'suspend', 'work', 'sahajganj', 'factori'],
#  ['hope', 'develop', 'nation', 'amidst', 'slowdown'],
#  ['india', 'readi', 'discuss', 'trade', 'issu', 'pm'],
#  ['world', 'economi', 'simultan', 'slump', 'report'],
#  ['rs', '45', '397', 'cr', 'fdi', 'approv', 'telecom'],
#  ['passeng', 'car', 'sale', 'maintain', 'growth', 'tempo', 'juli'],
#  ['india', 'fault', 'west', 'high', 'tariff'],
#  ["cadila'", 'hi-tech', 'plant', 'get', 'total', 'tga', 'nod'],
#  ['sinha', 'seek', 'support', 'parti', 'pass', 'fra', 'bill'],
#  ['uk', 'firm', 'discov', 'oil', 'kg', 'offshor'],
#  ['cid', 'probe', 'order', 'krushi', 'bank', 'scam'],
#  ['indian', 'co', 'think', 'global', 'rais', 'competit'],
#  ['orang', 'overtak', 'bpl', '1', 'cell', 'oper'],
#  ['low', 'domest', 'price', 'hit', 'tea', 'grower', 'return'],
#  ['ifci', 'bailout', 'may', 'sail'],
#  ['pm', 'want', 'a-i', 'divest', 'hasten'],
#  ["uti'", 'posit', 'threat'],
#  ['fiat', 'set', 'drive', 'palio', 'septemb'],
#  ['shouri', 'give', 'tata', 'clean', 'chit'],
#  ['ifc', 'fmo', 'deg', 'invest', 'srei', 'arm'],
#  ['enron', 'move', 'hc', 'merc', 'bia'],
#  ['hinduja', 'withdraw', 'bid', 'jessop', 'co'],
#  ['narasimham', 'keen', 'continu'],
#  ['hotel', 'corp', 'selloff', 'run', 'deadlock'],
#  ['pioneer', 'may', 'hike', 'stake', 'mf', 'firm'],
#  ['spender', 'leav', 'ford', 'india'],
#  ['basi', 'basmati', 'patent', 'fear'],
#  ['sensex', 'close', '3297.47'],
#  ['patent', '3', 'basmati', 'strain', 'us'],
#  ['india', 'necessari', 'adjust', 'indo-nep', 'trade', 'treati'],
#  ['bor',
#   'eye',
#   'rs',
#   '80',
#   'cr',
#   'net',
#   'plan',
#   'recov',
#   'rs',
#   '80-85',
#   'cr',
#   'npa'],
#  ['top', 'ten', 'firm', 'post', 'rs', '900', 'cr', 'loss', 'q1'],
#  ['need', 'rush', 'competit', 'law'],
#  ['three', 'japanes', 'firm', 'may', 'work', "boeing'", 'sonic', 'jet'],
#  ['govt', 'pressur', 'industri', 'hous'],
#  ['bill', 'remov', 'cap', 'fci', 'borrow', 'approv'],
#  ['boe', 'airbu', 'valuer', "ai'", 'aircraft', 'fleet'],
#  ['fipb', 'okay', '29', 'fdi', 'propos', 'worth', 'rs', '135', 'cr'],
#  ['auto', 'part', 'maker', 'look', 'china', 'buyout'],
#  ['npa', 'nationalis', 'bank', 'touch', 'rs', '61', '416', 'cr'],
#  ['a-i', 'bid', 'tata', 'await', 'sia', 'decis'],
#  ['privat', 'placement', 'safe', 'bet'],
#  ['sebi', 'propos', 'cbi', 'dispos'],
#  ['core', 'sector', 'regist', '1.2', 'growth'],
#  ['confus', 'compound', 'statu', 'a-i', 'bidder'],
#  ['govt', 'independ', 'director', 'sebi', 'board'],
#  ['stock', 'scam', 'jpc', 'get', 'extens'],
#  ['auto', 'part', 'industri', 'pen', 'surviv', 'agenda'],
#  ['govt', 'induct', 'independ', 'director', 'sebi', 'board'],
#  ['hll', 'extend', 'reach', 'door-step'],
#  ['bpcl', 'plan', 'petroleum', 'product', 'export', 'bangladesh'],
#  ['bad', 'debt', 'bog', 'financi', 'institut'],
#  ['bata', 'reebok', 'tie-up', 'retail', 'partnership'],
#  ['slowdown', 'stagnat', 'real', 'estat', 'market', 'worldwid'],
#  ['canada', '3000', 'tie', 'ia', 'jet'],
#  ['dragon', 'turn', 'endear'],
#  ['saarc', 'concern', 'attempt', 'expand', 'wto', 'agenda'],
#  ['shram', 'award', 'nine', 'ntpc', 'employe'],
#  ['spender', 'leav', 'ford', 'india'],
#  ['govt', 'review', 'factori', 'act'],
#  ['transfer', 'price', 'norm', 'tax', 'intern', 'deal'],
#  ['sky', 'limit', "surat'", 'sari', 'czar'],
#  ['bi', 'invest', 'rs', '23cr', 'expans'],
#  ['zee', 'channel', 'get', 'fresh', 'look'],
#  ['krushi', 'bank', 'vice', 'chairman', 'held'],
#  ['royal', 'enfield', 'roll', 'new', 'bike', 'everi', '6', 'month'],
#  ['steel', 'export', 'regist', '5', 'growth', 'april-juli'],
#  ['govt', 'await', 'rbi', 'guidelin', 'ssi'],
#  ['relianc', 'urg', 'start', 'ga', 'cracker', 'project'],
#  ['subhash', 'chandra', 'dilut', 'stake', 'zee'],
#  ['a-i', 'disinvest', 'wait', 'bidder'],
#  ['mutual', 'fund', 'invest', 'debt'],
#  ['mumbai', 'high', 'upgrad', 'hit', 'speedbreak'],
#  ['assocham', 'counter', 'flood', 'chines', 'good'],
#  ['govt', 'get', 'rs', '7.78', 'cr', 'dividend', 'vijaya', 'bank'],
#  ['basmati', 'export', 'expect', '6', 'lakh', 'tone'],
#  ['uppal', 'leav', 'volvo'],
#  ['cvc', 'cag', 'nix', 'propos', 'psu', 'strateg', 'sale'],
#  ['fi', 'play', 'match-mak', 'enron', 'sell-off'],
#  ['atla', 'copco', 'ab', 'hike', 'share', 'hold', 'india'],
#  ['market', 'unimpress', 'mtnl-bsnl', 'tie-up', 'talk'],
#  ['volvo', 'india', 'eye', 'divers', 'road'],
#  ['cbi', 'probe', 'forg', 'letter', 'a-i', 'selloff'],
#  ['hc', 'seek', 'probe', "uti'", 'invest', 'ril'],
#  ['steel', 'ministri', 'seek', 'rs', '182', 'cr', 'non-plan', 'loan'],
#  ['wide', 'incom', 'dispar', 'among', 'chines', 'worker'],
#  ['dubai', 'media', 'citi', 'woo', 'indian', 'firm'],
#  ["tata'", 'taco', 'project', 'bite', 'dust'],
#  ['resolv', 'issu', 'last', 'round', 'first'],
#  ['corpor', 'bank', 'top', 'brass', 'brush', 'skill', 'iim'],
#  ['fi', 'take', '18', 'stake', 'automartindia'],
#  ["united'", 'flight', 'fantasi'],
#  ['ifc', 'shore', 'india', 'portfolio'],
#  ['us', 'curb', 'india', 'like', 'say', 'enron', 'chairman'],
#  ['bidder', 'question', 'a-i', 'balanc', 'sheet'],
#  ['crude', 'output', 'slip', '5.7', 'p', 'c', 'juli'],
#  ['rs', '16', 'cr', 'condit', 'bail', 'ketan', 'parekh'],
#  ['rcf', 'eye', 'fertilis', 'unit', 'sail', 'ppl'],
#  ['broker', 'optimis', 'deriv', 'incent', 'scheme'],
#  ['ed', 'seek', 'detail', "ranbaxy'", 'uk', 'subsidiari'],
#  ['india', 'expand', 'itec', 'programm'],
#  ['boi', 'revis', 'interest', 'rate', 'deposit'],
#  ['alli', 'deal', 'opt', 'hzl', 'cmc'],
#  ['colorplu', 'goe', 'global', 'expand', 'indian', 'presenc'],
#  ['quarter', 'balco', 'workforc', 'seek', 'vr'],
#  ['tc', 'set', 'develop', 'centr', 'hungari'],
#  ['bharti', 'offer', 'bank', 'guarante', 'dot'],
#  ['rupe', 'steadi', 'dollar'],
#  ['sbi', 'home', 'financ', 'rais', 'fund'],
#  ['sensex', 'move', 'small', 'rang', 'earli', 'stage'],
#  ['sail', 'submit', 'altern', 'packag', 'iisco'],
#  ...]

# %% [markdown]
# ### Dividing into training and testing set

# %%
import textblob

# %%
from textblob import TextBlob

# %%
def subjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def polarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df2["Subjectivity"]=df2["headline_text"].apply(subjectivity)
df2["Polarity"]=df2["headline_text"].apply(polarity)

# %%
df2.head()
# Out:
#    publish_date        headline_category  \
# 0      20010529  business.india-business
# 1      20010715  business.india-business
# 2      20010727  business.india-business
# 3      20010804  business.india-business
# 4      20010807  business.india-business
#
#                                     headline_text  Subjectivity  Polarity
# 0  sensex stays in the bull zone; gains 60 points      0.000000       0.0
# 1      money wise brsensex faces a roller coaster      0.900000       0.7
# 2                for sensex; worst is yet to come      1.000000      -1.0
# 3         sensex recovers by 2.27% over last week      0.066667       0.0
# 4                      sensex slides by 11 points      0.000000       0.0

# %%
df2["sentiment"]=df2["Polarity"].apply(lambda x: '1' if x>=0 else '0')

# %%
df2
# Out:
#       publish_date        headline_category  \
# 0         20010529  business.india-business
# 1         20010715  business.india-business
# 2         20010727  business.india-business
# 3         20010804  business.india-business
# 4         20010807  business.india-business
# ...            ...                      ...
# 5701      20201219  business.india-business
# 5702      20201222  business.india-business
# 5703      20201223  business.india-business
# 5704      20201229  business.india-business
# 5705      20201230  business.india-business
#
#                                           headline_text  Subjectivity  \
# 0        sensex stays in the bull zone; gains 60 points      0.000000
# 1            money wise brsensex faces a roller coaster      0.900000
# 2                      for sensex; worst is yet to come      1.000000
# 3               sensex recovers by 2.27% over last week      0.066667
# 4                            sensex slides by 11 points      0.000000
# ...                                                 ...           ...
# 5701  sensex hits 47k for 1st time as eco hobbles to...      0.000000
# 5702           virus variant: sensex tanks 1;407 points      0.000000
# 5703               sensex regains 46k in pullback rally      0.000000
# 5704             sensex ends above 47k pts for 1st time      0.100000
# 5705    finance; it stocks take sensex to record levels      0.000000
#
#       Polarity sentiment
# 0          0.0         1
# 1          0.7         1
# 2         -1.0         0
# 3          0.0         1
# 4          0.0         1
# ...        ...       ...
# 5701       0.0         1
# 5702       0.0         1
# 5703       0.0         1
# 5704       0.0         1
# 5705       0.0         1
#
# [5706 rows x 6 columns]

# %%
df2["sentiment"].value_counts()
# Out:
# 1    4212
# 0    1494
# Name: sentiment, dtype: int64

# %%
all_pos_head=[]
for headline, sentiment in zip(df2['headline_text'],df2["sentiment"]):
    if sentiment=='1':
        all_pos_head.append(headline)

# %%
len(all_pos_head)
# Out:
# 4212

# %%
all_neg_head=[]
for headline, sentiment in zip(df2['headline_text'],df2["sentiment"]):
    if sentiment=='0':
        all_neg_head.append(headline)

# %%
len(all_neg_head)
# Out:
# 1494

# %%
0.75 * len(all_pos_head)
# Out:
# 3159.0

# %%
0.25 * len(all_pos_head)
# Out:
# 1053.0

# %%
0.75 * len(all_neg_head)
# Out:
# 1120.5

# %%
0.25 * len(all_neg_head)
# Out:
# 373.5

# %%
train_pos= all_pos_head[:3159]
test_pos=all_pos_head[3159:]
train_neg= all_neg_head[:1120]
test_neg=all_neg_head[1120:]
train_x=train_pos+ train_neg
test_x=test_pos+ test_neg

# %%
len(train_x)
# Out:
# 4279

# %%
train_y=np.append(np.ones((len(train_pos),1)),np.zeros((len(train_neg),1)),axis=0)

# %%
test_y=np.append(np.ones((len(test_pos),1)),np.zeros((len(test_neg),1)),axis=0)

# %%
def process(headline):
    tokenized =tokenizer.tokenize(headline)
    cleaned=[]
    for word in tokenized:
        if (word not in stopwords_english and word not in string.punctuation):
            cleaned.append(word)
    
    stemmed=[]
    for word in cleaned:
        stem_word= stemmer.stem(word)
        stemmed.append(stem_word)            
    return stemmed

# %%
def count_tweets(result, tweets, ys):
    yslist=np.squeeze(ys).tolist()
    for y, tweet in zip(yslist, tweets):
        for word in process(tweet):
            pair = (word,y)
            if pair in result:
                result[pair] += 1
            else: 
                result[pair] = 1
    return result

# %%
freqs = count_tweets({}, train_x, train_y)

# %%
process("I love America")
# Out:
# ['love', 'america']

# %%
def lookup(freqs, word, label):
    
    n = 0

    pair = (word, label)
    if (pair in freqs):
        n = freqs[pair]

    return n

# %%
def train_naive_bayes(freqs, train_x, train_y):
  
    loglikelihood = {}
    logprior = 0

    vocab = set([pair[0] for pair in freqs.keys()])
    V = len(vocab)

    N_pos = N_neg = 0
    for pair in freqs.keys():
        if pair[1] > 0:
            N_pos += freqs[pair]
        else:
            N_neg += freqs[pair]

    D = len(train_y)
    
    D_pos = (len(list(filter(lambda x: x > 0, train_y))))

    D_neg = (len(list(filter(lambda x: x <= 0, train_y))))

    logprior = np.log(D_pos) - np.log(D_neg)

    for word in vocab:
        freq_pos = lookup(freqs,word,1)
        freq_neg = lookup(freqs,word,0)

        p_w_pos = (freq_pos + 1) / (N_pos + V)
        p_w_neg = (freq_neg + 1) / (N_neg + V)

        loglikelihood[word] = np.log(p_w_pos/p_w_neg)

    return logprior, loglikelihood

# %%
logprior, loglikelihood = train_naive_bayes(freqs, train_x, train_y)
print(logprior)
print(len(loglikelihood))
# Out:
# 1.0369268365129454
# 2308

# %%
def naive_bayes_predict(tweet, logprior, loglikelihood):
    word_l = process(tweet)

    p = 0

    p += logprior

    for word in word_l:

        if word in loglikelihood:
          
            p += loglikelihood[word]


    return p

# %%
def test_naive_bayes(test_x, test_y, logprior, loglikelihood):
    accuracy = 0
    y_hats = []
    for tweet in test_x:
        if naive_bayes_predict(tweet, logprior, loglikelihood) > 0:
            y_hat_i = 1
        else:
            y_hat_i = 0

        y_hats.append(y_hat_i)

    error = np.mean(np.absolute(y_hats-test_y))

    accuracy = 1-error


    return accuracy

# %%
print("Naive Bayes accuracy =%0.4f" %
      (test_naive_bayes(test_x, test_y, logprior, loglikelihood)))
# Out:
# Naive Bayes accuracy =0.6379

# %%
from sklearn.model_selection import GridSearchCV

# %%
import sklearn

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,3),lowercase=False)

# %%
from sklearn.model_selection import train_test_split

# %%
score=df2["sentiment"]

# %%
df2["headlines cleaned"]=df2["headline_text"].apply(process)

# %%
Xtrain,Xtest,ytrain,ytest = train_test_split(cl[int(len(cl)/2):],score[int(len(cl)/2):],test_size=0.25,random_state=21)

# %%
Xtrain = vectorizer.fit_transform(Xtrain)
Xtest = vectorizer.transform(Xtest)

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
naive = MultinomialNB()
naive.fit(Xtrain,ytrain)
# Out:
# MultinomialNB()

# %%
prediciton = naive.predict(Xtest)

# %%
cleaned=df2["headlines cleaned"].tolist()

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

matrix = confusion_matrix(ytest,prediciton)
print(matrix)
print('The model accuracy is {}'.format(round(accuracy_score(ytest,prediciton),3)))
# Out:
# [[ 42 153]
#  [  0 519]]
# The model accuracy is 0.786

# %%
cl=[]
for head in cleaned:
    a=" ".join([str(elem) for elem in head])
    cl.append(a)

# %%
cl
# Out:
# ['car dealer caught bihar sale tax rule',
#  're-negoti best deshmukh lender so centr',
#  'samsung say hello cellular unit india',
#  'govt lift port-link curb import',
#  'ril plan mop rs 1 000cr',
#  'eicher crash red cut 200 job',
#  'indo rama post rs18cr net',
#  'jet sahara wait watch',
#  'auto bodi drive new classif norm',
#  'us 64 sunni day',
#  'dpc may contest merc jurisdict',
#  'brave new biotech',
#  'begin salari fall',
#  'dgca propos airfar upset airlin',
#  'zee art program turnaround',
#  'learn check right isi mark',
#  'mseb plan acid test dpc phase ii',
#  'ashok leyland cut job divis',
#  "fix former dse ed sodhi' pay packag lack transpar",
#  'dd metro grab',
#  'dpc signal climb see scope cut power tariff',
#  'satyam say may face manpow problem',
#  'net dip 54 keep payout 55',
#  'better late never nid take new design',
#  'sensex stay bull zone gain 60 point',
#  'sail cut loss half',
#  'drive low gear',
#  'bewar snoopwar watch',
#  'ia divest may roadblock new player domest sky',
#  'car sale drop 15 april',
#  'ia divest may roadblock new player domest sky',
#  'slowdown hit idbi net 27.3 rs 691 cr',
#  'car sale drop 15 april',
#  "korn ferri search dewang mehta' successor",
#  "korn ferri search dewang mehta' successor",
#  'media public promis big ad spend futur',
#  'centr unveil bailout packag madhavpura bank',
#  'goodyear roll tubeless radial tyre india',
#  'nationwid bank strike juli 4',
#  'mtnl execut cdma-wll servic soon',
#  'trai moot allot code std oper',
#  'bharti-singtel jv get loi std servic',
#  "hc restrain govt recov whisky' price differ",
#  'ia review flexi-far july-august',
#  'sportier imag import lotu elis',
#  'bnp pariba may acquir indian bank',
#  'crude oil product skid fiscal',
#  'govt nod 13 pvt parti start air servic',
#  'bsp mp charg sebi unwilling probe rpl',
#  'fipb clear 32 fdi propos worth rs 477 cr',
#  'lg launch healthcar product',
#  'jaswant hold talk bilater trade wto',
#  'propos enhanc petro price naik',
#  "sabeer bhatia' arzoo remain unfulfil",
#  'ranbaxi sue wilmark use similar brand name',
#  'dump dd goe rebid slot',
#  "8 global fi join rpl' 500 loan syndic",
#  'jaswant hold talk bilater trade wto',
#  'yamaha appeal fake bike china',
#  'satyam wari growth despit robust 2000-01',
#  'a-i present profit budget 2001-02',
#  "softwar park question satyam' export revenu",
#  'indian american disney interact top post',
#  'us lend ear india steel',
#  'rupe end mildli higher dollar',
#  "en-mass transfer balco' delhi offic",
#  'six-point strategi speed fdi flow',
#  'i-t haul firm bank fi invest tax-fre bond',
#  'dpc mseb fight legal battl',
#  'tc set asia-pacif hq singapor',
#  'import 300 sensit item 11',
#  'rpl get cabinet nod dilut relianc share',
#  'daewoo rework market strategi',
#  'enron debacl would dampen flow fdi india',
#  'nissan mitsubishi cut global vehicl output may',
#  'strateg partner may get 5 director a-i board',
#  'duti drawback rate partial roll back',
#  'distress export diesel ram naik',
#  'world bank announc 913.8 million aid india',
#  'summertim iim easi street',
#  'tata sia videocon case refer cabinet',
#  'hll unveil action-plan food revolut',
#  'subsidi lpg kerosen stay naik',
#  'prasar bharati seek agenc monitor dd reach',
#  'siemen buy-back offer begin june 25',
#  'china-russia trade hit record level',
#  'meet finalis madhavpura reviv plan june 25',
#  "satellite' corrupt cop still run",
#  'us lose key wto case eu',
#  'forex reserv swell 153 43 160',
#  "gaz de franc hedg petronet' risk",
#  'hdfc buy 8 stake positra sez rs 150 cr',
#  'media lab take have-not',
#  'lord paul vest interest open trade',
#  'without reform sustain bull run',
#  'desper seek disinvest',
#  'global oil major queue ibp pie',
#  'balmer lawri demerg',
#  'dolphin get aggress slash call rate',
#  'cellular giant born',
#  'offici batata bpl announc merger',
#  'a-i share deal boost sell-off price',
#  'hinduja pull shouri',
#  'panel call free agricultur market',
#  'toontown reach india',
#  'govt packag face difficulti redeem us 64 fulli',
#  'grasim industri worker reach closur agreement',
#  'dse provid liquid us 64 small investor',
#  'price rig need check',
#  'pak studi respons indian offer reduc tariff',
#  'g 8 financ minist hold summit rome',
#  'china dump good india cii',
#  'fall volum may forc dse merg bse',
#  'telecom small firm see space surviv',
#  'make mission possibl',
#  'make uti asset manag firm',
#  'us 64 paid earn less',
#  'godbol panel recommend privatis mseb',
#  'us 64 crisi disastr amfi chief',
#  'strenghten indo-pak trade tie cii',
#  'infosi see rs 800 cr profit fiscal q1 net soar 56',
#  'distacom sell 49 stake spice',
#  'bpl buy franc telecom batata',
#  'us slowdown take toll infosi',
#  'indian oil relianc among forb intern 500',
#  'npp exempt r d-savvi dpco',
#  'bharti cellular reduc airtim tariff magic',
#  'ongc nod increas product major field',
#  'rupe end bare chang dollar',
#  'essar slash airtim tariff cash card',
#  'dupont expans drive india',
#  'essel sell 50 lakh zee share us investor',
#  'bad news growth front',
#  'control sugar industri go soon shanta',
#  'shouri deni favour tata air india bid',
#  'uti packag like today',
#  'dupont expans drive india',
#  'pak click indian train co',
#  'maharaja fli chennai-hk direct',
#  'investor protect fund like next week',
#  'hc issu contempt notic netwar infosi',
#  'biocon transcorp technolog battl',
#  'govt may amend act allow rbi lower slr',
#  'investor urg centr interven us 64 scheme',
#  'wil default sent jail sinha',
#  'jpc govt set train gun hfcl zee',
#  'berger ici form jv make auto ind coat',
#  'eli lilli make india global bulk drug outsourc hub',
#  'rupe stage mild ralli',
#  'guidelin advisor bidder disinvest',
#  'sinha confid achiev indirect tax target',
#  'uti redempt rs 2 265 crore june amfi',
#  'skumar flip-flop e-com ventur',
#  'improv qualiti boost export thai minist',
#  'hc order bajaj auto make 701 worker perman',
#  'b k modi meet fi today',
#  'promot stake zee telefilm 59',
#  'murdoch upbeat indian market',
#  'bengal set panel decid fate psu',
#  'sinha meet bank fi tackl slowdown',
#  'improv qualiti boost export thai minist',
#  'sugar industri stand gain wto regim',
#  'uti get bank loan equiti hold',
#  'divest norm affect morgan stane',
#  'hunt nasscom presid last leg',
#  'fi stay away modi rubber open offer',
#  'broker meet juli 17 chart action plan',
#  'indo-myanmar border trade declin',
#  'milit reduc poverti kashmir',
#  'money wise brsensex face roller coaster',
#  'forex reserv swell 141 mn 43 596 mn',
#  'mphasi sharehold okay equiti sale chrysali',
#  'financi sector reform jeopardis economi',
#  'uti board fail firm exit rout us 64',
#  "commemor coin beijing' olymp bid success",
#  'transfer price rule aid higher tax collect',
#  'rs 28 cr citigroup fund daksh',
#  'fii net buyer equiti rs 261.2 crore',
#  'uti offer limit exit announc nav jan',
#  'spice talk cellphon major merger',
#  'nri industrialist optimist indo-pak summit',
#  'indian languag bridg digit gulf',
#  'small uti investor heav sigh relief',
#  'entreprenu vanguard growth',
#  'gdp project grow 6.3 cmie',
#  'rbi governor say economi good shape',
#  'inflat rise 5.16',
#  'activ govt role need tackl fake',
#  'textil polici envisag export target 50 b',
#  'fi seek rs 45 crore guarante modi',
#  "dpc' lng carrier deploy spot market",
#  'nri industrialist optimist indo-pak summit',
#  'maruti invest rs 550 crore',
#  "fii stake mrl may purnendu chatterjee' hold",
#  'lower manufactur call vat intern competit',
#  'govt amend i-t law tax e-commerc firm',
#  'somebodi err other pay price',
#  'niit cut back spend',
#  'bank need fund becom technolog compet',
#  'mp-base compani record 13 growth cmie report',
#  'compani q3 turn point',
#  'tisco seek acquisit opportun select field',
#  'dod may consid liberalis term ia selloff',
#  'market cool agra talk',
#  'ntpc buy enron equiti centr',
#  'j j irani stress achiev target',
#  'govt get rs 1 486 cr 4th cellular slot',
#  'telco among top 10 loser',
#  'rupe gain',
#  'us 64 lose game investor',
#  'block deal limelight listless market',
#  'sc allow balco plea discrimin',
#  'strateg sale hold least prioriti uti chief',
#  'relief investor 3 000 unit soon',
#  'coca cola close 2 plant mumbai pune',
#  'satellite-bas system airport soon',
#  'psu bank chief meet uti chief us 64 assist',
#  "tyco make b'lore plant global sourc base",
#  'hll eye organ tea segment',
#  'give grant poor countri us tell wb',
#  'increas bonu policy-hold lic',
#  'hc stop govt finalis cellular bid',
#  'saga it-aid design',
#  'state may fix margin pd shop govt',
#  'insur claim settl 7 day',
#  'car war global model indian price',
#  'moet-hennessi market cognac champagn india',
#  'mf industri grew 46.49 1999-2000',
#  'auto car two-wheel sale june',
#  'bid 4th cellular slot receiv',
#  'hyundai sonata make debut',
#  'ketan deni foreign bank account ownership',
#  'siemen q3 net profit 48.97',
#  'pay first fi tell modi',
#  'tisco top steel maker q1 net crash 79',
#  'india inc pessimist industri recoveri',
#  'ub group launch flavour water',
#  'govt target 50 bn textil export 2010',
#  "mid-air duel a-i' futur",
#  'a-i maruti hoc divest joshi',
#  'bse sub-panel overse corporatis process',
#  'busi bhailater',
#  'rupe stage smart ralli dollar',
#  "bush' wb plan hit india",
#  'badla oper rout rs 2 000 cr mf',
#  'vassal blame sebi us 64 crisi',
#  'maruti price go soon',
#  'biotech regul may face hurdl',
#  'bajaj elimin hit road',
#  'govt may rais cess petrol diesel',
#  'rbi favour greater freedom co-op bank',
#  'rbi forese higher agri growth fiscal',
#  'govt move sc 4th cellular slot paswan',
#  'top uti offici charg fraud',
#  'itc net 21 rs 301 crore q1',
#  'forex reserv declin 37 mn 43 559 mn',
#  'tax collect plung 13 q1',
#  'ipcl net 64 rs 12.67 cr q1',
#  'rural telesubscrib get cheap deal',
#  'say chees desi pizza rs 20',
#  'sail gloom time',
#  'money wisebrlesson us 64 debacl',
#  'merril lynch pay play bull boom',
#  'relianc dot ink basic circl pact',
#  'vsnl ventur provid servic nepal',
#  'cbi arrest subramanyam',
#  "fi yet finalis particip modi' open offer",
#  'bharti move hc dot follow',
#  "rise fuel cost dent a-i' bottomlin",
#  'yashwant quit demand cpi',
#  'india disinvest kashmir',
#  'us slump may last longer expect',
#  'pc sale revolut sight',
#  'one ikon mani model',
#  'mbt shelv ipo plan pvt placement',
#  "digvijay review financ department' function",
#  'boost demand reviv economi',
#  'smoke pipe line peac',
#  'sebi rais issu broker fund rbi say mehta',
#  'bollywood warm india inc',
#  'exid jv austrian firm',
#  'crude product dip 7.5 2.48 mt june',
#  'govt await hc rule',
#  'telco drive comm vehicl sale q2',
#  'rupe open slightli weak',
#  'power grid corpor invest rs 1 100 crore telecom',
#  'broker go one-day strike',
#  'dragon tiger china eye india',
#  'bharti-singtel pull vsnl bid',
#  'softwar becom free',
#  'rural credit like go rs 86 000 crore report',
#  'centr chart fresh norm ia sell-off',
#  'uti suspend offici cbi investig',
#  'multipl zone buy back mail.com stake',
#  'stock broker embark nationwid strike',
#  'india score size lose red tape fdi',
#  'indian household ditch stock market small save',
#  'ril invest rs 1 500 cr oil explor',
#  'sebi suspend ace stock broker nikhil shah',
#  'action initi bpl videocon',
#  "3 member panel probe uti' invest decis",
#  'govt may mull compens vsnl',
#  'govt file caveat sc tomorrow 4th cellular slot issu',
#  "vsnl' particip cellular bid dismiss",
#  'disinvest commiss reconstitut',
#  'a-i flight hong kong singapor mumbai',
#  'modi hive tyre busi',
#  'videocon withdraw ia bid decid shortli vsnl',
#  'top brass simpli peanut',
#  'bse suspend trade dsq softwar juli 30',
#  'indian tea export hit iran ban',
#  'telco loss',
#  'kawasaki sourc part bajaj',
#  'tarapor mum uti seek stronger regulatori capabl',
#  'vat panel probe revenu loss due vat vat servic',
#  'sbi icici bank outsmart other 3 year',
#  'ramadorai appoint tata tech chief',
#  'specialti ranbaxi call day',
#  "hiten dalal' arrest defer",
#  'hinduja sterlit csfb issu show-caus notic',
#  "verdict ketan parekh' bail plea tomorrow",
#  'hll net rise pay 250',
#  'sbi q1 net rise 26 rs 580 cr',
#  'samsung india h1 sale 38 rs 1 247cr',
#  'ibm invest 10m chrysali',
#  'irda warn lic gic uti equiti exposur',
#  'state pay rs 18 000cr ntpc',
#  'tata sack five top execut',
#  'uti talk privat bank us 64 packag',
#  'global tele arm plan techcompet centr',
#  'ril acquir oil ga block tullow',
#  'imf wb pressur simplifi loan term',
#  'purpl yogi plan makeov',
#  'equiti suffer setback sell pressur',
#  '4th round cellular bid stay hold',
#  'dunlop see exodu execut last 7 month',
#  'us 64 separ scheme',
#  "court reject ketan parekh' bail plea",
#  'share finish lower sustain sell',
#  'icici lombard may get irda nod tomorrow',
#  "govt seek sebi' opinion hzl delist",
#  'govt reduc stake idbi panel',
#  'gspc stop ga suppli essar steel plant',
#  'cii discuss jv british counterpart',
#  'cbi interrog arvind johari cyberspac',
#  'former bse presid damani dead',
#  '4 state readi buy dpc power',
#  'vsnl ibp sharehold nod like sept',
#  'rupe weaken slightli dollar',
#  'apollo tyre net profit drop 30 per cent',
#  'carrier net plung 75 rs 2.55 cr',
#  'canada 3000 begin mumbai-toronto flight',
#  'beer battl hot',
#  'sebi begin proceed broker rahul bajaj',
#  'busi india uk exce target',
#  'ec launch antitrust proceed de beer',
#  'nanda enter entertain',
#  'devanh airport project hit roadblock',
#  'polari pick 25 stake eternet inc',
#  'uti may hike redempt limit small investor',
#  'govt give nod investor protect fund',
#  'lot store hitachi india',
#  'royal philip buy cg glass',
#  '589 wb loan upgrad grand trunk road',
#  'indian techi',
#  'vsnl q1 net 4.54',
#  'icici net 13',
#  'rpl export 1.4 mt petro product q1',
#  'month-end pressur weaken rupe',
#  'bhel bag rs 18 cr suppli order apgenco',
#  'dull head-hunt find work financ insur',
#  'uti split',
#  'sensex worst yet come',
#  'retain depb export incent scheme export',
#  'underinvo hit mmtc edibl oil import',
#  'chines bike threat india yamaha',
#  'duralin hike capac goa plant',
#  'tax time',
#  'subramanyam 3 other remand polic custodi',
#  'philip carbon stop oper',
#  'us power major ae quit cesco',
#  'a-i valuat may fall way expect',
#  'psu spearhead growth q1',
#  'four state buy power current rate',
#  'ongc board clear recast plan',
#  "lnm group acquir romania' sidex",
#  'godrej q1 net profit rs 11.18 cr',
#  "maharashtra' offer unrealist dpc",
#  'chandra open dilut stake zee 50',
#  'bajaj auto q1 net inch rs 121cr',
#  'ipa moot open product critic patent drug',
#  'bank fi owe rs 900 cr tax',
#  'hc hear pil us 64 scheme aug 1',
#  'invest decis make power bsnl moot',
#  'cse set forg pact bse deriv',
#  'bob offer rs 300 cr uti',
#  'adob india may provid softwar state govt',
#  'cse worri cancel 14 mn dsq share',
#  'oil trader nationwid stir august 20',
#  'haldia petrochem may find saviour',
#  'infosi continu top growth fund',
#  'tea export may fall year',
#  'uti grappl potenti rs 1 700 cr pay-out',
#  'land compens market valu sc',
#  'top busi magazin cut staff',
#  'subsidi petro product rise',
#  'china enter wto challeng india',
#  'aig pick 12 stake nagarjuna refineri',
#  'cmc htl sell-off like august',
#  'bpl leow pact see big pictur',
#  "drt hear boi suit ketan' co",
#  'next godbol panel meet may cancel',
#  'converg bill tabl session',
#  'revamp corporatis uti demand',
#  'bnp pariba buy taiwanes invest trust report',
#  'lohani take new itdc chairman',
#  'car bike export scooter muv q1',
#  'carrier form panel recast',
#  'rupe weaken slightli',
#  'bajaj capit 3rd admir financi firm',
#  'cbi begin probe cyberspac share transact',
#  'singhania stake raymond 30',
#  'wockhardt q2 net 70.68',
#  'fresh bid appoint a-i valuer like',
#  'bodi languag speak louder speech',
#  'govt work packag coal india',
#  "raymond foray women' wear",
#  'modern under-valu anz grindlay cag',
#  'raymond earn rs 1 150 cr steel cement hive',
#  'reshuffl give profession touch itdc kumar',
#  'rupe end margin better',
#  'injunct fail prevent film piraci',
#  'balco kick vr union appeal reject',
#  'move rais import duti cigarett sinha',
#  'import mmtc cloud cbi probe recommend',
#  "pm' offer quit make short impact scrip",
#  'p srivastava take cbdt chairman',
#  'zee net 13 rs 36.3 cr',
#  'govt plan regul coal sector',
#  'tabl phone transcript uti deal sena',
#  'titan ind record rs 14.6 cr net loss',
#  'hc issu fresh contempt notic netwar infosi',
#  'agrani select alcatel satellit system',
#  'maharashtra okay divest bill',
#  'uti meet eye',
#  'bat q2 profit rise 7.9 europ asia',
#  'k j udeshi rbi execut director',
#  "relianc keen enron' stake dpc",
#  'ioc set lpg dispens station gangwar',
#  "uti heed jpc' warn sinha",
#  'us exim set move sc dabhol row',
#  'govt face critic bail-out',
#  'govt okay rs 1 000 cr bail-out ifci',
#  'fin post 28 rise profit',
#  'lic pick 9 stake obc market',
#  'electron export jump 72.5 2000-01',
#  'indo-pak sugar trade disput erupt',
#  'committe ask govt withdraw tot',
#  'rupe rock steadi',
#  "sbi' fraud case amount rs 269.15 cr",
#  'uti readi war chest us 64 redempt',
#  'export dip 5 trade deficit widen 34',
#  'tv suzuki net skid 46 per cent',
#  'icra unveil corp govern rate india',
#  "uti particip rpl' gdr offer",
#  'birla centuri net 18.98 q1',
#  'maruti sale 12 juli',
#  'singl rate vat may boost economi',
#  'icici lombard get nod irda',
#  'bob tie amc life insur',
#  'cbi ask sebi take action ed',
#  'industri slowdown lead recess',
#  'bharti offer rs 258 cr payment',
#  'wipro sharpen focu embed softwar',
#  'dip export due intern slowdown',
#  'zen wagonr drive mul sale',
#  'firm garner rs 20 cr german fair',
#  'rupe strengthen',
#  'uti reserv turn neg',
#  'arunach decentralis tea cultiv',
#  'videocon may sell stake ravva ventur',
#  'nine psu empanel divest',
#  'german bank credit power telecom project',
#  'gener motor invest india',
#  'indo-china trade get boost',
#  'b muthuraman new tisco md',
#  'lukewarm respons uti repurchas',
#  'vr central govt employe soon shouri',
#  'indian beer win intern acclaim',
#  'cse may suspend trade dsq softwar',
#  "bajaj auto' vr get lukewarm respons",
#  'us banker follow shariah strike gold',
#  'cii deleg meet us offici steel',
#  'karnik look rebuild nasscom',
#  'uti crisi usual public pay price',
#  'anti-dump duti theophyllin caffein import',
#  'ae pullout affect privatis prabhu',
#  'bentley car rs 1 cr',
#  'uti chief promis cleanup job',
#  'cancel dpc phase-i reviv phase-ii mistak',
#  'mrtpc give clean chit daewoo',
#  'financi sector face crisi confid vittal',
#  'bank india open branch china vietnam',
#  'uti receiv applic repurchas 2.22 crore unit',
#  'india potenti garner 100 bn fdi 5 yr',
#  'equiti rise smartli nse',
#  'singl rbi nomine appropri',
#  'kyoto enjoy back g 77 nation',
#  'petronet seal lng chain ink ga sale mou',
#  'closur psu last resort govt',
#  'china lift restrict pvt enterpris',
#  'soni get 808 mn credit line',
#  'govt allay fear inflat',
#  'ae pull orissa crisi galor',
#  'ifci enquir modern syntex account',
#  'sahara tie foreign airlin',
#  'bhel bag rs 10 cr order ongc',
#  'resign help sinha',
#  'uti may dig reserv fund',
#  'mp love bombay high',
#  'sensex recov 2.27 last week',
#  'sinha rule resign uti muddl',
#  'data storag domin spend',
#  'uti firm strateg sale dud firm',
#  'air nz deal forc sia rethink a-i',
#  'ulip keep uti flag high',
#  'uti may suspend us 64 sale indefinit',
#  'former wiproit make big techi world',
#  'cyberspac wrong invest decis sinha',
#  'potenti tap 100 bn fdi 5 yr',
#  'itc open relat area',
#  'hdfc standard life break even 5 year',
#  'itc chairman bat increas stake vst',
#  'wll mobil phone punjab march 2002',
#  'save dabhol',
#  'sbi forex profit downsw',
#  'ioc hike servo price',
#  'volta exoner unfair trade charg',
#  'hpcl complet bhatinda refineri dec 2005',
#  'fiiss mf oper contrast juli sebi',
#  'kiran karnik succeed',
#  'bharti initi talk rs 3000 cr debt',
#  'b2b transact volum touch rs 51 000 cr',
#  'cse board discuss dsq suspens tuesday',
#  'face offbrth silver line hcl',
#  'forc rescind ppa mseb',
#  'niit add 2 sbu retail transport',
#  'regulatori framework must media industri',
#  'tough time consum durabl firm warn icra',
#  'cyberspac scam get financi trap',
#  'bpl appoint i-sec sell maharashtra cellular licenc',
#  'pharma growth plan enchant industri analyst',
#  'a-i earn rs 245 cr via seat share',
#  'telco bajaj forse higher growth net profit',
#  'vsnl notifi vr employe',
#  'parliament approv repeal bank compani act',
#  'anti-dump case porcelain tile import china',
#  'ford reduc cost ownership',
#  'crompton greav recast come red',
#  'tata file fir dilip pends 5 other',
#  'india press limit agenda wto talk',
#  'tata hugh explor telecom tie-up',
#  "indian firm invit set unit china' sez",
#  'propos divest sail govt',
#  'tvs-suzuki report 4 juli sale',
#  'dd open fresh bid metro primetim',
#  'bifr ask torrent sort differ creditor',
#  'sia sought 49 stake a-i',
#  'honda launch activa delhi',
#  'nigeria technolog corp india',
#  "fieo weclom sbi' move cut plr",
#  'nse expel ashoka industri resourc',
#  'maruti hike car price today',
#  'cvc order re-tend rs 1 000 crore dot contract',
#  'sc transfer enron issu bombay hc',
#  'differ ia a-i divest yadav',
#  'catch em young kid consum',
#  'thermax announc vr employe',
#  'pcb pull take action eil',
#  "enron' dpc extrem pleas sc rule",
#  'india austria sign doubl taxat treati',
#  'gartner upbeat face gloomi doomi mart',
#  'jalan declin comment ifci bailout',
#  'godbol panel report applic relianc power',
#  'china revamp economi ahead wto entri',
#  'jk industri delist delhi bours',
#  'wheat export hit new low despit demand rise',
#  'raymond acquir hindustan ga arm',
#  'former uti chief subramanyam get bail',
#  'favour wireless user caus rs 24 cr loss',
#  'govt give ifci rs 400 cr',
#  'sensex slide 11 point',
#  'p downgrad seen littl impact',
#  'dpc warn mseb inform praya',
#  'price 3 bulk drug slash',
#  'strength direct market',
#  'tata file fir dilip pends 5 other',
#  'cement sale product dip juli',
#  'gross fiscal deficit soar rs 42 000 cr',
#  'rupe steadi us dollar',
#  '78 bn requir improv tele-dens paswan',
#  'govt may lower bank guarante ibp',
#  'india propos chang wto subsidi pact',
#  'bhel bag rs 280 crore order us',
#  'govt may agre reduc stake boi',
#  'india take wto issu ustr',
#  'pnb extend rs 300-400 cr uti sub-plr',
#  'govt issu norm diagnost lab',
#  'govt clear fdi propos worth rs 980 cr',
#  'telecom deal spearhead activ',
#  'govt allow bilater flight kochi',
#  'us allow duty-fre access 42 indian good',
#  'honda export 2 wheeler india',
#  "idbi' financ spotlight",
#  'mid-siz car segment fail keep promis',
#  "p' downgrad attract mix reaction",
#  'dpc charg power regul bia',
#  'srichakra lure young mind colour tyre',
#  'p downgrad affect fdi divest',
#  'bp amoco told pay rs 350 per share castrol stake',
#  'sia rais stake a-i post-selloff',
#  'realiti check entermedia',
#  'lock-in period hugh promot extend',
#  'build custom relationship sale',
#  'satnam offer ready-to-cook product',
#  'investor trust analyst doubt remain',
#  'indo rama keen invest butibori plant',
#  "dalmia welcom bp amoco' offer castrol stake",
#  'dabhol examin custom duti notic',
#  'mill produc sugar electr',
#  "moody' slash india outlook",
#  "evangelist fud-g developer' act",
#  'govt headhunt littl placement',
#  'realiti check entermedia',
#  'rate agenc wrong sinha',
#  'sinha allay fear rupe fall',
#  'centr buy enron hold dpc',
#  'govt allow bilater flight kochi',
#  "dabhol' 1 bn offer costli say mseb",
#  'enron offer sell stake cost',
#  'slowdown hit car sale',
#  'star pick major stake vijay tv',
#  'railtel corp invest rs 700 cr ofc network',
#  'p lower rate outlook bank',
#  'rupe eas margin ground',
#  'dabhol examin custom duti notic',
#  'fdi expect maran',
#  'germani switch dm euro',
#  'india call wto agenda talk',
#  'nasscom promot adopt',
#  'diversifi market export',
#  'bpl ispat set achiev financi closur',
#  'russia would welcom mig-at deal india',
#  'govt extend purchas prefer',
#  'industri growth dip 1.5 june',
#  'vat clean tax system sinha',
#  'onion export cap rein price',
#  "suspens continu sia' bid air-india",
#  'dpc move mumbai high court',
#  'pil challeng us 64 withdrawn',
#  'india push totalis pact us',
#  'alemb seek jv enter us european market',
#  'hinduja term show caus notic malafid',
#  'sinha find friend king',
#  'rbi issu guidelin financ film',
#  'coffee-consum countri bail grower',
#  'anti-aid drug cost less',
#  'sil mull tie-up oil psu',
#  'fdi upto expect maran',
#  "govt put idbi' financ spotlight",
#  'panel devis hardwar action plan',
#  'russia open mig-at deal india',
#  "tata may buy enron' stake dabhol power",
#  'introduct vat would revolutionari step sinha',
#  'cbi arrest ketan parekh',
#  'ketan parekh interrog cbi',
#  'rupe stage mild ralli us',
#  'ttk make smart move cooker world',
#  "india studi china' like wto entri",
#  'hinduja term dod notic unfair',
#  "leyland' juli sale 7.6",
#  'govt may margin hike kerosen lpg price',
#  'rbi favour self-regulatori norm mfi',
#  'ketan parekh back cbi custodi',
#  "inter gold launch men' jewelleri rang",
#  'amtek auto acquir whfl',
#  'govt heart bleed corpor pension',
#  'forex reserv rise 127 43 809',
#  'skoda chart new plan import car india',
#  'asia pacif enterpris meet tomorrow',
#  'check safe index fund',
#  'pollut free energi fuel cell',
#  "india' crude product dip 7.5",
#  'iip grow 4.5 2001-02',
#  "enron' exit countdown begin nov 19 2001",
#  'imc moot plan reviv economi',
#  'bhel implement montek committe recommend',
#  'ignit espresso engin',
#  'dalmia may acquir 40 stake revathi equip',
#  'cse work introduc margin trade',
#  "peta' demand could advers affect leather industri",
#  'tea board hire f ferguson review function',
#  'malwa foray sew thread oswal name',
#  'fii net buyer equiti rs 168.5 cr',
#  'centuri extrus submit fresh rehab scheme',
#  'fi agre fund 16 000 mw pvt project',
#  'centr ask ntpc buy enron stake dabhol',
#  'b volvo approach hc protect brand name',
#  'inflat remain stuck 4.96',
#  'sale top 10 compani 14 q1',
#  'india inc salut winner among winner',
#  'vat would result regist trader',
#  'idbi fix ifci bailout',
#  'india record healthi 6 growth power gener',
#  'plea bifr order gtc case dismiss',
#  'export promot scheme prove expens',
#  'export vegetarian food rise',
#  "ongc bid 400 ril 350 enron' panna-mukta stake",
#  'mig man mohanti next hal chairman',
#  'centr unveil medium term export polici',
#  'alstom focu core busi revamp bid',
#  'polic seiz document ex-md tata financ',
#  'fii reduc stake dabur india 6.43',
#  'sebi tell dse retain davar board',
#  'ril hll fall sell pressur',
#  'bajoria hold bombay dye cross 5',
#  'govt may buy back equiti neyv lignit',
#  'ap set get six power project',
#  "ongc bid 400m enron' panna-mukta",
#  'kingfish sell 614m pound properti',
#  'new ba servic take competit',
#  'export financ rate may see downward trend',
#  'uti investor die-hard loyalist',
#  'govt decid hinduja a-i bid 10 day',
#  'telco cut right issu',
#  'cabinet panel clear project worth rs 590 cr',
#  'deesh offer cheapest colour tv',
#  'unoc propos jv ioc',
#  'stock lead recoveri fresh fii buy',
#  'rupe eas margin dollar',
#  'uti sought fresh loan',
#  'indusind launch news channel',
#  'ia cut mumbai-delhi one-way economi fare',
#  'samsung eye rs 1 300 crore turnov',
#  'rbi supercess krushi board',
#  'icici maintain growth despit slowdown',
#  'letter comfort issu ifci bailout',
#  "hinduja keen buy enron' dpc stake",
#  'sebi announc futur trade',
#  'sterlit buyback offer cloud sebi ban',
#  'ccea clear rail power project',
#  'uti advanc us 64 nav announc',
#  'sebi allow bank fii deriv market',
#  'skill quit jolt enron',
#  'stock market function reform pm',
#  'medium term export strategi septemb',
#  'foreign carrier lower commiss',
#  'clash titan',
#  'anti-dump probe panel set',
#  'mechan monitor drug price hike of',
#  "bpl-batata talk spice' karnataka circl",
#  'petroleum product export vault ten-fold',
#  'unit start non-stop us-india flight',
#  'woe reserv staff recruit need',
#  'ratan tata offer step',
#  'corporatis rli card',
#  'pm paint rosi pictur amid econom gloom',
#  'bangalor bioinformat compani expans mode',
#  'motorola see job cut ariz chip line go',
#  'heavyweight steadi sensex',
#  'coop entri insur sector oppos',
#  'kinet eye non-lif life insur sector',
#  'mechan monitor drug price hike of',
#  'small medium firm face rough weather',
#  'india steamship chart rs 625 crore expans',
#  "tandon appoint pepsico' vp",
#  'tenth plan approach await cabinet nod',
#  'bengal govt sign mou microsoft',
#  'repli notic sent law ministri',
#  'hinduja pull race ibp',
#  'american gener sharehold approv aig bid',
#  'krushi bank account frozen board scrap',
#  'philip outsourc vcr product',
#  'telco shine despit loss',
#  "laloo' yt websit",
#  'chandra talk offload stake ztl',
#  'nasscom decentralis open region chapter',
#  'us airway announc three-stag restructur plan',
#  'ua plan non-stop flight',
#  'firm float call centr retain subscrib base',
#  'p coke scale back plan big joint ventur',
#  'trim 2 200 job back 6 day week',
#  'indo rama deni takeov threat',
#  'ia introduc walk-in flight delhi-mumbai sector',
#  'tata power acquir transmiss arm',
#  'india isol wto assert maran',
#  'bhel bag rs 2 079 cr order ntpc',
#  'tc team lead telecom co voip',
#  'cabinet nod electr bill',
#  'leelaventur eye hampi hassan',
#  'injunct oyzterbay coo vacat',
#  'indo-u agreement power manag',
#  'biotech export total rs 1072 cr',
#  'rbi transfer rs 9 350 cr dividend govt',
#  'japanes firm see chines import threat',
#  'maruti launch car disabl',
#  'sri lankan airlin resum flight new delhi',
#  'asci spread awar mislead ad',
#  'whirlpool expand product base',
#  'govt dpc set begin concili process',
#  'govt may dilut stake hindustan zinc',
#  'talk dhabol power begin tomorrow',
#  'centr take dhabol project',
#  'kapil dev promot indian tourism',
#  'festiv celebr harley-davidson',
#  'ia induct 4 320 aircraft',
#  'sterlit industri contest notic disqualif',
#  'cabinet nod insolv bill',
#  'godbol panel submit report 2-3 week',
#  'rupe weaken slightli dollar',
#  'mico bosch fear pinch',
#  'cabinet approv bill remedi sick industri',
#  'dabur scout partner genom project',
#  'nppa revis price 49 formul pack',
#  'news corp earn slip await better time',
#  'spammer creat havoc virtual world',
#  'white paper tn reveal fiscal eros',
#  'wipro forg allianc symantec',
#  'kinet ventur auto ancillari',
#  'ranbaxi get dgci nod market ciprofloxacin',
#  'tata financ move rbi relief',
#  'npcil plan add 11 000 mw',
#  'rbi conduct sale kerala govt bond',
#  'ketan parekh remand cbi custodi till aug 24',
#  'exodu surviv sellout',
#  'money wisebrgilt offer safe invest',
#  'uti seek nod trade us 64 unit',
#  'ap order confisc properti krushi case',
#  'termin notic 35 isp',
#  'eih withdraw preferenti issu',
#  'privat mutual fund big draw',
#  'centr mull demand reviv azmjahi mill',
#  'messeng vulner newer virus',
#  'fm news channel debut sept',
#  'cbi chargesheet 5 centuri scam',
#  'wipro forg allianc symantec',
#  "hardware' hardtalk fm",
#  'fm assur tax sop hardwar sector',
#  'govt mull revis payment mechan ipp',
#  'industri captain join hand water man',
#  'coffe earn fall',
#  'cvc await report recommend vora idbi chairman',
#  'auto-ancillari industri look abroad fresh leas life',
#  'futur hold h1b worker',
#  'nutraceut co british biolog enter uk',
#  'inflat rise 5.22',
#  'hsbc launch new servic',
#  'infosi relianc admir compani',
#  'cvc favour us model capit market',
#  'global slump drag export 2.7 2002',
#  'pm plan oper arrest econom slowdown',
#  'shantha biotech want move andhra',
#  'alert get vehicl insur',
#  'fipb spike skoda propos import octavia cbu',
#  "enron ae issu dent india' imag us regul",
#  'hzl disinvest',
#  'sebi ask thoma cook explain delay',
#  'ae accus orissa govt interfer',
#  'pioneer may hike stake mf firm',
#  'ambani premji n r murthi best ceo',
#  'concili process enron adjourn',
#  'vittal favour us style capit market',
#  'assocham set bodi prudenti norm',
#  'debt fund safest bet today',
#  'hoechst outpac other profit q1 2004',
#  'ficci regul hurdl fdi project',
#  'ifci cheat usha chairman cbi net',
#  'fii net buyer equiti rs 69 cr',
#  'appli right pressur win',
#  'govt provid rs 130 cr relief paradeep phosphat',
#  'harmonis food law rationalis tax task forc',
#  '1 000 multiplex bloom',
#  'indian investor get independ',
#  'assocham moot tourism council eastern region',
#  'rupe steadi dollar',
#  'arvind mill chairman bow',
#  'ansal set mega park noida',
#  'world knowledg worker',
#  'bharti effect revamp invest rs 1 500 crore',
#  'dunlop suspend work sahajganj factori',
#  'hope develop nation amidst slowdown',
#  'india readi discuss trade issu pm',
#  'world economi simultan slump report',
#  'rs 45 397 cr fdi approv telecom',
#  'passeng car sale maintain growth tempo juli',
#  'india fault west high tariff',
#  "cadila' hi-tech plant get total tga nod",
#  'sinha seek support parti pass fra bill',
#  'uk firm discov oil kg offshor',
#  'cid probe order krushi bank scam',
#  'indian co think global rais competit',
#  'orang overtak bpl 1 cell oper',
#  'low domest price hit tea grower return',
#  'ifci bailout may sail',
#  'pm want a-i divest hasten',
#  "uti' posit threat",
#  'fiat set drive palio septemb',
#  'shouri give tata clean chit',
#  'ifc fmo deg invest srei arm',
#  'enron move hc merc bia',
#  'hinduja withdraw bid jessop co',
#  'narasimham keen continu',
#  'hotel corp selloff run deadlock',
#  'pioneer may hike stake mf firm',
#  'spender leav ford india',
#  'basi basmati patent fear',
#  'sensex close 3297.47',
#  'patent 3 basmati strain us',
#  'india necessari adjust indo-nep trade treati',
#  'bor eye rs 80 cr net plan recov rs 80-85 cr npa',
#  'top ten firm post rs 900 cr loss q1',
#  'need rush competit law',
#  "three japanes firm may work boeing' sonic jet",
#  'govt pressur industri hous',
#  'bill remov cap fci borrow approv',
#  "boe airbu valuer ai' aircraft fleet",
#  'fipb okay 29 fdi propos worth rs 135 cr',
#  'auto part maker look china buyout',
#  'npa nationalis bank touch rs 61 416 cr',
#  'a-i bid tata await sia decis',
#  'privat placement safe bet',
#  'sebi propos cbi dispos',
#  'core sector regist 1.2 growth',
#  'confus compound statu a-i bidder',
#  'govt independ director sebi board',
#  'stock scam jpc get extens',
#  'auto part industri pen surviv agenda',
#  'govt induct independ director sebi board',
#  'hll extend reach door-step',
#  'bpcl plan petroleum product export bangladesh',
#  'bad debt bog financi institut',
#  'bata reebok tie-up retail partnership',
#  'slowdown stagnat real estat market worldwid',
#  'canada 3000 tie ia jet',
#  'dragon turn endear',
#  'saarc concern attempt expand wto agenda',
#  'shram award nine ntpc employe',
#  'spender leav ford india',
#  'govt review factori act',
#  'transfer price norm tax intern deal',
#  "sky limit surat' sari czar",
#  'bi invest rs 23cr expans',
#  'zee channel get fresh look',
#  'krushi bank vice chairman held',
#  'royal enfield roll new bike everi 6 month',
#  'steel export regist 5 growth april-juli',
#  'govt await rbi guidelin ssi',
#  'relianc urg start ga cracker project',
#  'subhash chandra dilut stake zee',
#  'a-i disinvest wait bidder',
#  'mutual fund invest debt',
#  'mumbai high upgrad hit speedbreak',
#  'assocham counter flood chines good',
#  'govt get rs 7.78 cr dividend vijaya bank',
#  'basmati export expect 6 lakh tone',
#  'uppal leav volvo',
#  'cvc cag nix propos psu strateg sale',
#  'fi play match-mak enron sell-off',
#  'atla copco ab hike share hold india',
#  'market unimpress mtnl-bsnl tie-up talk',
#  'volvo india eye divers road',
#  'cbi probe forg letter a-i selloff',
#  "hc seek probe uti' invest ril",
#  'steel ministri seek rs 182 cr non-plan loan',
#  'wide incom dispar among chines worker',
#  'dubai media citi woo indian firm',
#  "tata' taco project bite dust",
#  'resolv issu last round first',
#  'corpor bank top brass brush skill iim',
#  'fi take 18 stake automartindia',
#  "united' flight fantasi",
#  'ifc shore india portfolio',
#  'us curb india like say enron chairman',
#  'bidder question a-i balanc sheet',
#  'crude output slip 5.7 p c juli',
#  'rs 16 cr condit bail ketan parekh',
#  'rcf eye fertilis unit sail ppl',
#  'broker optimis deriv incent scheme',
#  "ed seek detail ranbaxy' uk subsidiari",
#  'india expand itec programm',
#  'boi revis interest rate deposit',
#  'alli deal opt hzl cmc',
#  'colorplu goe global expand indian presenc',
#  'quarter balco workforc seek vr',
#  'tc set develop centr hungari',
#  'bharti offer bank guarante dot',
#  'rupe steadi dollar',
#  'sbi home financ rais fund',
#  'sensex move small rang earli stage',
#  'sail submit altern packag iisco',
#  ...]
